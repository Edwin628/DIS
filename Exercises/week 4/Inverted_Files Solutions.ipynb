# %% [markdown]
# ## 📚 Exercise 2: Inverted Files - SOLUTIONS
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.
#
# **Solution in pdf.**

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()

# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content]
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))
# Out:
# [nltk_data] Downloading package stopwords to /Users/aibin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/aibin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
#Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        keyvals.append((word, doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w)
        total += 1
        doc_ids.append(doc_id)
    return (word,total, doc_ids)

# %%
key_values = []
for doc_id, doc_content in docs_n_doc_ids:
    key_values.extend(map_function(doc_id, doc_content))
# Shuffle phase
values = set(map(lambda x:x[0], key_values))
grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
# Reduce phase
inverted_files = []
for grouped_key_value in grouped_key_values:
    word, total, doc_ids = reduce_function(grouped_key_value)
    inverted_files.append((word, total, doc_ids))

# %%
grouped_key_values
# Out:
# [[('highli', 151)],
#  [('fish', 249), ('fish', 254), ('fish', 414), ('fish', 414)],
#  [('lepfllesp', 495)],
#  [('suhaibfahmi', 909)],
#  [('httpstcorcxh00hmqi', 930)],
#  [('begreifbar', 48)],
#  [('microenvironment', 32)],
#  [('doubl', 1009), ('doubl', 1042)],
#  [('gillesjobin1', 313)],
#  [('intern', 121),
#   ('intern', 139),
#   ('intern', 220),
#   ('intern', 631),
#   ('intern', 632),
#   ('intern', 684),
#   ('intern', 759),
#   ('intern', 807),
#   ('intern', 817),
#   ('intern', 934),
#   ('intern', 959)],
#  [('annual', 225)],
#  [('defens', 645), ('defens', 743)],
#  [('hot', 1014)],
#  [('lemoptix', 241), ('lemoptix', 624)],
#  [('vallebenasqu', 431)],
#  [('osaekomi', 295)],
#  [('alogoanalysi', 286)],
#  [('formula', 260)],
#  [('httpstcophsuxdc7hp', 88)],
#  [('flatearth', 99)],
#  [('httpstcoy2s3hz1817', 796)],
#  [('bottomup', 133)],
#  [('traver', 70), ('traver', 351), ('traver', 893)],
#  [('galaxi', 410)],
#  [('jorgensundberg', 232)],
#  [('httpstcogghuh49wmi', 822)],
#  [('tackl', 879)],
#  [('b', 533)],
#  [('httpstconhpahrisgp', 154)],
#  [('prematur', 514)],
#  [('httpstcofhw6avwslu', 525)],
#  [('meta', 80)],
#  [('im', 179),
#   ('im', 262),
#   ('im', 451),
#   ('im', 518),
#   ('im', 572),
#   ('im', 685),
#   ('im', 787),
#   ('im', 813),
#   ('im', 822),
#   ('im', 1011),
#   ('im', 1011),
#   ('im', 1032)],
#  [('handson', 337), ('handson', 985)],
#  [('jdmrt', 1068)],
#  [('ch', 657)],
#  [('neurosci', 84),
#   ('neurosci', 131),
#   ('neurosci', 131),
#   ('neurosci', 340),
#   ('neurosci', 436),
#   ('neurosci', 454)],
#  [('affam', 789)],
#  [('httpstcomfrjlnuopt', 662)],
#  [('httpstco089f9utg0f', 462)],
#  [('hang', 411), ('hang', 626)],
#  [('pvalu', 329)],
#  [('fairi', 491)],
#  [('développ', 827), ('développ', 967), ('développ', 1070)],
#  [('entrepreneur', 180),
#   ('entrepreneur', 613),
#   ('entrepreneur', 646),
#   ('entrepreneur', 791)],
#  [('mathemat', 717)],
#  [('httpstcohoypozoy93', 453)],
#  [('prédécesseur', 665)],
#  [('httpstcofp0yajwe9n', 385)],
#  [('httpstco3bjtbr7d5l', 892)],
#  [('nanoobjetsnanoparticul', 978)],
#  [('be', 65),
#   ('be', 78),
#   ('be', 80),
#   ('be', 102),
#   ('be', 108),
#   ('be', 213),
#   ('be', 236),
#   ('be', 263),
#   ('be', 267),
#   ('be', 314),
#   ('be', 325),
#   ('be', 374),
#   ('be', 411),
#   ('be', 447),
#   ('be', 457),
#   ('be', 479),
#   ('be', 501),
#   ('be', 513),
#   ('be', 519),
#   ('be', 547),
#   ('be', 594),
#   ('be', 613),
#   ('be', 613),
#   ('be', 655),
#   ('be', 660),
#   ('be', 666),
#   ('be', 715),
#   ('be', 715),
#   ('be', 760),
#   ('be', 791),
#   ('be', 845),
#   ('be', 846),
#   ('be', 863),
#   ('be', 903),
#   ('be', 909),
#   ('be', 915),
#   ('be', 999),
#   ('be', 1002),
#   ('be', 1028),
#   ('be', 1072)],
#  [('httpstco9fgitpnf', 572)],
#  [('somat', 734)],
#  [('biomedia', 176)],
#  [('dnasequenc', 159)],
#  [('resolut', 446)],
#  [('venez', 243), ('venez', 983), ('venez', 1037)],
#  [('measur', 86),
#   ('measur', 184),
#   ('measur', 186),
#   ('measur', 242),
#   ('measur', 361),
#   ('measur', 508)],
#  [('httpstcoybrips5tw8', 647)],
#  [('region', 672)],
#  [('regul', 833)],
#  [('srindustryday', 14)],
#  [('save', 339), ('save', 441), ('save', 698), ('save', 887), ('save', 1060)],
#  [('httpstco7wrh9tmlak', 627)],
#  [('meetup', 427)],
#  [('hm17', 48)],
#  [('scala', 315), ('scala', 427), ('scala', 455)],
#  [('winterwonderland', 203)],
#  [('shortliv', 66)],
#  [('aug', 422)],
#  [('gisiq', 441)],
#  [('decentr', 68), ('decentr', 101)],
#  [('mad', 142)],
#  [('usbeketrica', 472)],
#  [('httpstcobwarzzxaya', 1061)],
#  [('porcelain', 770)],
#  [('unibern', 223), ('unibern', 489)],
#  [('httpstco0wb6ae4gox', 200)],
#  [('httpstcoxzwezxleja', 540)],
#  [('fhaptic', 102)],
#  [('fallait', 1071)],
#  [('envirobot', 145), ('envirobot', 828), ('envirobot', 1008)],
#  [('septbern', 489)],
#  [('obligatoir', 277)],
#  [('thomasoppermann', 1057),
#   ('thomasoppermann', 1058),
#   ('thomasoppermann', 1059)],
#  [('httpstco5vujmpeatm', 469)],
#  [('method', 166),
#   ('method', 332),
#   ('method', 377),
#   ('method', 551),
#   ('method', 638),
#   ('method', 786)],
#  [('httpstcomynhu4trvi', 376)],
#  [('hubert', 424)],
#  [('httpstcohpfqgy1yuf', 304)],
#  [('viventi', 286)],
#  [('medicin', 156), ('medicin', 164), ('medicin', 625)],
#  [('social', 292), ('social', 292), ('social', 783), ('social', 1031)],
#  [('reich', 556)],
#  [('portrait', 779)],
#  [('httpstcox8aoof81ho', 1063)],
#  [('pitch', 2), ('pitch', 148), ('pitch', 323), ('pitch', 553)],
#  [('übernommen', 241)],
#  [('🚆ferroviair', 567)],
#  [('trevp', 68)],
#  [('♻🔆', 757)],
#  [('publicli', 80)],
#  [('mani', 122),
#   ('mani', 122),
#   ('mani', 190),
#   ('mani', 262),
#   ('mani', 346),
#   ('mani', 697),
#   ('mani', 724),
#   ('mani', 1044)],
#  [('associ', 207), ('associ', 457)],
#  [('cleantech', 813)],
#  [('phbismuth', 472)],
#  [('httpstcojdre4qvhvj', 284)],
#  [('am', 48),
#   ('am', 52),
#   ('am', 167),
#   ('am', 338),
#   ('am', 582),
#   ('am', 741),
#   ('am', 863)],
#  [('aztitecnalia', 522)],
#  [('weekend', 168),
#   ('weekend', 307),
#   ('weekend', 337),
#   ('weekend', 342),
#   ('weekend', 626),
#   ('weekend', 899)],
#  [('httpstcogprzz9ru08', 657)],
#  [('microbiota', 498)],
#  [('us', 46),
#   ('us', 195),
#   ('us', 245),
#   ('us', 263),
#   ('us', 264),
#   ('us', 359),
#   ('us', 391),
#   ('us', 487),
#   ('us', 504),
#   ('us', 623),
#   ('us', 697),
#   ('us', 726),
#   ('us', 733),
#   ('us', 741),
#   ('us', 790),
#   ('us', 946),
#   ('us', 990)],
#  [('endosymbiont', 809)],
#  [('cours', 165),
#   ('cours', 493),
#   ('cours', 515),
#   ('cours', 600),
#   ('cours', 790),
#   ('cours', 798)],
#  [('dh', 219)],
#  [('lts5', 855)],
#  [('marzari', 89)],
#  [('wef18', 10), ('wef18', 64), ('wef18', 785), ('wef18', 830)],
#  [('appear', 1009)],
#  [('medit', 221)],
#  [('entré', 782)],
#  [('psychologist', 507)],
#  [('effet', 978)],
#  [('kit', 419)],
#  [('kellyannepol', 637)],
#  [('manoeuvr', 1055)],
#  [('natureenergyjnl', 834)],
#  [('geht', 319), ('geht', 1015)],
#  [('httpstco1kcnfc67xr', 996)],
#  [('tbh', 58)],
#  [('stack', 66), ('stack', 66)],
#  [('dachat', 325)],
#  [('lifespan', 55)],
#  [('deliveri', 1061)],
#  [('cyclabl', 1039)],
#  [('temp', 279), ('temp', 844), ('temp', 1066)],
#  [('cyclobiblio', 194)],
#  [('httpstcojjpc1puyum', 9), ('httpstcojjpc1puyum', 774)],
#  [('rabelai', 238)],
#  [('20', 175), ('20', 734), ('20', 1054)],
#  [('httpstcos8gt62d2um', 888)],
#  [('gupta', 469)],
#  [('r2t2', 735)],
#  [('httpstco9dnfecxaof', 466)],
#  [('httpstcorzz6b6brrw', 967)],
#  [('traintest', 734)],
#  [('httpstcovbov65a1jz', 686)],
#  [('ten', 187), ('ten', 720)],
#  [('plug', 290)],
#  [('httpstcob1rcngnblz', 213), ('httpstcob1rcngnblz', 479)],
#  [('latest', 218),
#   ('latest', 232),
#   ('latest', 460),
#   ('latest', 496),
#   ('latest', 552),
#   ('latest', 745),
#   ('latest', 747),
#   ('latest', 864),
#   ('latest', 952)],
#  [('httpstcol977bmopel', 390)],
#  [('play', 100),
#   ('play', 291),
#   ('play', 394),
#   ('play', 539),
#   ('play', 770),
#   ('play', 790)],
#  [('cnbi', 178), ('cnbi', 438)],
#  [('croisé', 304)],
#  [('coll', 781)],
#  [('httpstcozzxzhasdjn', 1022)],
#  [('pagani', 463)],
#  [('headgenev', 705)],
#  [('fad', 1056)],
#  [('mediaroad', 27)],
#  [('love', 125),
#   ('love', 263),
#   ('love', 418),
#   ('love', 466),
#   ('love', 624),
#   ('love', 743)],
#  [('réflexion', 417), ('réflexion', 665)],
#  [('start', 31),
#   ('start', 134),
#   ('start', 230),
#   ('start', 255),
#   ('start', 257),
#   ('start', 260),
#   ('start', 274),
#   ('start', 288),
#   ('start', 359),
#   ('start', 441),
#   ('start', 656),
#   ('start', 719),
#   ('start', 910),
#   ('start', 975),
#   ('start', 984),
#   ('start', 998),
#   ('start', 1015)],
#  [('student', 15),
#   ('student', 38),
#   ('student', 58),
#   ('student', 83),
#   ('student', 88),
#   ('student', 128),
#   ('student', 191),
#   ('student', 196),
#   ('student', 259),
#   ('student', 264),
#   ('student', 269),
#   ('student', 275),
#   ('student', 312),
#   ('student', 323),
#   ('student', 323),
#   ('student', 413),
#   ('student', 471),
#   ('student', 586),
#   ('student', 593),
#   ('student', 596),
#   ('student', 654),
#   ('student', 677),
#   ('student', 700),
#   ('student', 709),
#   ('student', 716),
#   ('student', 716),
#   ('student', 733),
#   ('student', 790),
#   ('student', 790),
#   ('student', 807),
#   ('student', 847),
#   ('student', 985),
#   ('student', 1013)],
#  [('exciton', 303)],
#  [('reconnu', 665)],
#  [('iitdelhi', 748)],
#  [('site', 342), ('site', 705), ('site', 770), ('site', 800), ('site', 1039)],
#  [('onboard', 666)],
#  [('httpstcolyyuk5w3yp', 150)],
#  [('httpstco2hvx5go6s6', 472)],
#  [('httpstcovh8rzk17p4', 257)],
#  [('congratul', 191),
#   ('congratul', 257),
#   ('congratul', 285),
#   ('congratul', 434),
#   ('congratul', 593),
#   ('congratul', 720),
#   ('congratul', 731),
#   ('congratul', 891),
#   ('congratul', 940)],
#  [('coder', 347), ('coder', 1047)],
#  [('délicat', 665)],
#  [('httpstcouocn4jhqwb', 531)],
#  [('httpstcoynvyv7enuk', 222)],
#  [('stage', 56)],
#  [('httpstcoxfn5abbrit', 138)],
#  [('entrepreun', 910)],
#  [('dangereus', 821)],
#  [('drug', 211), ('drug', 284), ('drug', 577)],
#  [('httpstcosp5h61ese', 738)],
#  [('📚📝', 96)],
#  [('précieux', 279)],
#  [('httpstcofzflfmwopo', 743)],
#  [('coccolo', 322)],
#  [('navig', 104), ('navig', 1005)],
#  [('veri', 125),
#   ('veri', 260),
#   ('veri', 293),
#   ('veri', 307),
#   ('veri', 333),
#   ('veri', 575),
#   ('veri', 629),
#   ('veri', 771),
#   ('veri', 808),
#   ('veri', 830),
#   ('veri', 963)],
#  [('state', 66)],
#  [('httpstcogyvwr4hg0h', 385)],
#  [('edtech', 91),
#   ('edtech', 222),
#   ('edtech', 273),
#   ('edtech', 273),
#   ('edtech', 386),
#   ('edtech', 652)],
#  [('unicef', 143)],
#  [('relevé', 167), ('relevé', 252)],
#  [('mbryzek', 427)],
#  [('cérébrale', 277)],
#  [('phantom', 718)],
#  [('reliabl', 329), ('reliabl', 485), ('reliabl', 797)],
#  [('christma', 600), ('christma', 719), ('christma', 820)],
#  [('stabil', 66),
#   ('stabil', 289),
#   ('stabil', 377),
#   ('stabil', 551),
#   ('stabil', 628)],
#  [('jami', 699)],
#  [('into', 9),
#   ('into', 50),
#   ('into', 73),
#   ('into', 88),
#   ('into', 303),
#   ('into', 396),
#   ('into', 669),
#   ('into', 692),
#   ('into', 722),
#   ('into', 726),
#   ('into', 746),
#   ('into', 754),
#   ('into', 774),
#   ('into', 839)],
#  [('biociment', 283)],
#  [('💉', 655)],
#  [('academ', 642)],
#  [('martian', 24), ('martian', 67), ('martian', 153), ('martian', 932)],
#  [('httpstcoqvsxcayny7', 70)],
#  [('cheat', 240)],
#  [('marathon', 363)],
#  [('iro', 609)],
#  [('encor', 168), ('encor', 402), ('encor', 627)],
#  [('iitalk', 878)],
#  [('committe', 306), ('committe', 336)],
#  [('appli', 33),
#   ('appli', 60),
#   ('appli', 196),
#   ('appli', 222),
#   ('appli', 260),
#   ('appli', 337),
#   ('appli', 347),
#   ('appli', 422),
#   ('appli', 576),
#   ('appli', 640),
#   ('appli', 676),
#   ('appli', 688),
#   ('appli', 899),
#   ('appli', 987)],
#  [('hackathon', 420),
#   ('hackathon', 587),
#   ('hackathon', 656),
#   ('hackathon', 730),
#   ('hackathon', 873)],
#  [('determin', 32), ('determin', 525), ('determin', 607)],
#  [('semiarid', 235)],
#  [('grant', 53), ('grant', 697), ('grant', 697)],
#  [('httpstcowfi6bx6p79', 526)],
#  [('therapeut', 972)],
#  [('mail', 641)],
#  [('technew', 414)],
#  [('httpstcopzhx72iq33', 945)],
#  [('materialwissenschaft', 309)],
#  [('httpstcoksychtfodv', 759)],
#  [('deepartio', 612)],
#  [('présidenc', 665)],
#  [('httpstco2vqqgqhact', 11)],
#  [('valaisw', 829), ('valaisw', 847)],
#  [('httpstcowqjw1nfwcb', 691)],
#  [('overdu', 768)],
#  [('httpstcod8i7iov05c', 652)],
#  [('maddoxpr', 778), ('maddoxpr', 1006)],
#  [('aisten', 870)],
#  [('scm2018', 203), ('scm2018', 662)],
#  [('wave', 44), ('wave', 328), ('wave', 527), ('wave', 534), ('wave', 908)],
#  [('mention', 643), ('mention', 869)],
#  [('cryogen', 916)],
#  [('lematinch', 901)],
#  [('intestin', 607)],
#  [('bioterror', 641)],
#  [('collegium', 304)],
#  [('isabel', 801)],
#  [('lose', 692)],
#  [('except', 605), ('except', 790)],
#  [('ktsakmakidi', 728)],
#  [('httpstcooyjavnzdna', 647)],
#  [('four', 521)],
#  [('frauduleux', 773)],
#  [('peter', 957)],
#  [('faux', 659)],
#  [('from', 22),
#   ('from', 30),
#   ('from', 32),
#   ('from', 59),
#   ('from', 59),
#   ('from', 83),
#   ('from', 89),
#   ('from', 100),
#   ('from', 108),
#   ('from', 164),
#   ('from', 223),
#   ('from', 227),
#   ('from', 247),
#   ('from', 260),
#   ('from', 271),
#   ('from', 276),
#   ('from', 303),
#   ('from', 318),
#   ('from', 335),
#   ('from', 359),
#   ('from', 365),
#   ('from', 365),
#   ('from', 409),
#   ('from', 413),
#   ('from', 414),
#   ('from', 416),
#   ('from', 427),
#   ('from', 427),
#   ('from', 444),
#   ('from', 464),
#   ('from', 469),
#   ('from', 481),
#   ('from', 486),
#   ('from', 499),
#   ('from', 507),
#   ('from', 515),
#   ('from', 532),
#   ('from', 535),
#   ('from', 535),
#   ('from', 545),
#   ('from', 562),
#   ('from', 563),
#   ('from', 575),
#   ('from', 587),
#   ('from', 591),
#   ('from', 593),
#   ('from', 607),
#   ('from', 608),
#   ('from', 614),
#   ('from', 615),
#   ('from', 622),
#   ('from', 630),
#   ('from', 648),
#   ('from', 655),
#   ('from', 663),
#   ('from', 694),
#   ('from', 694),
#   ('from', 712),
#   ('from', 731),
#   ('from', 734),
#   ('from', 734),
#   ('from', 735),
#   ('from', 738),
#   ('from', 765),
#   ('from', 776),
#   ('from', 831),
#   ('from', 847),
#   ('from', 849),
#   ('from', 849),
#   ('from', 855),
#   ('from', 905),
#   ('from', 930),
#   ('from', 966),
#   ('from', 992),
#   ('from', 1013),
#   ('from', 1033),
#   ('from', 1064)],
#  [('microcityn', 402)],
#  [('around', 290), ('around', 614), ('around', 689), ('around', 764)],
#  [('pay', 26)],
#  [('prêter', 1049)],
#  [('gan', 859), ('gan', 859)],
#  [('httpstcoq3zob59dwu', 337)],
#  [('than', 21),
#   ('than', 64),
#   ('than', 64),
#   ('than', 111),
#   ('than', 214),
#   ('than', 355),
#   ('than', 379),
#   ('than', 531),
#   ('than', 580),
#   ('than', 778),
#   ('than', 811),
#   ('than', 858)],
#  [('alison', 323)],
#  [('h2020', 200),
#   ('h2020', 341),
#   ('h2020', 346),
#   ('h2020', 391),
#   ('h2020', 457)],
#  [('httpstcod7ylxqyt2a', 549)],
#  [('idiapch', 507)],
#  [('httpstcosraxlq5vc', 222)],
#  [('deconvolutionlab2', 80), ('deconvolutionlab2', 100)],
#  [('sustain', 229),
#   ('sustain', 401),
#   ('sustain', 510),
#   ('sustain', 669),
#   ('sustain', 669),
#   ('sustain', 748),
#   ('sustain', 915)],
#  [('luca', 1069)],
#  [('either', 791)],
#  [('dautr', 342), ('dautr', 682)],
#  [('biometr', 1073)],
#  [('newdawn', 608)],
#  [('flat', 872)],
#  [('httpstco6ixddicblu', 964)],
#  [('httpstco0iqt3k8fkq', 32)],
#  [('butterfli', 112)],
#  [('chergui', 504)],
#  [('map', 206)],
#  [('cela', 356), ('cela', 392)],
#  [('household', 166)],
#  [('receiv', 409), ('receiv', 525), ('receiv', 707)],
#  [('drosophila', 809)],
#  [('effyvayena', 50), ('effyvayena', 59), ('effyvayena', 580)],
#  [('httpstcoj2equhxb66', 309)],
#  [('débrouillé', 548)],
#  [('hgststorag', 1012)],
#  [('coorpacademi', 273)],
#  [('effect', 217)],
#  [('dotastro', 869)],
#  [('httpstcof2bc5igpvo', 1057)],
#  [('httpstcoiwtbu2mfyr', 554)],
#  [('astronom', 869)],
#  [('slasher', 702)],
#  [('httpstcocmx5oahu6a', 446)],
#  [('httpstcoquwkbsmdmf', 673)],
#  [('touchscreen', 878)],
#  [('lcc2018', 32)],
#  [('ultrasound', 855)],
#  [('libreinscript', 782)],
#  [('sofc', 1013)],
#  [('unineuchatel', 402)],
#  [('1112', 642)],
#  [('sphere', 221)],
#  [('httpstcok34o7qqbnp', 690)],
#  [('council', 291)],
#  [('smlotzd', 732)],
#  [('httpstcovp03plbbr7', 982)],
#  [('savoirpati', 1035)],
#  [('jamesgleick', 573)],
#  [('librari', 125),
#   ('librari', 136),
#   ('librari', 136),
#   ('librari', 326),
#   ('librari', 466),
#   ('librari', 655)],
#  [('httpstco3cnvxvrwdd', 441)],
#  [('bigdata', 165),
#   ('bigdata', 533),
#   ('bigdata', 737),
#   ('bigdata', 946),
#   ('bigdata', 1012)],
#  [('leila', 935)],
#  [('school', 78),
#   ('school', 152),
#   ('school', 249),
#   ('school', 371),
#   ('school', 414),
#   ('school', 453),
#   ('school', 473),
#   ('school', 517),
#   ('school', 535),
#   ('school', 560),
#   ('school', 561),
#   ('school', 684),
#   ('school', 853),
#   ('school', 899),
#   ('school', 968)],
#  [('dedic', 125), ('dedic', 673)],
#  [('believ', 278)],
#  [('🔪', 655)],
#  [('👉httpstcowgalji7h0g', 240)],
#  [('genèv', 243),
#   ('genèv', 463),
#   ('genèv', 571),
#   ('genèv', 571),
#   ('genèv', 876),
#   ('genèv', 1070)],
#  [('switzerlandglobalenterpris', 1041)],
#  [('fascinant', 456)],
#  [('style', 413), ('style', 682), ('style', 682)],
#  [('altitud', 611)],
#  [('sa\u200b', 1053)],
#  [('diy', 416)],
#  [('glückwunsch', 954)],
#  [('consanguin', 112)],
#  [('andor', 80)],
#  [('wcsj2019', 594)],
#  [('httpstco6c3s2rk03u', 563)],
#  [('httpstcoihyjn6az2i', 242)],
#  [('antibiotiqu', 149), ('antibiotiqu', 405), ('antibiotiqu', 424)],
#  [('citecmobilit', 842)],
#  [('httpstcoboxkkgrla', 553)],
#  [('httpstcote2xm3np15', 502)],
#  [('httpstco7whgqt8bmg', 398)],
#  [('vmwaremitgründ', 25)],
#  [('sketchnot', 431)],
#  [('algo2017', 533)],
#  [('solid', 166)],
#  [('cdfdanslapress', 282)],
#  [('mfe', 946)],
#  [('epflenac', 202),
#   ('epflenac', 299),
#   ('epflenac', 400),
#   ('epflenac', 400),
#   ('epflenac', 421),
#   ('epflenac', 446),
#   ('epflenac', 512),
#   ('epflenac', 601),
#   ('epflenac', 608),
#   ('epflenac', 710),
#   ('epflenac', 736),
#   ('epflenac', 867),
#   ('epflenac', 881),
#   ('epflenac', 931)],
#  [('visual', 316), ('visual', 450), ('visual', 867)],
#  [('ins2017', 114)],
#  [('😃', 654)],
#  [('carboneutr', 996)],
#  [('augmenté', 408)],
#  [('publichealth', 494)],
#  [('afternoon', 223)],
#  [('45th', 550)],
#  [('hormon', 714)],
#  [('sélectionné', 160)],
#  [('gafam', 924)],
#  [('httpstcovdczjrh87j', 772)],
#  [('ris3', 704)],
#  [('swissdecod', 587)],
#  [('httpstcopqslfajac', 289)],
#  [('ethspinoff', 963)],
#  [('solliancesolar', 419)],
#  [('sundanc', 313)],
#  [('ethen', 0),
#   ('ethen', 3),
#   ('ethen', 13),
#   ('ethen', 54),
#   ('ethen', 64),
#   ('ethen', 139),
#   ('ethen', 200),
#   ('ethen', 267),
#   ('ethen', 295),
#   ('ethen', 391),
#   ('ethen', 399),
#   ('ethen', 489),
#   ('ethen', 549),
#   ('ethen', 560),
#   ('ethen', 675),
#   ('ethen', 686),
#   ('ethen', 858),
#   ('ethen', 934),
#   ('ethen', 984),
#   ('ethen', 995)],
#  [('httpstco9qvu4leli0', 728)],
#  [('httpstcoqdjxfnh9ji', 357)],
#  [('publié', 710)],
#  [('katsyuba', 694)],
#  [('httpstco9f9q98oxp', 921)],
#  [('sconnect', 62)],
#  [('surprisingli', 87)],
#  [('spiroplasma', 809)],
#  [('srf', 576)],
#  [('1989', 720)],
#  [('httpstcotism9yrbeb', 629)],
#  [('trump', 556), ('trump', 620), ('trump', 1054)],
#  [('chroniqu', 1031)],
#  [('lallianc', 565)],
#  [('httpstcoa9sfxas20o', 805)],
#  [('joshconstin', 247)],
#  [('epflinnov', 677)],
#  [('livetweet', 899)],
#  [('two', 23),
#   ('two', 206),
#   ('two', 373),
#   ('two', 407),
#   ('two', 605),
#   ('two', 791),
#   ('two', 898),
#   ('two', 1006),
#   ('two', 1013)],
#  [('swissmadehardwar', 624)],
#  [('univbfc', 304)],
#  [('globu', 1011)],
#  [('recrut', 592)],
#  [('interview', 69),
#   ('interview', 181),
#   ('interview', 702),
#   ('interview', 741),
#   ('interview', 795),
#   ('interview', 905)],
#  [('introduct', 275)],
#  [('httpstcovuof6zibbm', 473)],
#  [('httpstcozmvfhhyhli', 141)],
#  [('molsystbiol', 629)],
#  [('27', 13), ('27', 633)],
#  [('newyear', 719)],
#  [('0', 572), ('0', 572)],
#  [('biorxivneursci', 290)],
#  [('exposur', 420), ('exposur', 730)],
#  [('fntpinfo', 815)],
#  [('httpstcosxe1fctdy4', 256)],
#  [('httpstcok8npxuuki8', 883), ('httpstcok8npxuuki8', 884)],
#  [('irem', 731)],
#  [('httpstcol4gcxplvsi', 688)],
#  [('beau', 1066)],
#  [('httpstco0givobwpuo', 593)],
#  [('guider', 789)],
#  [('boi', 737)],
#  [('noninvas', 758)],
#  [('startuptickerch', 286),
#   ('startuptickerch', 421),
#   ('startuptickerch', 801)],
#  [('httpstcoy3ixctmmey', 1024)],
#  [('dy', 1049)],
#  [('virtualswiss', 624)],
#  [('artificialintellig', 292),
#   ('artificialintellig', 414),
#   ('artificialintellig', 452)],
#  [('httpstcoo22esavphf', 725)],
#  [('hackdisrupt', 218)],
#  [('tdiethinktank', 815)],
#  [('httpstcognraozl2zh', 521)],
#  [('periperson', 290)],
#  [('jaqu', 42)],
#  [('anyth', 585)],
#  [('pmaurericrc', 830)],
#  [('richter', 1053)],
#  [('employe', 938)],
#  [('nétiez', 659)],
#  [('chang', 768), ('chang', 869)],
#  [('here', 44),
#   ('here', 103),
#   ('here', 185),
#   ('here', 262),
#   ('here', 278),
#   ('here', 348),
#   ('here', 353),
#   ('here', 466),
#   ('here', 559),
#   ('here', 576),
#   ('here', 635),
#   ('here', 678),
#   ('here', 688),
#   ('here', 743),
#   ('here', 937)],
#  [('httpstcof20kegnzrl', 870)],
#  [('predict', 127), ('predict', 557)],
#  [('vo', 801)],
#  [('womensmarch', 281), ('womensmarch', 582)],
#  [('überführen', 890)],
#  [('httpstcofgzktgbjq6', 419)],
#  [('httpstcoq0oikdrfgg', 77)],
#  [('begin', 471), ('begin', 605), ('begin', 625)],
#  [('entretien', 463)],
#  [('central', 617), ('central', 885)],
#  [('thx', 561)],
#  [('smartphon', 528), ('smartphon', 602)],
#  [('dirti', 941)],
#  [('insectmicrob', 991)],
#  [('extend', 393)],
#  [('privileg', 1072)],
#  [('httpstcothtcylrmtn', 162)],
#  [('nation', 54), ('nation', 64), ('nation', 480)],
#  [('vrai', 659), ('vrai', 687)],
#  [('httpstcodcuyrn9fng', 606)],
#  [('mondial', 1024)],
#  [('15h', 345)],
#  [('httpstcofgvqhgwc58', 428)],
#  [('collid', 273), ('collid', 1016)],
#  [('httpstcoytpwpwdbg', 710)],
#  [('httpstcormxjlczif6', 64)],
#  [('spacewatchm', 798)],
#  [('gewch2017', 72), ('gewch2017', 623)],
#  [('wir', 319)],
#  [('cohabitonsepfl', 1049)],
#  [('ethzurich', 1036)],
#  [('httpstcojt7hmcgny', 915)],
#  [('chemic', 743)],
#  [('wurd', 338)],
#  [('nano', 87), ('nano', 916)],
#  [('base', 292),
#   ('base', 457),
#   ('base', 503),
#   ('base', 681),
#   ('base', 682),
#   ('base', 684),
#   ('base', 739),
#   ('base', 799)],
#  [('httpstcoz9peeqtzc', 788)],
#  [('httpstcojlgbaxvtkj', 924)],
#  [('some', 100),
#   ('some', 100),
#   ('some', 185),
#   ('some', 189),
#   ('some', 262),
#   ('some', 323),
#   ('some', 457),
#   ('some', 458),
#   ('some', 466),
#   ('some', 474),
#   ('some', 640),
#   ('some', 722),
#   ('some', 836),
#   ('some', 937),
#   ('some', 1056)],
#  [('interiordesign', 232)],
#  [('10', 222),
#   ('10', 483),
#   ('10', 536),
#   ('10', 550),
#   ('10', 604),
#   ('10', 995)],
#  [('thermiqu', 322)],
#  [('yosef', 910)],
#  [('analyz', 690)],
#  [('réalité', 386)],
#  [('énergi', 283)],
#  [('httpstcoestl9bkiyv', 318)],
#  [('httpstcoawob8mwpvw', 681)],
#  [('worldclass', 990)],
#  [('membr', 63)],
#  [('food', 158), ('food', 323), ('food', 587), ('food', 606), ('food', 1056)],
#  [('uefaeuro', 128)],
#  [('fun', 542), ('fun', 587)],
#  [('againstbc', 8)],
#  [('embopress', 629)],
#  [('afford', 1061)],
#  [('httpstco39urk8zhu9', 905)],
#  [('httpstcocvhref9yhb', 252)],
#  [('swissgam', 313), ('swissgam', 624)],
#  [('wasserstein', 859)],
#  [('pepsico', 522)],
#  [('give', 32),
#   ('give', 213),
#   ('give', 312),
#   ('give', 418),
#   ('give', 518),
#   ('give', 765)],
#  [('julienguex', 800)],
#  [('témoignag', 955)],
#  [('seednight', 156), ('seednight', 553)],
#  [('vertic', 1004)],
#  [('not', 1),
#   ('not', 45),
#   ('not', 104),
#   ('not', 260),
#   ('not', 312),
#   ('not', 335),
#   ('not', 461),
#   ('not', 512),
#   ('not', 587),
#   ('not', 655),
#   ('not', 863),
#   ('not', 863),
#   ('not', 872),
#   ('not', 903),
#   ('not', 965)],
#  [('hbagp', 320), ('hbagp', 381)],
#  [('httpstcoyrndlr6zh0', 187)],
#  [('httpstcohwhjoi3lw5', 865)],
#  [('you', 50),
#   ('you', 50),
#   ('you', 68),
#   ('you', 80),
#   ('you', 215),
#   ('you', 236),
#   ('you', 245),
#   ('you', 260),
#   ('you', 260),
#   ('you', 262),
#   ('you', 263),
#   ('you', 278),
#   ('you', 307),
#   ('you', 307),
#   ('you', 315),
#   ('you', 337),
#   ('you', 340),
#   ('you', 341),
#   ('you', 367),
#   ('you', 393),
#   ('you', 397),
#   ('you', 397),
#   ('you', 411),
#   ('you', 422),
#   ('you', 445),
#   ('you', 448),
#   ('you', 448),
#   ('you', 482),
#   ('you', 509),
#   ('you', 531),
#   ('you', 537),
#   ('you', 540),
#   ('you', 540),
#   ('you', 559),
#   ('you', 620),
#   ('you', 621),
#   ('you', 635),
#   ('you', 635),
#   ('you', 640),
#   ('you', 654),
#   ('you', 655),
#   ('you', 671),
#   ('you', 691),
#   ('you', 691),
#   ('you', 692),
#   ('you', 791),
#   ('you', 791),
#   ('you', 791),
#   ('you', 791),
#   ('you', 810),
#   ('you', 820),
#   ('you', 938),
#   ('you', 940),
#   ('you', 963),
#   ('you', 973),
#   ('you', 987),
#   ('you', 1033),
#   ('you', 1074)],
#  [('impression3d', 327)],
#  [('httpstcooe6jhuulm9', 169)],
#  [('king', 1012)],
#  [('metastasi', 32)],
#  [('httpstco2va71avjyg', 841)],
#  [('moniqu', 1021)],
#  [('address', 401),
#   ('address', 492),
#   ('address', 519),
#   ('address', 724),
#   ('address', 899)],
#  [('httpstcovtwtstrorc', 761)],
#  [('cardiacsurgeon', 758)],
#  [('jan', 68), ('jan', 590)],
#  [('0203', 569)],
#  [('connai', 199)],
#  [('httpstcosrldb2o7pm', 423)],
#  [('cyberintproject', 746)],
#  [('leaf', 237)],
#  [('sichert', 425)],
#  [('imagejop', 80)],
#  [('1er', 160), ('1er', 894), ('1er', 902)],
#  [('revoir', 12)],
#  [('nonalcohol', 298)],
#  [('mass', 624), ('mass', 745)],
#  [('httpstcoou16d36it9', 171)],
#  [('srsa', 1066)],
#  [('campu', 37),
#   ('campu', 40),
#   ('campu', 82),
#   ('campu', 130),
#   ('campu', 202),
#   ('campu', 342),
#   ('campu', 430),
#   ('campu', 455),
#   ('campu', 643),
#   ('campu', 812),
#   ('campu', 925),
#   ('campu', 996),
#   ('campu', 996),
#   ('campu', 1032),
#   ('campu', 1063),
#   ('campu', 1066)],
#  [('cosmoorbu', 472)],
#  [('fifa', 291)],
#  [('httpstcoibllxngn6r', 1003)],
#  [('roboadvisor', 946)],
#  [('delà', 1043)],
#  [('enabl', 229), ('enabl', 259), ('enabl', 628)],
#  [('calibr', 438)],
#  [('display', 458)],
#  [('bese', 741)],
#  [('post', 286)],
#  [('httpstco0bgdavipyo', 899)],
#  [('wish', 277), ('wish', 307), ('wish', 491), ('wish', 940), ('wish', 1034)],
#  [('httpstcopc8hbowbwn', 525)],
#  [('digitalinnov', 245)],
#  [('📧', 197)],
#  [('bellon', 419)],
#  [('infra', 520)],
#  [('mystèr', 300), ('mystèr', 523)],
#  [('5060', 1068)],
#  [('even', 110),
#   ('even', 111),
#   ('even', 134),
#   ('even', 278),
#   ('even', 355),
#   ('even', 556),
#   ('even', 620),
#   ('even', 811),
#   ('even', 957),
#   ('even', 979)],
#  [('on🇪🇺eufund', 717)],
#  [('nviso', 448)],
#  [('marchand', 1068)],
#  [('demo', 316), ('demo', 323), ('demo', 518)],
#  [('ssuinvest', 646)],
#  [('beat', 344)],
#  [('damasio', 472)],
#  [('développeur', 862)],
#  [('depriv', 494)],
#  [('ebugnion', 10), ('ebugnion', 25)],
#  [('numeriqu', 12)],
#  [('bours', 43), ('bours', 574)],
#  [('tough', 650)],
#  [('httpstcoveig9f8bpl', 35)],
#  [('vdtech', 53),
#   ('vdtech', 62),
#   ('vdtech', 110),
#   ('vdtech', 120),
#   ('vdtech', 132),
#   ('vdtech', 156),
#   ('vdtech', 177),
#   ('vdtech', 206),
#   ('vdtech', 228),
#   ('vdtech', 242),
#   ('vdtech', 256),
#   ('vdtech', 286),
#   ('vdtech', 332),
#   ('vdtech', 354),
#   ('vdtech', 364),
#   ('vdtech', 389),
#   ('vdtech', 405),
#   ('vdtech', 421),
#   ('vdtech', 432),
#   ('vdtech', 508),
#   ('vdtech', 562),
#   ('vdtech', 616),
#   ('vdtech', 623),
#   ('vdtech', 649),
#   ('vdtech', 652),
#   ('vdtech', 693),
#   ('vdtech', 718),
#   ('vdtech', 754),
#   ('vdtech', 788),
#   ('vdtech', 800),
#   ('vdtech', 801),
#   ('vdtech', 831),
#   ('vdtech', 838),
#   ('vdtech', 852),
#   ('vdtech', 865),
#   ('vdtech', 882),
#   ('vdtech', 883),
#   ('vdtech', 884),
#   ('vdtech', 885),
#   ('vdtech', 891),
#   ('vdtech', 902),
#   ('vdtech', 970),
#   ('vdtech', 997),
#   ('vdtech', 1027),
#   ('vdtech', 1048),
#   ('vdtech', 1050)],
#  [('httpstcodgxoj2dafk', 219)],
#  [('diaspora', 746)],
#  [('httpstcocjwc2eueii', 762)],
#  [('léprouvett', 265)],
#  [('httpstco2eruzdhgxv', 610)],
#  [('expand', 499)],
#  [('cybersecurityday', 251),
#   ('cybersecurityday', 321),
#   ('cybersecurityday', 645),
#   ('cybersecurityday', 724),
#   ('cybersecurityday', 803)],
#  [('«', 167),
#   ('«', 188),
#   ('«', 202),
#   ('«', 208),
#   ('«', 252),
#   ('«', 282),
#   ('«', 294),
#   ('«', 366),
#   ('«', 384),
#   ('«', 468),
#   ('«', 610),
#   ('«', 618),
#   ('«', 627),
#   ('«', 636),
#   ('«', 644),
#   ('«', 710),
#   ('«', 742),
#   ('«', 752),
#   ('«', 842),
#   ('«', 851),
#   ('«', 862),
#   ('«', 862),
#   ('«', 1071)],
#  [('httpstcobhlj5whmbc', 424)],
#  [('epflfood', 253)],
#  [('draft', 341)],
#  [('watch', 17),
#   ('watch', 84),
#   ('watch', 99),
#   ('watch', 301),
#   ('watch', 353),
#   ('watch', 459),
#   ('watch', 613),
#   ('watch', 635),
#   ('watch', 649),
#   ('watch', 718),
#   ('watch', 992)],
#  [('pleas', 352), ('pleas', 640)],
#  [('considér', 62)],
#  [('co2', 900), ('co2', 965)],
#  [('grund', 611)],
#  [('cff', 250)],
#  [('naturecomm', 74), ('naturecomm', 211), ('naturecomm', 959)],
#  [('httpstco1rc2edm3bc', 913)],
#  [('deputi', 293)],
#  [('httpstcokzbzzlzn5c', 972)],
#  [('alex', 104), ('alex', 292)],
#  [('lutolf', 607)],
#  [('deciph', 755), ('deciph', 809)],
#  [('again', 646), ('again', 1029)],
#  [('curvilinear', 680)],
#  [('rolexlearningcent', 96),
#   ('rolexlearningcent', 168),
#   ('rolexlearningcent', 197),
#   ('rolexlearningcent', 749),
#   ('rolexlearningcent', 851),
#   ('rolexlearningcent', 872)],
#  [('httpstcoos7mfkm1eh', 177)],
#  [('professeur', 118), ('professeur', 463), ('professeur', 958)],
#  [('pierresoulag', 174), ('pierresoulag', 456), ('pierresoulag', 895)],
#  [('gerufen', 188)],
#  [('stream', 119)],
#  [('urswyd', 890)],
#  [('httpstcozyhob4ukc', 734)],
#  [('intellig', 62),
#   ('intellig', 69),
#   ('intellig', 292),
#   ('intellig', 610),
#   ('intellig', 797),
#   ('intellig', 1070)],
#  [('ml', 34),
#   ('ml', 97),
#   ('ml', 347),
#   ('ml', 501),
#   ('ml', 691),
#   ('ml', 899),
#   ('ml', 899)],
#  [('compbio', 30)],
#  [('pl', 530)],
#  [('energystorag', 117), ('energystorag', 642)],
#  [('catégori', 383)],
#  [('httpstcoirx8jrn9uk', 592)],
#  [('event', 15),
#   ('event', 27),
#   ('event', 33),
#   ('event', 62),
#   ('event', 180),
#   ('event', 420),
#   ('event', 471),
#   ('event', 559),
#   ('event', 605),
#   ('event', 762),
#   ('event', 874),
#   ('event', 973),
#   ('event', 987)],
#  [('result', 80), ('result', 375)],
#  [('détect', 383)],
#  [('parmelin', 238)],
#  [('eric', 327)],
#  [('1011', 1048)],
#  [('clipair', 711), ('clipair', 711)],
#  [('sandec', 975)],
#  [('constraint', 260)],
#  [('bonjour', 467)],
#  [('httpstcouyp6thrhbm', 564)],
#  [('httpstcojgq7umgzgi', 378)],
#  [('9', 39), ('9', 202), ('9', 525), ('9', 586), ('9', 615), ('9', 741)],
#  [('nathanquint', 621)],
#  [('elderli', 486)],
#  [('spectra', 661)],
#  [('realen', 737)],
#  [('christianeuhau', 552)],
#  [('ventur', 286), ('ventur', 506), ('ventur', 1027)],
#  [('get', 5),
#   ('get', 211),
#   ('get', 222),
#   ('get', 348),
#   ('get', 352),
#   ('get', 390),
#   ('get', 464),
#   ('get', 554),
#   ('get', 557),
#   ('get', 649),
#   ('get', 688),
#   ('get', 719),
#   ('get', 941),
#   ('get', 953),
#   ('get', 979),
#   ('get', 985),
#   ('get', 1006),
#   ('get', 1046),
#   ('get', 1065)],
#  [('dies', 451)],
#  [('httpstcoulurhrsqwi', 353)],
#  [('httpstcouriy2wnepi', 79)],
#  [('🐦', 341)],
#  [('arbor', 913)],
#  [('6th', 301)],
#  [('universitelav', 554)],
#  [('httpstcoyqz0yffegc', 551)],
#  [('ex', 739)],
#  [('630pm', 390)],
#  [('win', 77), ('win', 175), ('win', 267), ('win', 272), ('win', 688)],
#  [('répétition', 1019)],
#  [('mayb', 312), ('mayb', 938)],
#  [('elaudierlaudi', 530)],
#  [('httpstcozwtxnyi6r1', 512)],
#  [('httpstcoz9l9tvcek', 598)],
#  [('edit', 390), ('edit', 464)],
#  [('leg', 108), ('leg', 373)],
#  [('enc2017', 1005)],
#  [('1315', 1047)],
#  [('besson', 855)],
#  [('iplf', 525), ('iplf', 752)],
#  [('ged', 535)],
#  [('httpstcoxunovzzdtm', 517)],
#  [('qualifi', 308)],
#  [('pic', 375), ('pic', 1005)],
#  [('lespac', 570)],
#  [('humanitarian', 830), ('humanitarian', 856), ('humanitarian', 975)],
#  [('transport', 69),
#   ('transport', 69),
#   ('transport', 366),
#   ('transport', 520),
#   ('transport', 851),
#   ('transport', 1061)],
#  [('t', 140), ('t', 278), ('t', 373), ('t', 691), ('t', 692)],
#  [('focus', 303), ('focus', 507)],
#  [('featur', 458), ('featur', 612), ('featur', 856), ('featur', 905)],
#  [('small', 68), ('small', 414)],
#  [('neu', 890)],
#  [('suincol', 154)],
#  [('earn', 881)],
#  [('lahauteecolearc', 383)],
#  [('envol', 860)],
#  [('httpstco5uemh3nxma', 732)],
#  [('courtin', 114)],
#  [('news', 4), ('news', 630)],
#  [('goodpowwow', 915)],
#  [('meet', 95),
#   ('meet', 98),
#   ('meet', 143),
#   ('meet', 203),
#   ('meet', 225),
#   ('meet', 270),
#   ('meet', 274),
#   ('meet', 305),
#   ('meet', 306),
#   ('meet', 323),
#   ('meet', 339),
#   ('meet', 459),
#   ('meet', 487),
#   ('meet', 489),
#   ('meet', 578),
#   ('meet', 588),
#   ('meet', 601),
#   ('meet', 607),
#   ('meet', 629),
#   ('meet', 643),
#   ('meet', 679),
#   ('meet', 699),
#   ('meet', 733),
#   ('meet', 748),
#   ('meet', 1008)],
#  [('httpstcolijub1fwym', 654)],
#  [('union', 294), ('union', 468)],
#  [('tensorflow', 276)],
#  [('jeffrey', 260)],
#  [('surround', 1032)],
#  [('prixbcninnovation17', 568)],
#  [('ateli', 11), ('ateli', 265), ('ateli', 265)],
#  [('httpstcoyjguw9c133', 382)],
#  [('museebolo', 698)],
#  [('confer', 31),
#   ('confer', 179),
#   ('confer', 250),
#   ('confer', 306),
#   ('confer', 308),
#   ('confer', 340),
#   ('confer', 538),
#   ('confer', 541),
#   ('confer', 622),
#   ('confer', 629),
#   ('confer', 635),
#   ('confer', 804),
#   ('confer', 999),
#   ('confer', 1005),
#   ('confer', 1060)],
#  [('henri', 818)],
#  [('résistant', 405), ('résistant', 424)],
#  [('httpstcoju8ess8cuj', 798)],
#  [('httpstco1ja3cl59dq', 872)],
#  [('cen', 107)],
#  [('larchiv', 844)],
#  [('plate', 485)],
#  [('dimens', 882)],
#  [('hack', 587), ('hack', 587), ('hack', 587)],
#  [('mar', 24),
#   ('mar', 67),
#   ('mar', 153),
#   ('mar', 554),
#   ('mar', 782),
#   ('mar', 894),
#   ('mar', 902),
#   ('mar', 932)],
#  [('mean', 312)],
#  [('follicular', 35)],
#  [('dite', 174)],
#  [('fifpro', 291)],
#  [('httpstcopdoheao9w6', 443)],
#  [('threat', 112), ('threat', 746)],
#  [('serait', 602)],
#  [('the', 13),
#   ('the', 13),
#   ('the', 13),
#   ('the', 14),
#   ('the', 27),
#   ('the', 27),
#   ('the', 27),
#   ('the', 31),
#   ('the', 31),
#   ('the', 32),
#   ('the', 33),
#   ('the', 40),
#   ('the', 41),
#   ('the', 44),
#   ('the', 57),
#   ('the', 60),
#   ('the', 65),
#   ('the', 65),
#   ('the', 69),
#   ('the', 71),
#   ('the', 77),
#   ('the', 80),
#   ('the', 80),
#   ('the', 80),
#   ('the', 84),
#   ('the', 87),
#   ('the', 89),
#   ('the', 95),
#   ('the', 95),
#   ('the', 95),
#   ('the', 98),
#   ('the', 98),
#   ('the', 101),
#   ('the', 103),
#   ('the', 103),
#   ('the', 104),
#   ('the', 106),
#   ('the', 108),
#   ('the', 108),
#   ('the', 108),
#   ('the', 109),
#   ('the', 121),
#   ('the', 124),
#   ('the', 125),
#   ('the', 126),
#   ('the', 126),
#   ('the', 126),
#   ('the', 134),
#   ('the', 135),
#   ('the', 136),
#   ('the', 137),
#   ('the', 139),
#   ('the', 139),
#   ('the', 141),
#   ('the', 141),
#   ('the', 148),
#   ('the', 150),
#   ('the', 150),
#   ('the', 150),
#   ('the', 154),
#   ('the', 158),
#   ('the', 158),
#   ('the', 164),
#   ('the', 175),
#   ('the', 175),
#   ('the', 178),
#   ('the', 180),
#   ('the', 180),
#   ('the', 187),
#   ('the', 187),
#   ('the', 189),
#   ('the', 191),
#   ('the', 191),
#   ('the', 195),
#   ('the', 196),
#   ('the', 203),
#   ('the', 212),
#   ('the', 215),
#   ('the', 218),
#   ('the', 221),
#   ('the', 223),
#   ('the', 223),
#   ('the', 225),
#   ('the', 228),
#   ('the', 230),
#   ('the', 232),
#   ('the', 232),
#   ('the', 236),
#   ('the', 237),
#   ('the', 237),
#   ('the', 245),
#   ('the', 245),
#   ('the', 245),
#   ('the', 254),
#   ('the', 255),
#   ('the', 257),
#   ('the', 257),
#   ('the', 260),
#   ('the', 264),
#   ('the', 269),
#   ('the', 270),
#   ('the', 272),
#   ('the', 272),
#   ('the', 275),
#   ('the', 276),
#   ('the', 278),
#   ('the', 278),
#   ('the', 288),
#   ('the', 290),
#   ('the', 293),
#   ('the', 294),
#   ('the', 295),
#   ('the', 296),
#   ('the', 298),
#   ('the', 301),
#   ('the', 301),
#   ('the', 303),
#   ('the', 306),
#   ('the', 306),
#   ('the', 310),
#   ('the', 312),
#   ('the', 328),
#   ('the', 334),
#   ('the', 339),
#   ('the', 339),
#   ('the', 341),
#   ('the', 341),
#   ('the', 343),
#   ('the', 346),
#   ('the', 364),
#   ('the', 364),
#   ('the', 375),
#   ('the', 375),
#   ('the', 380),
#   ('the', 381),
#   ('the', 386),
#   ('the', 390),
#   ('the', 390),
#   ('the', 393),
#   ('the', 393),
#   ('the', 400),
#   ('the', 407),
#   ('the', 407),
#   ('the', 409),
#   ('the', 410),
#   ('the', 410),
#   ('the', 411),
#   ('the', 412),
#   ('the', 413),
#   ('the', 413),
#   ('the', 416),
#   ('the', 418),
#   ('the', 419),
#   ('the', 419),
#   ('the', 422),
#   ('the', 427),
#   ('the', 428),
#   ('the', 434),
#   ('the', 435),
#   ('the', 441),
#   ('the', 444),
#   ('the', 447),
#   ('the', 449),
#   ('the', 455),
#   ('the', 455),
#   ('the', 457),
#   ('the', 459),
#   ('the', 459),
#   ('the', 460),
#   ('the', 461),
#   ('the', 464),
#   ('the', 464),
#   ('the', 466),
#   ('the', 468),
#   ('the', 469),
#   ('the', 474),
#   ('the', 480),
#   ('the', 481),
#   ('the', 485),
#   ('the', 485),
#   ('the', 485),
#   ('the', 486),
#   ('the', 487),
#   ('the', 491),
#   ('the', 496),
#   ('the', 497),
#   ('the', 499),
#   ('the', 501),
#   ('the', 502),
#   ('the', 504),
#   ('the', 504),
#   ('the', 506),
#   ('the', 512),
#   ('the', 512),
#   ('the', 512),
#   ('the', 512),
#   ('the', 513),
#   ('the', 519),
#   ('the', 527),
#   ('the', 531),
#   ('the', 533),
#   ('the', 533),
#   ('the', 534),
#   ('the', 536),
#   ('the', 537),
#   ('the', 541),
#   ('the', 547),
#   ('the', 550),
#   ('the', 552),
#   ('the', 557),
#   ('the', 559),
#   ('the', 560),
#   ('the', 562),
#   ('the', 563),
#   ('the', 564),
#   ('the', 572),
#   ('the', 572),
#   ('the', 573),
#   ('the', 575),
#   ('the', 575),
#   ('the', 575),
#   ('the', 577),
#   ('the', 579),
#   ('the', 586),
#   ('the', 589),
#   ('the', 589),
#   ('the', 591),
#   ('the', 594),
#   ('the', 597),
#   ('the', 598),
#   ('the', 600),
#   ('the', 601),
#   ('the', 601),
#   ('the', 601),
#   ('the', 601),
#   ('the', 605),
#   ('the', 606),
#   ('the', 607),
#   ('the', 607),
#   ('the', 612),
#   ('the', 613),
#   ('the', 614),
#   ('the', 620),
#   ('the', 622),
#   ('the', 623),
#   ('the', 624),
#   ('the', 624),
#   ('the', 626),
#   ('the', 629),
#   ('the', 632),
#   ('the', 634),
#   ('the', 639),
#   ('the', 640),
#   ('the', 641),
#   ('the', 641),
#   ('the', 643),
#   ('the', 645),
#   ('the', 646),
#   ('the', 649),
#   ('the', 655),
#   ('the', 655),
#   ('the', 656),
#   ('the', 667),
#   ('the', 669),
#   ('the', 669),
#   ('the', 669),
#   ('the', 671),
#   ('the', 671),
#   ('the', 672),
#   ('the', 674),
#   ('the', 677),
#   ('the', 679),
#   ('the', 685),
#   ('the', 686),
#   ('the', 688),
#   ('the', 691),
#   ('the', 696),
#   ('the', 697),
#   ('the', 698),
#   ('the', 699),
#   ('the', 699),
#   ('the', 703),
#   ('the', 703),
#   ('the', 703),
#   ('the', 704),
#   ('the', 704),
#   ('the', 711),
#   ('the', 718),
#   ('the', 719),
#   ('the', 724),
#   ('the', 724),
#   ('the', 724),
#   ('the', 725),
#   ('the', 726),
#   ('the', 730),
#   ('the', 732),
#   ('the', 736),
#   ('the', 736),
#   ('the', 741),
#   ('the', 741),
#   ('the', 743),
#   ('the', 746),
#   ('the', 747),
#   ('the', 747),
#   ('the', 748),
#   ('the', 748),
#   ('the', 749),
#   ('the', 755),
#   ('the', 759),
#   ('the', 759),
#   ('the', 759),
#   ('the', 760),
#   ('the', 760),
#   ('the', 762),
#   ('the', 762),
#   ('the', 762),
#   ('the', 767),
#   ('the', 767),
#   ('the', 770),
#   ('the', 770),
#   ('the', 776),
#   ('the', 776),
#   ('the', 778),
#   ('the', 786),
#   ('the', 787),
#   ('the', 787),
#   ('the', 790),
#   ('the', 790),
#   ('the', 804),
#   ('the', 804),
#   ('the', 807),
#   ('the', 808),
#   ('the', 817),
#   ('the', 818),
#   ('the', 830),
#   ('the', 831),
#   ('the', 846),
#   ('the', 850),
#   ('the', 858),
#   ('the', 859),
#   ('the', 863),
#   ('the', 865),
#   ('the', 865),
#   ('the', 868),
#   ('the', 871),
#   ('the', 873),
#   ('the', 875),
#   ('the', 878),
#   ('the', 883),
#   ('the', 884),
#   ('the', 887),
#   ('the', 898),
#   ('the', 899),
#   ('the', 903),
#   ('the', 905),
#   ('the', 908),
#   ('the', 910),
#   ('the', 917),
#   ('the', 918),
#   ('the', 919),
#   ('the', 931),
#   ('the', 934),
#   ('the', 936),
#   ('the', 937),
#   ('the', 938),
#   ('the', 938),
#   ('the', 943),
#   ('the', 944),
#   ('the', 948),
#   ('the', 950),
#   ('the', 950),
#   ('the', 950),
#   ('the', 952),
#   ('the', 957),
#   ('the', 959),
#   ('the', 963),
#   ('the', 965),
#   ('the', 971),
#   ('the', 973),
#   ('the', 979),
#   ('the', 981),
#   ('the', 984),
#   ('the', 987),
#   ('the', 990),
#   ('the', 991),
#   ('the', 992),
#   ('the', 995),
#   ('the', 999),
#   ('the', 1003),
#   ('the', 1003),
#   ('the', 1005),
#   ('the', 1008),
#   ('the', 1012),
#   ('the', 1013),
#   ('the', 1013),
#   ('the', 1014),
#   ('the', 1032),
#   ('the', 1056),
#   ('the', 1056),
#   ('the', 1060)],
#  [('jchenal', 976), ('jchenal', 977), ('jchenal', 1010)],
#  [('urbain', 463), ('urbain', 463), ('urbain', 967)],
#  [('rencart', 462)],
#  [('jour', 402), ('jour', 894), ('jour', 989), ('jour', 1066)],
#  [('httpstcozyenraseir', 5)],
#  [('httpstcoqeimkjiqyy', 534)],
#  [('treatment', 166), ('treatment', 547)],
#  [('overhead', 909)],
#  [('7047', 161)],
#  [('liker', 366)],
#  [('bâtiment', 644), ('bâtiment', 1023), ('bâtiment', 1070)],
#  [('nucleosom', 66), ('nucleosom', 66)],
#  [('400k', 1014)],
#  [('httpstconjovod2dsn', 243)],
#  [('httpstcozfksmvxap5', 384)],
#  [('wpcapit', 399)],
#  [('siraganyan', 608)],
#  [('fab', 916)],
#  [('recogn', 547)],
#  [('être', 283)],
#  [('led', 938)],
#  [('rue', 383)],
#  [('marcelsalath', 21),
#   ('marcelsalath', 50),
#   ('marcelsalath', 58),
#   ('marcelsalath', 65),
#   ('marcelsalath', 158),
#   ('marcelsalath', 181),
#   ('marcelsalath', 312),
#   ('marcelsalath', 580),
#   ('marcelsalath', 581),
#   ('marcelsalath', 656),
#   ('marcelsalath', 722),
#   ('marcelsalath', 797),
#   ('marcelsalath', 938)],
#  [('psw', 916)],
#  [('tablet', 435), ('tablet', 533)],
#  [('httpstcokbmt3ojtnm', 360)],
#  [('mélodi', 942)],
#  [('lire', 70), ('lire', 351)],
#  [('progenitor', 734)],
#  [('httpstco7p7b964hq3', 302)],
#  [('porto', 306)],
#  [('œuvr', 456)],
#  [('de', 11),
#   ('de', 11),
#   ('de', 12),
#   ('de', 12),
#   ('de', 12),
#   ('de', 16),
#   ('de', 20),
#   ('de', 43),
#   ('de', 47),
#   ('de', 51),
#   ('de', 56),
#   ('de', 63),
#   ('de', 63),
#   ('de', 70),
#   ('de', 70),
#   ('de', 70),
#   ('de', 81),
#   ('de', 93),
#   ('de', 94),
#   ('de', 94),
#   ('de', 94),
#   ('de', 98),
#   ('de', 118),
#   ('de', 129),
#   ('de', 149),
#   ('de', 149),
#   ('de', 157),
#   ('de', 161),
#   ('de', 167),
#   ('de', 168),
#   ('de', 172),
#   ('de', 181),
#   ('de', 197),
#   ('de', 197),
#   ('de', 207),
#   ('de', 207),
#   ('de', 207),
#   ('de', 207),
#   ('de', 207),
#   ('de', 207),
#   ('de', 251),
#   ('de', 252),
#   ('de', 252),
#   ('de', 265),
#   ('de', 265),
#   ('de', 266),
#   ('de', 266),
#   ('de', 268),
#   ('de', 279),
#   ('de', 287),
#   ('de', 297),
#   ('de', 302),
#   ('de', 311),
#   ('de', 311),
#   ('de', 325),
#   ('de', 325),
#   ('de', 325),
#   ('de', 327),
#   ('de', 342),
#   ('de', 345),
#   ('de', 357),
#   ('de', 357),
#   ('de', 362),
#   ('de', 383),
#   ('de', 383),
#   ('de', 383),
#   ('de', 383),
#   ('de', 388),
#   ('de', 403),
#   ('de', 403),
#   ('de', 404),
#   ('de', 417),
#   ('de', 439),
#   ('de', 439),
#   ('de', 452),
#   ('de', 456),
#   ('de', 463),
#   ('de', 463),
#   ('de', 463),
#   ('de', 463),
#   ('de', 467),
#   ('de', 520),
#   ('de', 523),
#   ('de', 523),
#   ('de', 526),
#   ('de', 543),
#   ('de', 548),
#   ('de', 565),
#   ('de', 565),
#   ('de', 566),
#   ('de', 567),
#   ('de', 567),
#   ('de', 568),
#   ('de', 569),
#   ('de', 574),
#   ('de', 584),
#   ('de', 584),
#   ('de', 584),
#   ('de', 592),
#   ('de', 599),
#   ('de', 599),
#   ('de', 602),
#   ('de', 603),
#   ('de', 604),
#   ('de', 604),
#   ('de', 610),
#   ('de', 618),
#   ('de', 627),
#   ('de', 627),
#   ('de', 636),
#   ('de', 644),
#   ('de', 644),
#   ('de', 644),
#   ('de', 651),
#   ('de', 665),
#   ('de', 665),
#   ('de', 682),
#   ('de', 687),
#   ('de', 687),
#   ('de', 702),
#   ('de', 705),
#   ('de', 710),
#   ('de', 710),
#   ('de', 710),
#   ('de', 729),
#   ('de', 740),
#   ('de', 740),
#   ('de', 742),
#   ('de', 744),
#   ('de', 744),
#   ('de', 752),
#   ('de', 780),
#   ('de', 782),
#   ('de', 783),
#   ('de', 788),
#   ('de', 800),
#   ('de', 803),
#   ('de', 821),
#   ('de', 824),
#   ('de', 825),
#   ('de', 825),
#   ('de', 829),
#   ('de', 837),
#   ('de', 841),
#   ('de', 842),
#   ('de', 844),
#   ('de', 844),
#   ('de', 857),
#   ('de', 857),
#   ('de', 857),
#   ('de', 862),
#   ('de', 862),
#   ('de', 862),
#   ('de', 862),
#   ('de', 874),
#   ('de', 876),
#   ('de', 882),
#   ('de', 894),
#   ('de', 894),
#   ('de', 895),
#   ('de', 900),
#   ('de', 900),
#   ('de', 901),
#   ('de', 902),
#   ('de', 902),
#   ('de', 902),
#   ('de', 923),
#   ('de', 924),
#   ('de', 925),
#   ('de', 925),
#   ('de', 929),
#   ('de', 939),
#   ('de', 942),
#   ('de', 947),
#   ('de', 947),
#   ('de', 947),
#   ('de', 958),
#   ('de', 961),
#   ('de', 961),
#   ('de', 967),
#   ('de', 978),
#   ('de', 978),
#   ('de', 988),
#   ('de', 989),
#   ('de', 993),
#   ('de', 993),
#   ('de', 1016),
#   ('de', 1016),
#   ('de', 1018),
#   ('de', 1020),
#   ('de', 1022),
#   ('de', 1022),
#   ('de', 1023),
#   ('de', 1025),
#   ('de', 1030),
#   ('de', 1030),
#   ('de', 1031),
#   ('de', 1035),
#   ('de', 1037),
#   ('de', 1037),
#   ('de', 1039),
#   ('de', 1039),
#   ('de', 1039),
#   ('de', 1040),
#   ('de', 1042),
#   ('de', 1047),
#   ('de', 1049),
#   ('de', 1049),
#   ('de', 1050),
#   ('de', 1051),
#   ('de', 1051),
#   ('de', 1052),
#   ('de', 1062),
#   ('de', 1063),
#   ('de', 1066),
#   ('de', 1066),
#   ('de', 1067),
#   ('de', 1068),
#   ('de', 1069),
#   ('de', 1069),
#   ('de', 1069)],
#  [('timeseri', 34), ('timeseri', 34)],
#  [('catharuçia', 70)],
#  [('psncnewslightbox', 428)],
#  [('timeshigh', 121),
#   ('timeshigh', 139),
#   ('timeshigh', 319),
#   ('timeshigh', 934)],
#  [('lhumanité', 602)],
#  [('ultratom', 109)],
#  [('pattaroni', 1069)],
#  [('sequenc', 34)],
#  [('concret', 304), ('concret', 883), ('concret', 884)],
#  [('resolv', 589)],
#  [('highlights1112', 438)],
#  [('compar', 221), ('compar', 413)],
#  [('httpstcoc9c96wee6b', 106)],
#  [('nombreus', 279)],
#  [('httpstcokrppxbgqqk', 537)],
#  [('decemb', 339), ('decemb', 441)],
#  [('httpstcoty35u7vfah', 712)],
#  [('httpstcoeek6g1vnm5', 970)],
#  [('httpstcoixkk2ofku', 388)],
#  [('readtoreef', 814)],
#  [('anticanc', 211)],
#  [('date', 339), ('date', 441), ('date', 464), ('date', 887), ('date', 1060)],
#  [('httpstcokcwnh9i9sf', 396)],
#  [('worldlead', 135)],
#  [('geissbuhl', 357)],
#  [('httpstcoznjk3bz6mo', 838)],
#  [('httpstcoyaklj6rwyz', 887)],
#  [('httpstcofdi5yz2a6m', 847)],
#  [('move', 556)],
#  [('jure', 557)],
#  [('indian', 15)],
#  [('swissborg', 19)],
#  [('introductori', 34)],
#  [('eye', 91), ('eye', 447)],
#  [('httpstcoponztf3vft', 778)],
#  [('geographemedecin', 437)],
#  [('ppurtweet', 710)],
#  [('scalalang', 370), ('scalalang', 409)],
#  [('ambiant', 283)],
#  [('“', 18),
#   ('“', 69),
#   ('“', 103),
#   ('“', 166),
#   ('“', 212),
#   ('“', 260),
#   ('“', 292),
#   ('“', 393),
#   ('“', 497),
#   ('“', 504),
#   ('“', 863),
#   ('“', 985)],
#  [('💡👉httpstcogz0y5vtrij', 99)],
#  [('languag', 792)],
#  [('supercrit', 769)],
#  [('httpstcoslz0pbxvi', 1029)],
#  [('manufactur', 375)],
#  [('la2024', 1042)],
#  [('gehendragurung', 350)],
#  [('6', 90), ('6', 175), ('6', 272), ('6', 767), ('6', 975)],
#  [('beltandroad', 639)],
#  [('aprè', 277),
#   ('aprè', 665),
#   ('aprè', 705),
#   ('aprè', 752),
#   ('aprè', 900),
#   ('aprè', 1037)],
#  [('moyen', 520)],
#  [('mendeleïev', 311)],
#  [('directli', 30), ('directli', 44)],
#  [('politonew', 196), ('politonew', 639)],
#  [('asemday', 270)],
#  [('sec', 492)],
#  [('httpstcoxwvnxyfunq', 134)],
#  [('casestudi', 955)],
#  [('vleaderstech', 399)],
#  [('httpstcoqot0l2xucd', 374)],
#  [('impact', 144),
#   ('impact', 166),
#   ('impact', 280),
#   ('impact', 342),
#   ('impact', 672),
#   ('impact', 986),
#   ('impact', 1023)],
#  [('grandformat', 552)],
#  [('httpstcotw6q3kan5q', 571)],
#  [('reflex', 993)],
#  [('tech4dev', 1007)],
#  [('alp', 150), ('alp', 150)],
#  [('cern', 210), ('cern', 541), ('cern', 594), ('cern', 874)],
#  [('seedstarssummit', 951)],
#  [('httpstco9f2iuduopr', 1008)],
#  [('landscap', 126), ('landscap', 525)],
#  [('httpstcozg9e18bg21', 893)],
#  [('evangelist', 747)],
#  [('mountain', 358), ('mountain', 526), ('mountain', 836)],
#  [('me', 59),
#   ('me', 85),
#   ('me', 88),
#   ('me', 104),
#   ('me', 240),
#   ('me', 411),
#   ('me', 735),
#   ('me', 764),
#   ('me', 790),
#   ('me', 910),
#   ('me', 938),
#   ('me', 938),
#   ('me', 987),
#   ('me', 1044)],
#  [('april', 30), ('april', 479), ('april', 642), ('april', 990)],
#  [('see', 30),
#   ('see', 95),
#   ('see', 106),
#   ('see', 114),
#   ('see', 156),
#   ('see', 313),
#   ('see', 367),
#   ('see', 387),
#   ('see', 426),
#   ('see', 428),
#   ('see', 482),
#   ('see', 509),
#   ('see', 555),
#   ('see', 589),
#   ('see', 612),
#   ('see', 671),
#   ('see', 813),
#   ('see', 907),
#   ('see', 934),
#   ('see', 963),
#   ('see', 973)],
#  [('10pm', 655)],
#  [('httpstcojosupjdg7k', 14)],
#  [('p', 85), ('p', 224)],
#  [('universel', 602)],
#  [('titlelength', 280)],
#  [('emp', 611)],
#  [('univantil', 554)],
#  [('httpstcoxng9dhji4', 39)],
#  [('🇨🇭', 241), ('🇨🇭', 382)],
#  [('httpstcoh3jz6pjmta', 544)],
#  [('listen', 21)],
#  [('flowecommerc', 427)],
#  [('itfa', 294), ('itfa', 468)],
#  [('httpstcomhp3nbjn9', 379)],
#  [('hauss', 900)],
#  [('profession', 291)],
#  [('dédié', 261), ('dédié', 297)],
#  [('lexpertis', 439)],
#  [('bruno', 809), ('bruno', 1068)],
#  [('11am', 31)],
#  [('►', 647)],
#  [('recruit', 323), ('recruit', 938)],
#  [('capac', 126)],
#  [('babi', 514)],
#  [('httpstcos6vtp56sbr', 1046)],
#  [('hwurcc', 575)],
#  [('httpstcolmdqyovvl9', 53)],
#  [('rampd', 71)],
#  [('esr', 931)],
#  [('prepar', 343)],
#  [('celui', 862)],
#  [('reli', 1012)],
#  [('françou', 535)],
#  [('oscienc', 24),
#   ('oscienc', 67),
#   ('oscienc', 111),
#   ('oscienc', 153),
#   ('oscienc', 328),
#   ('oscienc', 355),
#   ('oscienc', 527),
#   ('oscienc', 811),
#   ('oscienc', 932)],
#  [('sa', 202), ('sa', 627)],
#  [('httpstcod7efdxo4mp', 575)],
#  [('martialart', 715)],
#  [('lch', 400)],
#  [('spot', 941)],
#  [('savonario', 70)],
#  [('scicommfilmhack', 420)],
#  [('teamwork', 955)],
#  [('httpstcoo5ido16day', 492)],
#  [('httpstcod7slk6ruat', 742)],
#  [('new', 13),
#   ('new', 30),
#   ('new', 60),
#   ('new', 68),
#   ('new', 69),
#   ('new', 73),
#   ('new', 79),
#   ('new', 110),
#   ('new', 117),
#   ('new', 126),
#   ('new', 148),
#   ('new', 158),
#   ('new', 164),
#   ('new', 177),
#   ('new', 184),
#   ('new', 191),
#   ('new', 201),
#   ('new', 257),
#   ('new', 263),
#   ('new', 291),
#   ('new', 317),
#   ('new', 332),
#   ('new', 341),
#   ('new', 343),
#   ('new', 354),
#   ('new', 377),
#   ('new', 398),
#   ('new', 415),
#   ('new', 446),
#   ('new', 479),
#   ('new', 504),
#   ('new', 504),
#   ('new', 525),
#   ('new', 551),
#   ('new', 562),
#   ('new', 595),
#   ('new', 606),
#   ('new', 625),
#   ('new', 669),
#   ('new', 673),
#   ('new', 677),
#   ('new', 680),
#   ('new', 684),
#   ('new', 694),
#   ('new', 703),
#   ('new', 719),
#   ('new', 732),
#   ('new', 738),
#   ('new', 750),
#   ('new', 753),
#   ('new', 779),
#   ('new', 793),
#   ('new', 795),
#   ('new', 798),
#   ('new', 820),
#   ('new', 831),
#   ('new', 838),
#   ('new', 839),
#   ('new', 871),
#   ('new', 959),
#   ('new', 986),
#   ('new', 1033)],
#  [('swissnexsf', 215),
#   ('swissnexsf', 241),
#   ('swissnexsf', 247),
#   ('swissnexsf', 313),
#   ('swissnexsf', 963)],
#  [('scirobot', 17)],
#  [('handi', 845)],
#  [('2018hpeworkshop', 611)],
#  [('détendr', 277)],
#  [('vélostat', 81)],
#  [('alway', 689)],
#  [('httpstcoel8rjs7wc1', 766)],
#  [('roi', 98)],
#  [('epfllts5', 855)],
#  [('epflalumnigala', 255), ('epflalumnigala', 310)],
#  [('impost', 249), ('impost', 414)],
#  [('virtualis', 909)],
#  [('whose', 979)],
#  [('flyerlft', 375)],
#  [('dahl', 1053)],
#  [('httpstcoumgkc3ot0d', 973)],
#  [('httpstconum7njo85j', 450)],
#  [('stromtanken', 1011)],
#  [('mpagran', 659), ('mpagran', 740)],
#  [('thereof', 166)],
#  [('go', 323),
#   ('go', 347),
#   ('go', 430),
#   ('go', 471),
#   ('go', 525),
#   ('go', 542),
#   ('go', 572),
#   ('go', 772),
#   ('go', 981),
#   ('go', 999),
#   ('go', 1006),
#   ('go', 1036)],
#  [('kudo', 189)],
#  [('httpstcotmtdstsjzh', 271)],
#  [('alexalahi', 104), ('alexalahi', 292)],
#  [('1030', 257)],
#  [('laboratoir', 123), ('laboratoir', 129)],
#  [('swisscomm', 212)],
#  [('travaux', 207), ('travaux', 961), ('travaux', 1039)],
#  [('assa2018', 294), ('assa2018', 468)],
#  [('httpstcoi5lwefylxm', 914)],
#  [('theme', 669)],
#  [('entrepreneuri', 910)],
#  [('1200', 33)],
#  [('s', 13),
#   ('s', 44),
#   ('s', 58),
#   ('s', 58),
#   ('s', 104),
#   ('s', 114),
#   ('s', 152),
#   ('s', 248),
#   ('s', 292),
#   ('s', 337),
#   ('s', 473),
#   ('s', 517),
#   ('s', 532),
#   ('s', 589),
#   ('s', 592),
#   ('s', 630),
#   ('s', 684),
#   ('s', 755),
#   ('s', 770),
#   ('s', 770),
#   ('s', 817),
#   ('s', 849),
#   ('s', 849),
#   ('s', 853),
#   ('s', 935),
#   ('s', 968),
#   ('s', 975)],
#  [('pourriez', 1039)],
#  [('these', 85),
#   ('these', 116),
#   ('these', 269),
#   ('these', 323),
#   ('these', 414),
#   ('these', 511),
#   ('these', 641),
#   ('these', 859)],
#  [('zusammenarbeit', 425)],
#  [('campusbiotech', 181), ('campusbiotech', 708)],
#  [('httpstcoscmuhk60vn', 611)],
#  [('httpstcomsnlgmpaol', 246)],
#  [('ever', 178),
#   ('ever', 328),
#   ('ever', 407),
#   ('ever', 527),
#   ('ever', 608),
#   ('ever', 908)],
#  [('swissquotenew', 825)],
#  [('httpstcoipc3bfdrsl', 824)],
#  [('campus…', 326)],
#  [('checkpoint', 349)],
#  [('shape', 135)],
#  [('httpstcojz7tpghojn', 771)],
#  [('mauricelibrarysecur', 325),
#   ('mauricelibrarysecur', 345),
#   ('mauricelibrarysecur', 860)],
#  [('corefacil', 98), ('corefacil', 203)],
#  [('présentera', 569)],
#  [('v', 297), ('v', 913)],
#  [('—', 260)],
#  [('pari', 467), ('pari', 479), ('pari', 710)],
#  [('httpstcostnysj1cx', 694)],
#  [('httpstcocqa8fqwqqg', 619)],
#  [('expériment', 456), ('expériment', 627)],
#  [('haptic', 102), ('haptic', 102)],
#  [('eurekalert', 211),
#   ('eurekalert', 524),
#   ('eurekalert', 833),
#   ('eurekalert', 966)],
#  [('rarediseas', 948)],
#  [('beer', 416), ('beer', 416)],
#  [('finish', 540)],
#  [('httpstco8hh2xacpdn', 139)],
#  [('partagé', 304)],
#  [('bühler', 323)],
#  [('french', 150),
#   ('french', 185),
#   ('french', 286),
#   ('french', 492),
#   ('french', 682),
#   ('french', 702),
#   ('french', 905)],
#  [('portivechju', 207), ('portivechju', 989)],
#  [('late', 490), ('late', 500)],
#  [('httpstcokbirk356nn', 150), ('httpstcokbirk356nn', 185)],
#  [('🇨🇭merci', 26)],
#  [('passion', 143)],
#  [('seguinb', 316)],
#  [('stabilité', 900)],
#  [('httpstcor5vbp61wqi', 739)],
#  [('inriabordeaux', 554)],
#  [('villar', 601)],
#  [('tomograph', 446)],
#  [('mblokesch', 513)],
#  [('propr', 1039)],
#  [('gafa', 921)],
#  [('professorship', 850)],
#  [('zizi', 988)],
#  [('long', 26), ('long', 246), ('long', 948), ('long', 1012)],
#  [('httpstcogyclie4vhl', 1054)],
#  [('httpstcok6brnizpdi', 786)],
#  [('httpstcompplaahj3x', 1056)],
#  [('link', 732)],
#  [('häuschen', 451)],
#  [('microstructur', 544), ('microstructur', 1000)],
#  [('mindfram', 768)],
#  [('drop', 98), ('drop', 141)],
#  [('disgrac', 281)],
#  [('heigvd', 200)],
#  [('httpstcomvsvcwdtxb', 768)],
#  [('martelinnov', 263), ('martelinnov', 391)],
#  [('wo', 438)],
#  [('numériqu', 202),
#   ('numériqu', 243),
#   ('numériqu', 382),
#   ('numériqu', 565),
#   ('numériqu', 723),
#   ('numériqu', 958),
#   ('numériqu', 958),
#   ('numériqu', 1024)],
#  [('brilliant', 613)],
#  [('idsia', 905)],
#  [('societi', 65),
#   ('societi', 238),
#   ('societi', 312),
#   ('societi', 589),
#   ('societi', 672)],
#  [('we', 60),
#   ('we', 65),
#   ('we', 65),
#   ('we', 78),
#   ('we', 98),
#   ('we', 108),
#   ('we', 134),
#   ('we', 134),
#   ('we', 191),
#   ('we', 203),
#   ('we', 221),
#   ('we', 223),
#   ('we', 247),
#   ('we', 264),
#   ('we', 281),
#   ('we', 307),
#   ('we', 333),
#   ('we', 346),
#   ('we', 353),
#   ('we', 414),
#   ('we', 445),
#   ('we', 572),
#   ('we', 580),
#   ('we', 601),
#   ('we', 671),
#   ('we', 703),
#   ('we', 760),
#   ('we', 802),
#   ('we', 863),
#   ('we', 886),
#   ('we', 909),
#   ('we', 935),
#   ('we', 963),
#   ('we', 1013),
#   ('we', 1046),
#   ('we', 1065)],
#  [('httpstcohrow4kecko', 858)],
#  [('daccord', 356)],
#  [('httpstco7g2w1geiz9', 860)],
#  [('he', 126)],
#  [('veuillez', 988)],
#  [('commeric', 628)],
#  [('summerschool', 196)],
#  [('évaluat', 167), ('évaluat', 252)],
#  [('schleiss', 400), ('schleiss', 823), ('schleiss', 1067)],
#  [('httpstcow1djd9yzkm', 715)],
#  [('electricvehicl', 642)],
#  [('winter', 368), ('winter', 749), ('winter', 963)],
#  [('entr', 304), ('entr', 304), ('entr', 345), ('entr', 925)],
#  [('epflev', 191),
#   ('epflev', 238),
#   ('epflev', 258),
#   ('epflev', 265),
#   ('epflev', 309),
#   ('epflev', 506),
#   ('epflev', 528),
#   ('epflev', 635),
#   ('epflev', 707),
#   ('epflev', 846)],
#  [('dfloreano', 905)],
#  [('wirkung', 49)],
#  [('flaviacorda', 530)],
#  [('meteolak', 766)],
#  [('japan', 144), ('japan', 342), ('japan', 715)],
#  [('confess', 122)],
#  [('australia', 278)],
#  [('hp1a', 66), ('hp1a', 959)],
#  [('nachhaltig', 721)],
#  [('erstmal', 638)],
#  [('httpstcor3t1sszogo', 564)],
#  [('while', 938), ('while', 960)],
#  [('monday', 635)],
#  [('moyenag', 1054)],
#  [('cheesecak', 253)],
#  [('camp', 619), ('camp', 906), ('camp', 963)],
#  [('ocean', 119)],
#  [('vertrauen', 384)],
#  [('httpstcoxzqq8zekqj', 729)],
#  [('😍', 764)],
#  [('term', 26), ('term', 1012), ('term', 1031)],
#  [('enorm', 158)],
#  [('vscocam', 326)],
#  [('asilomar', 459)],
#  [('httpstcoxivngafghi', 871)],
#  [('georgio', 1027)],
#  [('mpicbg', 638), ('mpicbg', 745)],
#  [('introduc', 407)],
#  [('génétiqu', 266), ('génétiqu', 783)],
#  [('check', 691), ('check', 776), ('check', 959)],
#  [('class', 383), ('class', 429), ('class', 882)],
#  [('tomorrow', 68),
#   ('tomorrow', 72),
#   ('tomorrow', 91),
#   ('tomorrow', 156),
#   ('tomorrow', 301),
#   ('tomorrow', 503),
#   ('tomorrow', 513),
#   ('tomorrow', 656),
#   ('tomorrow', 743),
#   ('tomorrow', 760),
#   ('tomorrow', 772)],
#  [('25042017', 441)],
#  [('httpstcoqgwo4mcpjt', 754)],
#  [('72', 122), ('72', 301), ('72', 707), ('72', 742)],
#  [('leur', 56),
#   ('leur', 244),
#   ('leur', 417),
#   ('leur', 683),
#   ('leur', 1010),
#   ('leur', 1021),
#   ('leur', 1047)],
#  [('subscrib', 637)],
#  [('swisscomb2ben', 399)],
#  [('tou', 63), ('tou', 168), ('tou', 860), ('tou', 988)],
#  [('👌🏻', 1032)],
#  [('philipp', 162), ('philipp', 213), ('philipp', 479)],
#  [('avc', 43)],
#  [('pr', 739)],
#  [('personifi', 50)],
#  ...]

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('intens', 1, [714]),
#  ('httpstcoblwafqtopd', 1, [694]),
#  ('vou',
#   19,
#   [144,
#    174,
#    197,
#    265,
#    277,
#    325,
#    342,
#    345,
#    402,
#    467,
#    467,
#    659,
#    665,
#    860,
#    920,
#    988,
#    1030,
#    1039,
#    1066]),
#  ('hazard', 2, [185, 526]),
#  ('bien', 7, [12, 26, 81, 610, 627, 927, 939]),
#  ('giraulthubert', 2, [275, 1013]),
#  ('😷😝', 1, [919]),
#  ('ist', 3, [105, 167, 319]),
#  ('nice', 7, [22, 100, 234, 372, 591, 808, 1036]),
#  ('walli', 2, [185, 743]),
#  ('editionslavolt', 1, [472]),
#  ('maxconf2018', 2, [545, 663]),
#  ('climatiqu', 1, [962]),
#  ('httpstcozwtkplh6ht', 1, [420]),
#  ('massiv', 1, [515]),
#  ('swim', 1, [1008]),
#  ('httpstcoqgyot0yvzn', 1, [545]),
#  ('jattali', 1, [827]),
#  ('harvard', 1, [359]),
#  ('presid', 12, [10, 330, 360, 390, 477, 579, 762, 779, 819, 863, 875, 974]),
#  ('cciliv', 3, [80, 100, 685]),
#  ('httpstcoli5nturtjh', 1, [596]),
#  ('digitalhealth', 4, [84, 181, 514, 588]),
#  ('teach', 3, [231, 413, 999]),
#  ('hydropow', 1, [271]),
#  ('shametortur', 1, [278]),
#  ('zuerich', 1, [1011]),
#  ('écomorphologiqu', 2, [167, 252]),
#  ('a…', 1, [426]),
#  ('httpstcotmtdstsjzh', 1, [271]),
#  ('norman', 1, [1061]),
#  ('loan', 1, [53]),
#  ('partner', 6, [106, 196, 212, 522, 775, 1072]),
#  ('srg', 1, [144]),
#  ('duré', 1, [266]),
#  ('sunris', 1, [749]),
#  ('httpstcotlieahzlsd', 1, [232]),
#  ('cosmoorbu', 1, [472]),
#  ('10h', 1, [243]),
#  ('cio', 2, [1037, 1042]),
#  ('httpstcoegweg4aqj4', 1, [724]),
#  ('httpstcot9imltiuel', 1, [476]),
#  ('httpstcon2e6p5luuw', 1, [927]),
#  ('10pm', 1, [655]),
#  ('eusciencehub', 1, [71]),
#  ('cesmichigan', 2, [294, 468]),
#  ('📸🦈💦', 1, [325]),
#  ('realdonaldtrump', 2, [620, 813]),
#  ('campusday', 1, [721]),
#  ('httpstcokbirk356nn', 2, [150, 185]),
#  ('thymio', 1, [382]),
#  ('daylightsymposium', 1, [376]),
#  ('johan', 1, [532]),
#  ('mang', 1, [927]),
#  ('httpstcobdowqoqx', 1, [308]),
#  ('irrespect', 1, [1044]),
#  ('drug', 3, [211, 284, 577]),
#  ('solarenergi', 1, [217]),
#  ('lc3technolog', 1, [748]),
#  ('releas', 1, [60]),
#  ('franceia', 1, [118]),
#  ('magnifiqu', 1, [1020]),
#  ('httpstcomwb4zuqjjo', 1, [1062]),
#  ('httpstcob9jpcjfjsz', 1, [640]),
#  ('httpstcoyu4r1mhcjo', 1, [784]),
#  ('individu', 1, [303]),
#  ('11am', 1, [31]),
#  ('within', 2, [639, 1060]),
#  ('alzheim', 6, [131, 149, 264, 532, 879, 997]),
#  ('httpstcouriy2wnepi', 1, [79]),
#  ('citec', 1, [842]),
#  ('primat', 1, [970]),
#  ('embojourn', 1, [694]),
#  ('remnantnew', 1, [52]),
#  ('swisscomb2ben', 1, [399]),
#  ('lutolf', 1, [607]),
#  ('httpstcowdnmbshqfr', 1, [609]),
#  ('httpstcoo5tsdoy6zj', 1, [508]),
#  ('involv', 1, [591]),
#  ('mani', 8, [122, 122, 190, 262, 346, 697, 724, 1044]),
#  ('cosi', 1, [265]),
#  ('epflalumni', 2, [490, 1017]),
#  ('toss2017', 1, [471]),
#  ('idrrim', 1, [815]),
#  ('elect', 1, [981]),
#  ('3ème', 1, [202]),
#  ('genom', 4, [228, 284, 352, 358]),
#  ('forecast', 1, [526]),
#  ('vasilgelev', 1, [639]),
#  ('crossdress', 1, [529]),
#  ('httpstco0iqt3k8fkq', 1, [32]),
#  ('scholarli', 1, [422]),
#  ('market', 5, [397, 448, 628, 726, 870]),
#  ('elfirepfl', 1, [30]),
#  ('theme', 1, [669]),
#  ('httpstco6yiyk7cyi1', 1, [1016]),
#  ('schweizer', 1, [25]),
#  ('son', 10, [16, 205, 651, 665, 705, 752, 860, 874, 893, 996]),
#  ('httpstcof8vfogntco', 1, [842]),
#  ('marchand', 1, [1068]),
#  ('imdbschool', 1, [563]),
#  ('last', 11, [77, 154, 175, 180, 481, 550, 607, 635, 719, 957, 987]),
#  ('y', 3, [287, 682, 1024]),
#  ('sbb', 1, [250]),
#  ('movement', 1, [498]),
#  ('insta', 1, [325]),
#  ('cruelamom', 1, [582]),
#  ('wish', 5, [277, 307, 491, 940, 1034]),
#  ('httpstcocniwy0knqi', 1, [442]),
#  ('httpstcortxwav5pan', 1, [12]),
#  ('httpstcoh0tw5auhlg', 1, [836]),
#  ('httpstcok8npxuuki8', 2, [883, 884]),
#  ('francisco', 1, [963]),
#  ('imagejop', 1, [80]),
#  ('dedux', 1, [241]),
#  ('sold', 1, [337]),
#  ('adelio', 1, [419]),
#  ('httpstcow5bxpzmtuo', 1, [325]),
#  ('étudiant·e·', 1, [1025]),
#  ('jure', 1, [557]),
#  ('medtech', 3, [84, 725, 726]),
#  ('chute', 1, [1050]),
#  ('httpstcotl9v2shaai', 1, [547]),
#  ('moëll', 1, [1030]),
#  ('fpga', 3, [666, 909, 917]),
#  ('rate', 1, [834]),
#  ('nanostructur', 4, [113, 193, 332, 680]),
#  ('session', 5, [223, 294, 393, 468, 991]),
#  ('nobillag', 1, [144]),
#  ('2018hpeworkshop', 1, [611]),
#  ('id', 1, [80]),
#  ('venez', 3, [243, 983, 1037]),
#  ('benefit', 2, [294, 468]),
#  ('fifel', 1, [107]),
#  ('httpstcolb223yt804', 1, [92]),
#  ('24', 2, [265, 990]),
#  ('herzlich', 1, [25]),
#  ('httpstcojrwbq3pngc', 1, [869]),
#  ('ainsi', 3, [149, 342, 383]),
#  ('incontro', 1, [851]),
#  ('oskarfreysing', 1, [979]),
#  ('ethen',
#   20,
#   [0,
#    3,
#    13,
#    54,
#    64,
#    139,
#    200,
#    267,
#    295,
#    391,
#    399,
#    489,
#    549,
#    560,
#    675,
#    686,
#    858,
#    934,
#    984,
#    995]),
#  ('httpstconpgbukjhbl', 1, [228]),
#  ('swissedtech', 3, [652, 1016, 1016]),
#  ('httpstcofzvdm86ntf', 1, [1002]),
#  ('process', 5, [45, 290, 666, 755, 948]),
#  ('ignobel', 2, [230, 380]),
#  ('ctrl', 1, [438]),
#  ('classifi', 1, [734]),
#  ('metastast', 1, [32]),
#  ('we',
#   36,
#   [60,
#    65,
#    65,
#    78,
#    98,
#    108,
#    134,
#    134,
#    191,
#    203,
#    221,
#    223,
#    247,
#    264,
#    281,
#    307,
#    333,
#    346,
#    353,
#    414,
#    445,
#    572,
#    580,
#    601,
#    671,
#    703,
#    760,
#    802,
#    863,
#    886,
#    909,
#    935,
#    963,
#    1013,
#    1046,
#    1065]),
#  ('manyfac', 1, [637]),
#  ('tackl', 1, [879]),
#  ('africa', 2, [775, 1061]),
#  ('split', 1, [918]),
#  ('flaviacorda', 1, [530]),
#  ('machen', 2, [701, 890]),
#  ('shashank', 1, [748]),
#  ('talent', 2, [301, 905]),
#  ('achiev', 4, [397, 448, 519, 681]),
#  ('conf', 2, [46, 88]),
#  ('traveltuesday', 1, [136]),
#  ('httpstcoaaiitfl6ji', 1, [741]),
#  ('drpetti', 2, [320, 381]),
#  ('preventiteu', 1, [588]),
#  ('présenc', 1, [829]),
#  ('venir', 2, [604, 627]),
#  ('runtim', 1, [917]),
#  ('part', 9, [64, 125, 166, 269, 501, 512, 909, 939, 963]),
#  ('httpstconpfe5lge1a', 1, [520]),
#  ('salonsuissedelasant', 1, [1035]),
#  ('nestor', 1, [927]),
#  ('reward', 1, [948]),
#  ('cup', 1, [1066]),
#  ('étudier', 2, [43, 706]),
#  ('neue', 2, [167, 638]),
#  ('watch', 11, [17, 84, 99, 301, 353, 459, 613, 635, 649, 718, 992]),
#  ('httpstcolbd4stauna', 1, [205]),
#  ('httpstco5t7egh0quw', 1, [29]),
#  ('french', 7, [150, 185, 286, 492, 682, 702, 905]),
#  ('constraint', 1, [260]),
#  ('dun', 6, [265, 268, 385, 840, 874, 996]),
#  ('certain', 1, [685]),
#  ('entrepreun', 1, [910]),
#  ('httpstcouui9tmgnxt', 1, [916]),
#  ('smattheydoret', 1, [437]),
#  ('httpstcotyjw6gyijd', 1, [473]),
#  ('statut', 1, [1031]),
#  ('tech4dev', 1, [1007]),
#  ('na', 1, [70]),
#  ('davantag', 1, [244]),
#  ('httpstcotaqf8volq', 1, [365]),
#  ('clip', 1, [794]),
#  ('launch', 9, [57, 421, 453, 504, 506, 559, 586, 677, 703]),
#  ('ed', 1, [119]),
#  ('view', 3, [99, 310, 335]),
#  ('open',
#   26,
#   [2,
#    49,
#    54,
#    109,
#    188,
#    245,
#    260,
#    348,
#    393,
#    393,
#    420,
#    442,
#    453,
#    480,
#    504,
#    515,
#    587,
#    590,
#    688,
#    688,
#    703,
#    730,
#    850,
#    898,
#    911,
#    960]),
#  ('rich', 1, [5]),
#  ('stationn', 1, [687]),
#  ('serait', 1, [602]),
#  ('bishnoi', 1, [748]),
#  ('portivechju', 2, [207, 989]),
#  ('damag', 2, [712, 966]),
#  ('save', 5, [339, 441, 698, 887, 1060]),
#  ('tue', 1, [648]),
#  ('apprendr', 5, [118, 311, 827, 827, 1026]),
#  ('httpstcofopmo6q4ur', 1, [855]),
#  ('pecub', 1, [1035]),
#  ('africangeek', 1, [233]),
#  ('sestrin1', 1, [35]),
#  ('kingconrad', 2, [240, 637]),
#  ('relat', 1, [103]),
#  ('httpstcowjzxyjg5iq', 1, [1040]),
#  ('ethspinoff', 1, [963]),
#  ('he', 1, [126]),
#  ('version', 2, [164, 343]),
#  ('aitcamp', 1, [953]),
#  ('medicin', 3, [156, 164, 625]),
#  ('cage', 1, [124]),
#  ('light',
#   13,
#   [36, 44, 328, 406, 527, 544, 562, 597, 597, 714, 757, 831, 908]),
#  ('cyberspac', 1, [830]),
#  ('past', 1, [296]),
#  ('swisscognit', 1, [1041]),
#  ('centuryold', 1, [728]),
#  ('pulli', 2, [301, 339]),
#  ('coaward', 1, [720]),
#  ('httpstcooueqdvczdd', 1, [878]),
#  ('physicien', 1, [70]),
#  ('mentor', 2, [222, 339]),
#  ('datajamday', 3, [235, 426, 982]),
#  ('deeplearn', 5, [34, 165, 165, 521, 859]),
#  ('repair', 3, [712, 966, 1000]),
#  ('suffir', 1, [892]),
#  ('httpstcoh4f3dhx6i9', 1, [677]),
#  ('top10', 2, [686, 767]),
#  ('opensourc', 4, [524, 616, 713, 904]),
#  ('fundament', 1, [312]),
#  ('yunu', 3, [107, 107, 791]),
#  ('chaîn', 1, [12]),
#  ('handi', 1, [845]),
#  ('httpstcogghuh49wmi', 1, [822]),
#  ('httpstcov3tojtyjqd', 1, [3]),
#  ('introductori', 1, [34]),
#  ('httpstcou3unicyadi', 1, [300]),
#  ('siggenev', 1, [39]),
#  ('region', 1, [672]),
#  ('httpstcoarkwnybioy', 1, [471]),
#  ('thank',
#   27,
#   [108,
#    113,
#    218,
#    232,
#    245,
#    247,
#    259,
#    307,
#    315,
#    337,
#    341,
#    353,
#    399,
#    446,
#    460,
#    496,
#    516,
#    522,
#    552,
#    724,
#    747,
#    764,
#    810,
#    938,
#    938,
#    1002,
#    1005]),
#  ('2020', 3, [521, 981, 996]),
#  ('httpstcogtxlhi6lt', 1, [5]),
#  ('appoint', 3, [579, 875, 950]),
#  ('devic', 1, [878]),
#  ('httpstcouwftrbqvyh', 1, [706]),
#  ('leçon', 2, [172, 843]),
#  ('sciencetm', 1, [943]),
#  ('how',
#   28,
#   [21,
#    80,
#    122,
#    122,
#    143,
#    229,
#    341,
#    391,
#    492,
#    497,
#    507,
#    507,
#    518,
#    540,
#    613,
#    666,
#    669,
#    692,
#    736,
#    764,
#    818,
#    838,
#    856,
#    864,
#    869,
#    879,
#    907,
#    1002]),
#  ('trust', 9, [21, 50, 198, 580, 580, 581, 581, 640, 1044]),
#  ('conway', 1, [886]),
#  ('thinkswiss', 1, [995]),
#  ('100kg', 1, [430]),
#  ('innovaud', 5, [143, 148, 399, 421, 605]),
#  ('elliottrham', 1, [979]),
#  ('teilen', 1, [49]),
#  ('experiment', 1, [79]),
#  ('httpstcocjwc2eueii', 1, [762]),
#  ('stéphane', 1, [962]),
#  ('ohn', 1, [319]),
#  ('géothermi', 1, [967]),
#  ('httpstcoevlw3kf6v', 1, [998]),
#  ('geschicht', 1, [105]),
#  ('natureenergyjnl', 1, [834]),
#  ('doehlergroup', 1, [522]),
#  ('internship', 2, [731, 733]),
#  ('begreifbar', 1, [48]),
#  ('loch', 1, [189]),
#  ('t6ss', 1, [591]),
#  ('ieee', 2, [407, 917]),
#  ('extrêmement', 1, [742]),
#  ('design',
#   15,
#   [83, 133, 138, 260, 260, 453, 493, 511, 518, 669, 692, 703, 714, 798, 906]),
#  ('mattia', 1, [154]),
#  ('exciton', 1, [303]),
#  ('httpstcodpemd35x1r', 1, [260]),
#  ('cell',
#   16,
#   [29,
#    173,
#    242,
#    296,
#    317,
#    398,
#    406,
#    529,
#    595,
#    607,
#    681,
#    734,
#    734,
#    771,
#    833,
#    854]),
#  ('prendrai', 1, [61]),
#  ('episod', 1, [90]),
#  ('😏😊', 1, [866]),
#  ('techniqu', 1, [159]),
#  ('sigchi', 1, [435]),
#  ('mariag', 1, [437]),
#  ('weevilsodali', 1, [55]),
#  ('showcas', 1, [990]),
#  ('south', 1, [393]),
#  ('epflartlab', 4, [765, 781, 781, 983]),
#  ('emmanuelmacron', 1, [1037]),
#  ('expo', 2, [174, 1060]),
#  ('text', 1, [582]),
#  ('httpstcohblrytdmtt', 1, [6]),
#  ('continu', 3, [166, 177, 703]),
#  ('unildur', 2, [586, 961]),
#  ('2015', 1, [241]),
#  ('helga', 1, [210]),
#  ('mobilitätswend', 1, [1011]),
#  ('heurist', 1, [469]),
#  ('professorship', 1, [850]),
#  ('httpstcoryqo5z3jhk', 1, [132]),
#  ('flowcytometri', 1, [203]),
#  ('recrut', 1, [592]),
#  ('build', 9, [198, 320, 381, 510, 596, 669, 669, 684, 750]),
#  ('compétenc', 2, [565, 827]),
#  ('camp', 3, [619, 906, 963]),
#  ('httpstcoun7wlrhkna', 1, [156]),
#  ('chercheur', 1, [383]),
#  ('httpstcoojfrwo2glw', 1, [34]),
#  ('sbfich', 1, [200]),
#  ('venu', 2, [601, 626]),
#  ('daprè', 1, [1038]),
#  ('thermal', 1, [949]),
#  ('video', 9, [89, 95, 99, 492, 585, 649, 718, 758, 816]),
#  ('limplant', 1, [1030]),
#  ('enfantsado', 1, [1024]),
#  ('swsx', 4, [21, 198, 580, 581]),
#  ('baks3assoc', 1, [704]),
#  ('semain', 2, [325, 1047]),
#  ('httpstco06jmxdae2h', 1, [59]),
#  ('multipl', 1, [180]),
#  ('abstract', 4, [350, 393, 393, 578]),
#  ('biometr', 1, [1073]),
#  ('httpstco7whgqt8bmg', 1, [398]),
#  ('sphere', 1, [221]),
#  ('swissedtechcollid', 3, [91, 143, 273]),
#  ('c7', 1, [1030]),
#  ('httpstcorqftymktm9', 1, [195]),
#  ('namibian', 1, [235]),
#  ('theworldin', 1, [231]),
#  ('6', 5, [90, 175, 272, 767, 975]),
#  ('code', 8, [233, 347, 525, 528, 636, 707, 742, 752]),
#  ('bilanz', 1, [295]),
#  ('httpstco50aucbavcm', 1, [995]),
#  ('juli', 1, [222]),
#  ('domest', 1, [228]),
#  ('httpstcos3gmguc9sf', 1, [997]),
#  ('lacadémi', 1, [1022]),
#  ('sport', 1, [471]),
#  ('via',
#   93,
#   [16,
#    44,
#    45,
#    70,
#    73,
#    107,
#    110,
#    129,
#    132,
#    149,
#    173,
#    206,
#    211,
#    217,
#    228,
#    231,
#    234,
#    242,
#    256,
#    271,
#    280,
#    282,
#    286,
#    291,
#    298,
#    299,
#    332,
#    351,
#    354,
#    364,
#    383,
#    387,
#    389,
#    405,
#    421,
#    430,
#    432,
#    440,
#    452,
#    459,
#    464,
#    486,
#    499,
#    508,
#    510,
#    524,
#    539,
#    543,
#    562,
#    582,
#    595,
#    597,
#    616,
#    625,
#    647,
#    676,
#    692,
#    693,
#    718,
#    754,
#    788,
#    801,
#    815,
#    827,
#    831,
#    833,
#    838,
#    839,
#    843,
#    852,
#    854,
#    865,
#    879,
#    882,
#    883,
#    884,
#    889,
#    897,
#    923,
#    924,
#    934,
#    966,
#    970,
#    972,
#    997,
#    1008,
#    1029,
#    1040,
#    1050,
#    1062,
#    1064,
#    1067,
#    1071]),
#  ('httpstcoa5in0tcls7', 1, [731]),
#  ('durabilité', 1, [961]),
#  ('eurosys2018', 3, [274, 306, 306]),
#  ('httpstcocmoowb3eh6', 1, [93]),
#  ('😊', 2, [409, 1005]),
#  ('opportunité', 2, [129, 801]),
#  ('développ', 3, [827, 967, 1070]),
#  ('rueeggthurgau', 1, [209]),
#  ('flowersinria', 1, [735]),
#  ('sil', 1, [467]),
#  ('httpstcosca1n4ayuq', 1, [624]),
#  ('1315th', 1, [102]),
#  ('carv', 2, [256, 389]),
#  ('ive', 1, [262]),
#  ('epfllts5', 1, [855]),
#  ('silkroad', 1, [530]),
#  ('eröffnet', 1, [443]),
#  ('httpstco16jwmxzzn8', 1, [634]),
#  ('coldion', 1, [661]),
#  ('protect', 3, [41, 124, 830]),
#  ('cmi', 1, [225]),
#  ('strongli', 1, [987]),
#  ('flyabil', 1, [1036]),
#  ('either', 1, [791]),
#  ('evidencebas', 1, [126]),
#  ('cdf', 1, [282]),
#  ('immers', 1, [444]),
#  ('lymph', 1, [696]),
#  ('challeng', 6, [71, 158, 267, 492, 657, 724]),
#  ('httpstcozx134tvlaf', 1, [1003]),
#  ('own', 3, [75, 528, 957]),
#  ('httpstcoztwr6xeqot', 1, [1025]),
#  ('remind', 1, [735]),
#  ('sui', 4, [12, 199, 467, 1030]),
#  ('univers',
#   23,
#   [4,
#    13,
#    64,
#    71,
#    121,
#    139,
#    195,
#    294,
#    468,
#    482,
#    531,
#    632,
#    648,
#    686,
#    759,
#    759,
#    812,
#    817,
#    912,
#    912,
#    934,
#    944,
#    995]),
#  ('jan', 2, [68, 590]),
#  ('matter', 6, [110, 111, 280, 355, 704, 811]),
#  ('essenti', 1, [41]),
#  ('smile', 1, [894]),
#  ('fail', 1, [813]),
#  ('chromatin', 3, [378, 378, 959]),
#  ('lallianc', 1, [565]),
#  ('httpstcorgsyaedoci', 1, [829]),
#  ('about',
#   36,
#   [79,
#    102,
#    103,
#    126,
#    138,
#    163,
#    258,
#    274,
#    288,
#    310,
#    312,
#    323,
#    329,
#    341,
#    365,
#    390,
#    466,
#    481,
#    518,
#    526,
#    545,
#    608,
#    658,
#    663,
#    733,
#    743,
#    790,
#    799,
#    802,
#    804,
#    808,
#    859,
#    888,
#    904,
#    957,
#    987]),
#  ('crispri', 1, [513]),
#  ('nberpub', 4, [294, 294, 468, 468]),
#  ('ingénieur', 2, [205, 862]),
#  ('icymi', 1, [595]),
#  ('state', 1, [66]),
#  ('httpstcodrtxjxjdzd', 1, [155]),
#  ('poisson', 1, [599]),
#  ('fallait', 1, [1071]),
#  ('httpstcowsnmjekhmo', 1, [770]),
#  ('vibrio', 2, [591, 738]),
#  ('gill', 1, [15]),
#  ('harmanton', 1, [336]),
#  ('pilot', 1, [429]),
#  ('stilofficiel', 2, [569, 902]),
#  ('httpstcoxwnsg7vcei', 1, [149]),
#  ('afternoon', 1, [223]),
#  ('httpstcowejk5iwilc', 1, [623]),
#  ('benoit', 1, [316]),
#  ('nobelpr', 5, [42, 238, 258, 265, 727]),
#  ('thx', 1, [561]),
#  ('hydro', 1, [400]),
#  ('welcom', 5, [57, 258, 286, 847, 1013]),
#  ('httpstcogddwywahp4', 1, [296]),
#  ('httpstcot6fblcy27j', 1, [335]),
#  ('mytechni', 1, [800]),
#  ('fintech', 3, [19, 127, 538]),
#  ('ehr', 1, [25]),
#  ('mjf', 1, [844]),
#  ('httpstcovpqbi71cn5', 1, [873]),
#  ('stepgeneva', 1, [863]),
#  ('httpstcovtqzs8r1rl', 1, [701]),
#  ('mechatronik', 1, [48]),
#  ('croir', 1, [439]),
#  ('search', 3, [134, 316, 640]),
#  ('httpstco0givobwpuo', 1, [593]),
#  ('bioinformat', 2, [320, 381]),
#  ('fpbock', 1, [86]),
#  ('semiarid', 1, [235]),
#  ('rest', 1, [325]),
#  ('intracrani', 1, [290]),
#  ('henri', 1, [818]),
#  ('befor', 5, [90, 275, 504, 727, 751]),
#  ('techsmithd', 1, [747]),
#  ('simonl', 1, [346]),
#  ('autonom', 2, [292, 1008]),
#  ('httpstcosnrtupk8po', 1, [118]),
#  ('nanotub', 1, [695]),
#  ('httpstco1ko7mdz4ag', 1, [881]),
#  ('coltran', 1, [189]),
#  ('fr', 1, [633]),
#  ('itfa', 2, [294, 468]),
#  ('weekend', 6, [168, 307, 337, 342, 626, 899]),
#  ('ideal', 3, [640, 883, 884]),
#  ('🎧', 2, [168, 197]),
#  ('feet', 1, [649]),
#  ('doit', 2, [939, 958]),
#  ('httpstco0bnmbpx50k', 1, [475]),
#  ('réaménag', 1, [1063]),
#  ('therapist', 1, [1029]),
#  ('httpstcol9zkm8twqz', 1, [579]),
#  ('digital', 3, [384, 565, 822]),
#  ('aprè', 6, [277, 665, 705, 752, 900, 1037]),
#  ('cardiacsurgeon', 1, [758]),
#  ('14h', 2, [345, 604]),
#  ('line', 4, [93, 589, 686, 1061]),
#  ('creativ', 1, [790]),
#  ('forget', 1, [90]),
#  ('bloodi', 1, [278]),
#  ('stroke', 2, [972, 1029]),
#  ('schiesser', 1, [785]),
#  ('léprouvett', 1, [265]),
#  ('key', 1, [643]),
#  ('jetzt', 1, [167]),
#  ('pribabl', 1, [535]),
#  ('dem', 1, [188]),
#  ('made',
#   16,
#   [75,
#    80,
#    115,
#    163,
#    234,
#    247,
#    375,
#    416,
#    576,
#    618,
#    628,
#    660,
#    669,
#    770,
#    985,
#    1055]),
#  ('révision', 1, [161]),
#  ('problèm', 1, [823]),
#  ('2017',
#   24,
#   [48,
#    48,
#    63,
#    121,
#    154,
#    178,
#    265,
#    420,
#    422,
#    431,
#    538,
#    560,
#    609,
#    705,
#    730,
#    887,
#    929,
#    931,
#    934,
#    975,
#    1015,
#    1062,
#    1064,
#    1066]),
#  ('zotero', 5, [61, 439, 682, 840, 939]),
#  ('zettabyt', 1, [458]),
#  ('jdmrt', 1, [1068]),
#  ('httpstcorbhltiqx8a', 2, [135, 179]),
#  ('petra', 1, [734]),
#  ('18th', 1, [225]),
#  ('flexibl', 1, [440]),
#  ('one',
#   20,
#   [21,
#    58,
#    66,
#    71,
#    126,
#    158,
#    236,
#    413,
#    461,
#    461,
#    531,
#    632,
#    634,
#    657,
#    669,
#    691,
#    790,
#    859,
#    903,
#    1009]),
#  ('solarpow', 1, [870]),
#  ('crucial', 1, [548]),
#  ('haptic', 2, [102, 102]),
#  ('eight', 1, [984]),
#  ('stone', 1, [293]),
#  ('wirklich', 1, [105]),
#  ('la',
#   102,
#   [11,
#    11,
#    11,
#    12,
#    12,
#    16,
#    20,
#    26,
#    26,
#    26,
#    26,
#    26,
#    47,
#    51,
#    56,
#    61,
#    61,
#    81,
#    94,
#    118,
#    149,
#    149,
#    149,
#    157,
#    168,
#    182,
#    183,
#    197,
#    199,
#    202,
#    244,
#    252,
#    287,
#    300,
#    304,
#    304,
#    322,
#    325,
#    342,
#    345,
#    357,
#    362,
#    382,
#    383,
#    386,
#    386,
#    392,
#    404,
#    404,
#    452,
#    463,
#    526,
#    565,
#    566,
#    568,
#    584,
#    592,
#    603,
#    604,
#    610,
#    636,
#    644,
#    659,
#    706,
#    723,
#    766,
#    783,
#    784,
#    788,
#    788,
#    800,
#    806,
#    842,
#    844,
#    860,
#    874,
#    894,
#    895,
#    901,
#    902,
#    913,
#    919,
#    923,
#    929,
#    958,
#    958,
#    961,
#    976,
#    977,
#    978,
#    988,
#    996,
#    1016,
#    1016,
#    1018,
#    1022,
#    1030,
#    1030,
#    1042,
#    1054,
#    1066,
#    1066]),
#  ('femm', 1, [488]),
#  ('surollon', 1, [601]),
#  ('httpstcowcmsrzdv51', 1, [552]),
#  ('httpstcoj3gzqu9pqa', 1, [705]),
#  ('gniarfffff', 1, [311]),
#  ('httpstcoflbrxiqi6a', 1, [833]),
#  ('brantut', 1, [431]),
#  ('crée', 1, [182]),
#  ('httpstcowpllsit0kd', 1, [253]),
#  ('1980', 1, [1069]),
#  ('mad', 1, [142]),
#  ('antibiotiqu', 3, [149, 405, 424]),
#  ('chi', 1, [658]),
#  ('httpstco5qiiwlrwqj', 1, [129]),
#  ('martindahinden', 1, [940]),
#  ('doc', 1, [840]),
#  ('16h', 1, [604]),
#  ('solarcel', 1, [986]),
#  ('beibringen', 1, [701]),
#  ('httpstcoculfwnlubc', 1, [685]),
#  ('httpstcon4yqbge3m', 1, [438]),
#  ('httpstcosyqnwjmzzx', 1, [977]),
#  ('smit', 1, [575]),
#  ('panel', 6, [83, 107, 320, 646, 684, 724]),
#  ('beauti', 2, [458, 601]),
#  ('summer', 3, [28, 78, 535]),
#  ('esthétiqu', 1, [1023]),
#  ('httpstcoqkysnjcskw', 1, [182]),
#  ('mitochondria', 3, [131, 532, 997]),
#  ('heigvd', 1, [200]),
#  ('noir', 6, [174, 174, 782, 837, 837, 1043]),
#  ('neural', 1, [387]),
#  ('prendra', 1, [860]),
#  ('metabol', 2, [629, 694]),
#  ('swissdecod', 1, [587]),
#  ('httpstcoboxkkgrla', 1, [553]),
#  ('2018',
#   30,
#   [27,
#    28,
#    30,
#    32,
#    46,
#    137,
#    144,
#    168,
#    197,
#    202,
#    250,
#    263,
#    277,
#    350,
#    390,
#    393,
#    464,
#    465,
#    466,
#    512,
#    560,
#    586,
#    642,
#    688,
#    709,
#    719,
#    719,
#    801,
#    898,
#    1007]),
#  ('bertarellineuro', 1, [481]),
#  ('yesterday', 2, [381, 525]),
#  ('franceint', 1, [784]),
#  ('httpstcotw6q3kan5q', 1, [571]),
#  ('httpstcoaodxrekih3', 1, [243]),
#  ('beethoven', 1, [1051]),
#  ('void', 1, [410]),
#  ('mindblow', 1, [1014]),
#  ('–', 6, [44, 44, 292, 560, 720, 973]),
#  ('températur', 2, [283, 766]),
#  ('babi', 1, [514]),
#  ('httpstcoknqnghd6ma', 1, [383]),
#  ('sozial', 1, [105]),
#  ('httpstcol4gcxplvsi', 1, [688]),
#  ('minuten', 1, [1015]),
#  ('httpstcoc8ssuixmmg', 1, [215]),
#  ('httpstcol3uzhzaidt', 1, [1072]),
#  ('httpstcoxyrzbcfwoq', 1, [573]),
#  ('httpstco3qhw8vh9il', 2, [173, 854]),
#  ('amyloid', 1, [661]),
#  ('montserrat', 1, [227]),
#  ('indian', 1, [15]),
#  ('httpstcop2yco15lgo', 1, [815]),
#  ('httpstco4d9qk0bn80', 1, [528]),
#  ('safe', 3, [104, 104, 124]),
#  ('von', 8, [48, 241, 425, 425, 737, 737, 890, 969]),
#  ('unistra', 1, [334]),
#  ('httpstco09hxnyityk', 1, [975]),
#  ('nccrmarvel', 1, [545]),
#  ('yet', 2, [691, 903]),
#  ('httpstcoztbmsxxp3x', 1, [36]),
#  ('httpstcoluraa7vj2c', 1, [261]),
#  ('ensmmofficiel', 1, [304]),
#  ('amp8207', 1, [334]),
#  ('cortex', 1, [290]),
#  ('collaboratif', 2, [304, 385]),
#  ('glückwunsch', 1, [954]),
#  ('httpstcoyqvbpliwdv', 1, [1026]),
#  ('voici', 1, [325]),
#  ('newdawn', 1, [608]),
#  ('uniofread', 1, [522]),
#  ('cndpdebatpubl', 1, [603]),
#  ('develop',
#   21,
#   [31,
#    132,
#    159,
#    166,
#    169,
#    229,
#    419,
#    440,
#    551,
#    577,
#    577,
#    607,
#    624,
#    647,
#    677,
#    678,
#    684,
#    712,
#    732,
#    966,
#    980]),
#  ('combien', 1, [687]),
#  ('suivr', 3, [417, 780, 892]),
#  ('hill', 1, [736]),
#  ('news', 2, [4, 630]),
#  ('psd', 1, [965]),
#  ('daylight', 1, [376]),
#  ('foli', 1, [894]),
#  ('httpstcopqslfajac', 1, [289]),
#  ('ownership', 1, [422]),
#  ('thinkservic', 1, [862]),
#  ('much', 4, [198, 333, 736, 940]),
#  ('ictproposereu', 1, [346]),
#  ('zizi', 1, [988]),
#  ('squar', 1, [715]),
#  ('alexandr', 1, [69]),
#  ('lîle', 1, [463]),
#  ('httpstcoriozv4axxn', 1, [131]),
#  ('là', 2, [929, 1049]),
#  ('fatherjenkin', 1, [936]),
#  ('httpstcoxv6bg2vfq4', 1, [262]),
#  ('on🇪🇺eufund', 1, [717]),
#  ('mission', 5, [138, 493, 554, 665, 798]),
#  ('yale', 1, [195]),
#  ('molecul', 1, [547]),
#  ('conseil', 1, [857]),
#  ('hackuarium', 1, [176]),
#  ('stack', 2, [66, 66]),
#  ('httpstcoz9l9tvcek', 1, [598]),
#  ('aceexpedit', 3, [474, 496, 919]),
#  ('httpstcoicjzbgikkg', 1, [331]),
#  ('httpstcos1t6jccyoj', 1, [398]),
#  ('nestl', 1, [522]),
#  ('cdmissionindia', 1, [15]),
#  ('mouvement', 2, [279, 861]),
#  ('genova', 1, [639]),
#  ('practition', 2, [33, 946]),
#  ('httpstcoyaklj6rwyz', 1, [887]),
#  ('adnovum', 1, [700]),
#  ('signé', 1, [423]),
#  ('venture2018', 3, [445, 506, 613]),
#  ('headgenev', 1, [705]),
#  ('httpstcoruxbhhsidi', 1, [803]),
#  ('cancer', 8, [8, 32, 173, 242, 529, 547, 547, 854]),
#  ('riff', 1, [787]),
#  ('httpstcoj8pzbx8p6v', 1, [726]),
#  ('scicommfilmhack', 1, [420]),
#  ('httpstcoh9i17a12yx', 1, [380]),
#  ('dougla', 1, [32]),
#  ('row', 1, [407]),
#  ('cc',
#   14,
#   [53, 177, 311, 312, 313, 472, 572, 608, 649, 672, 815, 891, 1039, 1040]),
#  ('mylausann', 1, [749]),
#  ('swissnex', 1, [963]),
#  ('restetil', 1, [1069]),
#  ('universitelav', 1, [554]),
#  ('neinzunobillag', 1, [144]),
#  ('nanoparticul', 1, [978]),
#  ('antirheumat', 1, [211]),
#  ('act', 2, [82, 581]),
#  ('perl', 1, [886]),
#  ('httpstcociezy0jtbm', 1, [750]),
#  ('ft', 1, [972]),
#  ('foresti', 1, [653]),
#  ('engadget', 1, [647]),
#  ('microbiologist', 1, [777]),
#  ('meinen', 1, [954]),
#  ('barth', 1, [795]),
#  ('erlaubt', 1, [638]),
#  ('readtoreef', 1, [814]),
#  ('fate', 1, [607]),
#  ('languag', 1, [792]),
#  ('pasteur', 1, [579]),
#  ('chees', 2, [587, 587]),
#  ('darkmatt', 3, [111, 355, 811]),
#  ('verifi', 1, [581]),
#  ('besson', 1, [855]),
#  ('sec', 1, [492]),
#  ('scriven', 1, [748]),
#  ('httpstco5zcwxyykdh', 1, [625]),
#  ('employe', 1, [938]),
#  ('httpstcoou16d36it9', 1, [171]),
#  ('cybersecur', 2, [645, 724]),
#  ('créatif', 1, [363]),
#  ('sconnect', 1, [62]),
#  ('httpstcoctx6uusyog', 1, [276]),
#  ('prof',
#   21,
#   [107,
#    107,
#    107,
#    119,
#    126,
#    157,
#    187,
#    223,
#    264,
#    275,
#    288,
#    296,
#    318,
#    419,
#    575,
#    699,
#    791,
#    903,
#    915,
#    1067,
#    1068]),
#  ('dataviz', 2, [413, 790]),
#  ('videogam', 2, [715, 715]),
#  ('httpstcohnsuosekx3', 1, [344]),
#  ('motam', 1, [867]),
#  ('hgststorag', 1, [1012]),
#  ('httpstco8rlp0zzhyb', 1, [0]),
#  ('alexalahi', 2, [104, 292]),
#  ('je', 11, [12, 61, 161, 199, 199, 439, 467, 862, 988, 1030, 1054]),
#  ('comprehens', 1, [469]),
#  ('qui', 9, [26, 56, 168, 282, 383, 548, 682, 752, 913]),
#  ('excit',
#   21,
#   [4,
#    60,
#    106,
#    343,
#    358,
#    387,
#    419,
#    427,
#    445,
#    464,
#    474,
#    515,
#    563,
#    576,
#    608,
#    629,
#    951,
#    984,
#    999,
#    1046,
#    1065]),
#  ('httpstcojc6dcitrx2', 2, [328, 527]),
#  ('hear', 2, [65, 221]),
#  ('coaché', 1, [566]),
#  ('brjsa📀', 1, [99]),
#  ('erf2018', 1, [102]),
#  ('httpstcoefz6cwdb96', 1, [980]),
#  ('dann', 1, [890]),
#  ('technologisteu', 3, [217, 648, 669]),
#  ('httpstcofiymwvlnar', 1, [512]),
#  ('worm', 1, [696]),
#  ('peut', 2, [283, 892]),
#  ('clear', 1, [65]),
#  ('httpstcou1ottqcvlu', 1, [145]),
#  ('volontair', 1, [429]),
#  ('httpstcoqgkbwg220b', 1, [821]),
#  ('lab',
#   16,
#   [95,
#    95,
#    100,
#    245,
#    258,
#    387,
#    419,
#    419,
#    503,
#    532,
#    591,
#    699,
#    731,
#    864,
#    958,
#    980]),
#  ('activit', 1, [929]),
#  ('soap', 1, [75]),
#  ('roysocchem', 1, [807]),
#  ('scolair', 1, [783]),
#  ('millisecond', 1, [66]),
#  ('httpstco0bajjgzvtj', 1, [465]),
#  ('avalanch', 6, [150, 150, 185, 185, 526, 526]),
#  ('pic', 2, [375, 1005]),
#  ('tough', 1, [650]),
#  ('geht', 2, [319, 1015]),
#  ('httpstcom80vlqskfq', 1, [1069]),
#  ('archaïqu', 1, [843]),
#  ('sa', 2, [202, 627]),
#  ('insiscnr', 1, [304]),
#  ('prospérité', 1, [26]),
#  ('httpstcoqb0t28tdtq', 1, [1019]),
#  ('union', 2, [294, 468]),
#  ('independant', 1, [356]),
#  ('httpstcofhrlh3haa9', 1, [408]),
#  ('jeu', 1, [633]),
#  ('httpstco9d256rj7ct', 1, [769]),
#  ('sexual', 1, [979]),
#  ('httpstcoofmfg5uwf', 1, [48]),
#  ('securityprivaci', 1, [640]),
#  ('techni', 2, [553, 800]),
#  ('httpstcoewpqrcc817', 1, [733]),
#  ('eucommiss', 7, [140, 237, 391, 549, 1057, 1058, 1059]),
#  ('vite', 1, [687]),
#  ('gise', 2, [441, 772]),
#  ('truenorthia', 1, [685]),
#  ('founder', 2, [154, 506]),
#  ('catalyt', 1, [334]),
#  ('newyearresolut', 1, [341]),
#  ('induc', 1, [469]),
#  ('deceiv', 1, [50]),
#  ('2101', 1, [197]),
#  ('lockedin', 1, [438]),
#  ('docomomo', 1, [633]),
#  ('bcdiploma', 1, [561]),
#  ('httpstcoqj7zbiiia6', 1, [372]),
#  ('slashandburn', 1, [808]),
#  ('architectur', 9, [77, 123, 232, 376, 453, 455, 714, 788, 788]),
#  ('deliv', 2, [124, 223]),
#  ('httpstcojlgbaxvtkj', 1, [924]),
#  ('testé', 1, [172]),
#  ('httpstcohdf05qrhiu', 1, [154]),
#  ('ug', 1, [1011]),
#  ('httpstcoiyxfpxdcbq', 1, [589]),
#  ('commeric', 1, [628]),
#  ('lenvironn', 2, [783, 876]),
#  ('détendr', 1, [277]),
#  ('happylook', 1, [76]),
#  ('replica', 1, [316]),
#  ('httpstcopbmkt2wxcg', 1, [595]),
#  ('lombr', 1, [1051]),
#  ('piss', 1, [936]),
#  ('secret', 2, [70, 414]),
#  ('sponsor', 1, [33]),
#  ('wsl', 1, [526]),
#  ('ericdubay', 2, [99, 240]),
#  ('cusophd', 2, [301, 339]),
#  ('metoo', 1, [979]),
#  ('lymphoma', 1, [35]),
#  ('httpstconhax6irai5', 1, [918]),
#  ('informatik', 1, [309]),
#  ('j', 2, [144, 945]),
#  ('microprojector', 1, [624]),
#  ('2', 12, [27, 121, 124, 200, 596, 614, 622, 686, 740, 778, 822, 941]),
#  ('room', 2, [419, 513]),
#  ('cultureartsci', 1, [837]),
#  ('sendai', 1, [519]),
#  ('rivoalti', 1, [70]),
#  ('edx', 1, [214]),
#  ('carboneutr', 1, [996]),
#  ('ehlnew', 2, [244, 302]),
#  ('gianpaolorando', 1, [416]),
#  ('cyberintproject', 1, [746]),
#  ('httpstcovdczjrh87j', 1, [772]),
#  ('5th', 1, [0]),
#  ('unread', 1, [109]),
#  ('festiv', 2, [313, 1032]),
#  ('xma', 1, [263]),
#  ('reçoit', 1, [752]),
#  ('probe', 4, [173, 676, 854, 949]),
#  ('décret', 1, [1054]),
#  ('letemp', 4, [295, 610, 665, 844]),
#  ('esrofficiel', 1, [130]),
#  ('predict', 2, [127, 557]),
#  ('connaiss', 2, [118, 893]),
#  ('désolé', 1, [199]),
#  ('captur', 3, [575, 585, 770]),
#  ('detour', 1, [815]),
#  ('acmepfl', 1, [914]),
#  ('nanopattern', 1, [949]),
#  ('virtual', 8, [376, 444, 449, 717, 718, 758, 907, 917]),
#  ('femtoprint®', 1, [225]),
#  ('m', 3, [731, 829, 945]),
#  ('videostitch', 1, [428]),
#  ('sélectionné', 1, [160]),
#  ('fibril', 1, [661]),
#  ('bad', 3, [104, 335, 575]),
#  ('prenant', 1, [794]),
#  ('verantwortung', 1, [105]),
#  ('soimêm', 1, [456]),
#  ('yardenkatz', 1, [556]),
#  ('dire', 1, [1043]),
#  ('votr', 6, [12, 160, 548, 665, 848, 1048]),
#  ('montreux', 1, [1032]),
#  ('savmap', 1, [235]),
#  ('rememb', 1, [409]),
#  ('went', 1, [987]),
#  ('droneday', 1, [1060]),
#  ('labor', 2, [294, 468]),
#  ('httpstcoco2lbnhmvd', 1, [737]),
#  ('httpstcoycddh7u8pu', 1, [862]),
#  ('fourthrevolut', 1, [22]),
#  ('httpstcodhsmrolyj7', 1, [429]),
#  ('httpstcoiv291y1aiu', 1, [268]),
#  ('dkineu', 1, [684]),
#  ('httpstcoeituenfoax', 1, [81]),
#  ('ravindra', 1, [748]),
#  ('mahamad', 1, [56]),
#  ('httpstconhsvjdpa0w', 1, [142]),
#  ('hope', 5, [308, 482, 692, 755, 769]),
#  ('area', 4, [41, 112, 521, 640]),
#  ('color', 1, [684]),
#  ('httpstcoud2auxd5', 1, [820]),
#  ('proch', 1, [862]),
#  ('reconstruct', 3, [436, 454, 855]),
#  ('lappel', 1, [526]),
#  ('danger', 4, [150, 150, 185, 185]),
#  ('fort', 1, [543]),
#  ('httpstcomkagtigntv', 1, [661]),
#  ('httpstcocmx5oahu6a', 1, [446]),
#  ('httpstcoivvkwm8ymi', 1, [656]),
#  ('melenchon', 1, [825]),
#  ('httpstcoazwevbdhvv', 1, [493]),
#  ('httpstco2r2t895qxi', 1, [504]),
#  ('myswitzerland', 1, [749]),
#  ('local', 1, [303]),
#  ('machinelearn', 10, [127, 165, 165, 503, 587, 610, 667, 733, 765, 999]),
#  ('wast', 3, [166, 323, 555]),
#  ('greatcellsolar', 1, [419]),
#  ('softrobots………', 1, [1065]),
#  ('women', 1, [646]),
#  ('httpstcooyguvk0le4', 1, [64]),
#  ('haven', 1, [691]),
#  ('httpstco2eruzdhgxv', 1, [610]),
#  ('httpstcoppddpyyiri', 1, [844]),
#  ('dsm', 1, [522]),
#  ('stress', 3, [28, 490, 1031]),
#  ('fakenew', 1, [27]),
#  ('portrait', 1, [779]),
#  ('usbeketrica', 1, [472]),
#  ('critic', 2, [150, 292]),
#  ('adressé', 1, [742]),
#  ('httpstcomrdf4m2rgm', 1, [1039]),
#  ('man', 4, [787, 787, 787, 787]),
#  ('httpstcoixgzzoaatx', 1, [658]),
#  ('innovant', 1, [1026]),
#  ('stay', 5, [78, 125, 722, 813, 836]),
#  ('gelähmten', 1, [701]),
#  ('isadilenardo', 1, [316]),
#  ('httpstcorag69bzvk', 1, [247]),
#  ('pfeifer', 2, [264, 879]),
#  ('humanum', 1, [592]),
#  ('httpstcokzbzzlzn5c', 1, [972]),
#  ('selfsuffici', 2, [83, 155]),
#  ('🌱', 1, [637]),
#  ('whipton', 1, [175]),
#  ('jordi', 1, [227]),
#  ('httpstcozpubapi464', 1, [483]),
#  ('zhdk', 1, [873]),
#  ('garfieldabh', 1, [1019]),
#  ('httpstcocmhoigyevq', 1, [349]),
#  ('busi', 8, [71, 539, 645, 874, 926, 1003, 1003, 1005]),
#  ('comic', 1, [715]),
#  ('divisar', 1, [232]),
#  ('energystrategi', 1, [608]),
#  ('httpstcoxzogadbp4d', 1, [928]),
#  ('excess', 1, [834]),
#  ('win', 5, [77, 175, 267, 272, 688]),
#  ('réseau', 1, [1063]),
#  ('absorpt', 1, [597]),
#  ('archimag', 1, [183]),
#  ('feather', 1, [1055]),
#  ('swissrobot', 2, [646, 657]),
#  ('irak', 1, [1067]),
#  ('polytechn', 1, [596]),
#  ('suck', 1, [353]),
#  ('princeton', 1, [676]),
#  ('contest', 1, [654]),
#  ('httpstco1fgggsnrkl', 1, [95]),
#  ('postfin', 1, [148]),
#  ('took', 2, [899, 936]),
#  ('ali', 1, [867]),
#  ('fun', 2, [542, 587]),
#  ('thearkvalai', 1, [130]),
#  ('econom', 3, [101, 103, 401]),
#  ('bours', 2, [43, 574]),
#  ('hint', 2, [341, 865]),
#  ('etr', 1, [26]),
#  ('kur', 1, [167]),
#  ('42born2cod', 1, [561]),
#  ('cholera', 1, [738]),
#  ('vice', 1, [875]),
#  ('lagepoli', 1, [1019]),
#  ('httpstcovnvszikvoc', 1, [415]),
#  ('wind', 2, [150, 1055]),
#  ('httpstcon28ufhjpaq', 1, [633]),
#  ('ancien', 1, [1017]),
#  ('httpstcoavujdhhuvu', 1, [834]),
#  ('httpstcot1g10gvbt', 1, [298]),
#  ('enrol', 1, [41]),
#  ('httpstcon2d0xw6krz', 1, [559]),
#  ('httpstcof47bx1wyki', 1, [514]),
#  ('becaus', 1, [655]),
#  ('terrywinn', 1, [419]),
#  ('yve', 1, [898]),
#  ('cafe', 1, [1032]),
#  ('philipp', 3, [162, 213, 479]),
#  ('show', 12, [17, 189, 230, 380, 609, 671, 764, 765, 790, 838, 864, 1002]),
#  ('uniqu', 3, [801, 883, 884]),
#  ('23rdthing', 1, [678]),
#  ('seulement', 1, [265]),
#  ('solar',
#   24,
#   [29,
#    40,
#    83,
#    152,
#    296,
#    299,
#    317,
#    364,
#    396,
#    398,
#    406,
#    419,
#    473,
#    517,
#    595,
#    681,
#    684,
#    705,
#    771,
#    853,
#    913,
#    968,
#    1002,
#    1004]),
#  ('magnet', 1, [558]),
#  ('populair', 1, [742]),
#  ('mechan', 6, [44, 512, 607, 607, 753, 809]),
#  ('givaudan', 1, [522]),
#  ('httpstco6c3s2rk03u', 1, [563]),
#  ('promis', 3, [406, 486, 693]),
#  ('correcteur', 1, [651]),
#  ('thinksportsuccessstori', 1, [1060]),
#  ('leaf', 1, [237]),
#  ('had', 4, [746, 899, 1046, 1065]),
#  ('soon', 3, [963, 972, 998]),
#  ('httpstcoh8cjpqe2', 1, [744]),
#  ('global', 8, [13, 82, 106, 319, 393, 434, 623, 721]),
#  ('submiss', 3, [350, 393, 578]),
#  ('shevchenko', 1, [745]),
#  ('httpstcomass98crri', 2, [328, 527]),
#  ('environ', 4, [104, 171, 292, 442]),
#  ('institut',
#   13,
#   [28, 54, 220, 449, 579, 665, 675, 741, 799, 933, 937, 950, 984]),
#  ('httpstco4ask1pvykb', 1, [515]),
#  ('dutilis', 1, [889]),
#  ('httpstcov9rrdrv5jz', 1, [907]),
#  ('cryo', 1, [526]),
#  ('defens', 2, [645, 743]),
#  ('prédécesseur', 1, [665]),
#  ('epflstud', 1, [716]),
#  ('politician', 1, [572]),
#  ('play', 6, [100, 291, 394, 539, 770, 790]),
#  ('realen', 1, [737]),
#  ('wpcapit', 1, [399]),
#  ('publicli', 1, [80]),
#  ('cyclabl', 1, [1039]),
#  ('madrid', 1, [709]),
#  ('danser', 2, [168, 197]),
#  ('pariet', 1, [290]),
#  ('httpstcosktacgrukw', 1, [126]),
#  ('httpstcoznphy0ralc', 1, [57]),
#  ('prêt', 1, [1051]),
#  ('stromtanken', 1, [1011]),
#  ('httpstcoaz7xlfk3da', 1, [961]),
#  ('httpstcoepymyqckzw', 1, [1048]),
#  ('😉', 5, [209, 325, 735, 802, 1049]),
#  ('also', 8, [30, 108, 108, 108, 150, 192, 323, 530]),
#  ('début', 3, [47, 901, 1018]),
#  ('httpstco6lmgbkcsdb', 1, [76]),
#  ('everybodi', 2, [178, 573]),
#  ('httpstcold04jbxpsw', 1, [978]),
#  ('httpstcouwvuz7i9v9', 1, [501]),
#  ('borgesjorgel', 1, [846]),
#  ('manu', 1, [748]),
#  ('httpstco7qzba4qjxg', 1, [588]),
#  ('pictur', 2, [559, 866]),
#  ('virtualis', 1, [909]),
#  ('impost', 2, [249, 414]),
#  ('unosat', 1, [243]),
#  ('httpstcohjbhwul4pv', 1, [979]),
#  ('crew', 1, [474]),
#  ('nvmt', 1, [77]),
#  ('vitro', 1, [354]),
#  ('porcelain', 1, [770]),
#  ('hesso', 5, [11, 63, 200, 525, 829]),
#  ('mossoul', 1, [1067]),
#  ('lightmatter2017', 1, [371]),
#  ('tedbyrn', 1, [1005]),
#  ('giulia', 1, [633]),
#  ('solardecathlon', 2, [83, 705]),
#  ('51', 1, [272]),
#  ('focu', 2, [754, 911]),
#  ('sadress', 1, [1017]),
#  ('enabl', 3, [229, 259, 628]),
#  ('folk', 1, [340]),
#  ('fems2017', 4, [55, 498, 809, 991]),
#  ('instal', 8, [115, 152, 155, 473, 517, 627, 853, 968]),
#  ('unsupervis', 1, [365]),
#  ('decaathlon', 1, [705]),
#  ('karni', 1, [608]),
#  ('gone', 1, [620]),
#  ('ktsakmakidi', 1, [728]),
#  ('httpstcoit0sbqlkqc', 1, [228]),
#  ('did', 3, [80, 142, 323]),
#  ('elastictim', 1, [247]),
#  ('salgado', 1, [231]),
#  ('climatechang', 2, [474, 1025]),
#  ('multimedia', 1, [114]),
#  ('httpstcothtcylrmtn', 1, [162]),
#  ('httpstco6tiu1sc7oi', 1, [601]),
#  ('madonna', 2, [240, 582]),
#  ('httpstcogxoftztum9', 1, [480]),
#  ('httpstcoupvwgqkpez', 1, [973]),
#  ('détermin', 1, [1031]),
#  ('arbr', 2, [543, 543]),
#  ('httpstconr3dbkmysp', 1, [399]),
#  ('algorithm', 4, [80, 100, 557, 572]),
#  ('epflcampu',
#   16,
#   [46,
#    239,
#    350,
#    371,
#    393,
#    574,
#    617,
#    715,
#    752,
#    763,
#    796,
#    806,
#    837,
#    1007,
#    1045,
#    1061]),
#  ('québec', 1, [1030]),
#  ('instagram', 1, [345]),
#  ('akademischen', 1, [188]),
#  ('down', 5, [173, 307, 719, 736, 854]),
#  ('plongé', 1, [456]),
#  ('mass', 2, [624, 745]),
#  ('archizoom', 1, [453]),
#  ...]
