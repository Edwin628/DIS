# %% [markdown]
# ## 📚 Exercise 2: Inverted Files
#
# In this exercise, we will understand the functioning of the Inverted Files and how implement them using MapReduce.
#
# ### Overview
#
# We learnt in the lecture that terms are typically stored in an inverted list. Now, in the inverted list, instead of only storing document identifiers of the documents in which the term appears, assume we also store an *offset* of the appearance of a term in a document. An $offset$ of a term $l_k$ given a document is defined as the number of words between the start of the document and $l_k$. Thus our inverted list is now:
#
# $l_k= \langle f_k: \{d_{i_1} \rightarrow [o_1,\ldots,o_{n_{i_1}}]\},
# \{d_{i_2} \rightarrow [o_1,\ldots,o_{n_{i_2}}]\}, \ldots,
# \{d_{i_k} \rightarrow [o_1,\ldots,o_{n_{i_k}}]\} \rangle$
#
# This means that in document $d_{i_1}$ term $l_k$ appears $n_{i_1}$ times and at offset $[o_1,\ldots,o_{n_{i_1}}]$, where $[o_1,\ldots,o_{n_{i_1}}]$ are sorted in ascending order, these type of indices are also known as term-offset indices. An example of a term-offset index is as follows:
#
# **Obama** = $⟨4 : {1 → [3]},{2 → [6]},{3 → [2,17]},{4 → [1]}⟩$
#
# **Governor** = $⟨2 : {4 → [3]}, {7 → [14]}⟩$
#
# **Election** = $⟨4 : {1 → [1]},{2 → [1,21]},{3 → [3]},{5 → [16,22,51]}⟩$
#
# Which is to say that the term **Governor** appear in 2 documents. In document 4 at offset 3, in document 7 at offset 14. Now let us consider the *SLOP/x* operator in text retrieval. This operator has the syntax: *QueryTerm1 SLOP/x QueryTerm2* finds occurrences of *QueryTerm1* within $x$ (but not necessarily in that order) words of *QueryTerm2*, where $x$ is a positive integer argument ($x \geq 1$). Thus $x = 1$ demands that *QueryTerm1* be adjacent to *QueryTerm2*.
#
# ### Questions
#
# 1. List the set of documents that satisfy the query **Obama** *SLOP/2* **Election**.
# 2. List each set of values for which the query **Obama** *SLOP/x* **Election** has a different set of documents as answers (starting from $x = 1$).
# 3. Consider the general procedure for "merging" two term-offset inverted lists for a given document, to determine where the document satisfies a *SLOP/x* clause (since in general there will be many offsets at which each term occurs in a document). Let $L$ denote the total number of occurrences of the two terms in the document. Assume we have a pointer to the list of occurrences of each term and can move the pointer along this list. As we do so we check whether we have a hit for $SLOP/x$ (i.e. the $SLOP/x$ clause is satisfied). Each move of either pointer counts as a step. Based on this assumption is there a general "merging" procedure to determine whether the document satisfies a $SLOP/x$ clause, for which the following is true? Justify your answer.
#
#     1. The merge can be accomplished in a number of steps linear in $L$ regardless of $x$, and we can ensure that each pointer moves only to the right (i.e. forward).
#     2. The merge can be accomplished in a number of steps linear in $L$, but a pointer may be forced to move to the left (i.e. backwards).
#     3. The merge can require $x \times L$ steps in some cases.

# %% [markdown]
# ## Create inverted files using MapReduce
# In this exercise, we want to create the inverted files using the MapReduce framework. Write the **map** and **reduce** function.
# Note that the code of **run_mapreduce** is just a simulation of the behavior of  map-reduce system.
#
# ## Goal:
# - Create inverted files using the MapReduce framework.
# - Test the implementation on `epfldocs.txt` data.
#
# ### What you are learning in this exercise:
# - Having a better understanding of inverted files.
# - Learn how to implement inverted files using the MapReduce framework.

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import string
from nltk.corpus import stopwords
import math
from collections import Counter
import numpy as np
nltk.download('stopwords')
nltk.download('punkt')

stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to /Users/aibin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/aibin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Tokenize, stem a document
def tokenize(text):
    """
    It tokenizes and stems an input text.
    
    :param text: str, with the input text
    :return: list, of the tokenized and stemmed tokens.
    """
    text = "".join([ch for ch in text if ch not in string.punctuation])
    tokens = nltk.word_tokenize(text)
    return " ".join([stemmer.stem(word.lower()) for word in tokens])

with open("epfldocs.txt") as f:
    content = f.readlines()
original_documents = [x.strip() for x in content] 
documents = [tokenize(d).split() for d in original_documents]
docs_n_doc_ids = list(zip(range(len(documents)), documents))

# %%
# Take a pair (doc_id, content). Example: (0, ['how', 'to', 'bake', 'bread', 'without', 'bake', 'recip'])
# Return: list of (word, doc_id). Example: ('bake', 0)
# For simplicity, we assume each mapper handles a document
def map_function(doc_id, content):
    keyvals = []
    for word in content:
        # YOUR CODE HERE
        keyvals.append((word,doc_id))
    return keyvals

# %%
# Take a list of pairs (word, doc_id). Example:  [('bake', 0), ('bake', 0), ('bake', 3)]
# Return: (word, frequency, list of document ids). Example ('bake', 3, [0, 0, 3])
# For simplicity, we assume each reducer handles a word
def reduce_function(lst):
    total = 0
    word = lst[0][0]
    doc_ids = []
    for w, doc_id in lst:
        assert(word==w) # Assume each reducer handles 1 word
        # YOUR CODE HERE
        total = total+1
        doc_ids.append(doc_id)
    return (word, total, doc_ids)

# %%
key_values = []
for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
# Shuffle phase
values = set(map(lambda x:x[0], key_values))
grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]

# %%
grouped_key_values
# Out:
# [[('verantwortung', 105)],
#  [('’', 13),
#   ('’', 32),
#   ('’', 44),
#   ('’', 58),
#   ('’', 58),
#   ('’', 60),
#   ('’', 62),
#   ('’', 107),
#   ('’', 123),
#   ('’', 144),
#   ('’', 152),
#   ('’', 197),
#   ('’', 197),
#   ('’', 243),
#   ('’', 243),
#   ('’', 243),
#   ('’', 248),
#   ('’', 278),
#   ('’', 282),
#   ('’', 282),
#   ('’', 282),
#   ('’', 337),
#   ('’', 363),
#   ('’', 373),
#   ('’', 388),
#   ('’', 403),
#   ('’', 411),
#   ('’', 414),
#   ('’', 414),
#   ('’', 453),
#   ('’', 473),
#   ('’', 495),
#   ('’', 517),
#   ('’', 532),
#   ('’', 543),
#   ('’', 584),
#   ('’', 589),
#   ('’', 604),
#   ('’', 610),
#   ('’', 610),
#   ('’', 627),
#   ('’', 627),
#   ('’', 627),
#   ('’', 627),
#   ('’', 630),
#   ('’', 644),
#   ('’', 665),
#   ('’', 684),
#   ('’', 691),
#   ('’', 691),
#   ('’', 692),
#   ('’', 710),
#   ('’', 723),
#   ('’', 731),
#   ('’', 755),
#   ('’', 770),
#   ('’', 770),
#   ('’', 800),
#   ('’', 817),
#   ('’', 821),
#   ('’', 843),
#   ('’', 843),
#   ('’', 849),
#   ('’', 849),
#   ('’', 851),
#   ('’', 853),
#   ('’', 861),
#   ('’', 862),
#   ('’', 862),
#   ('’', 901),
#   ('’', 935),
#   ('’', 958),
#   ('’', 968),
#   ('’', 975),
#   ('’', 1023),
#   ('’', 1025),
#   ('’', 1026),
#   ('’', 1026),
#   ('’', 1040),
#   ('’', 1067),
#   ('’', 1071)],
#  [('jaqu', 42)],
#  [('vert', 841)],
#  [('nextleap2020', 68)],
#  [('3', 53),
#   ('3', 538),
#   ('3', 555),
#   ('3', 840),
#   ('3', 894),
#   ('3', 989),
#   ('3', 1064)],
#  [('elektroden', 701)],
#  [('best', 14),
#   ('best', 77),
#   ('best', 277),
#   ('best', 348),
#   ('best', 493),
#   ('best', 531),
#   ('best', 560),
#   ('best', 691),
#   ('best', 875),
#   ('best', 995)],
#  [('spécifiqu', 742), ('spécifiqu', 840)],
#  [('httpstcos3gmguc9sf', 997)],
#  [('leg', 108), ('leg', 373)],
#  [('httpstconr6udhtjm', 211)],
#  [('httpstcoh4f3dhx6i9', 677)],
#  [('fribourg', 705)],
#  [('signal', 12), ('signal', 880)],
#  [('languag', 792)],
#  [('httpstcoptjukxxkk4', 79)],
#  [('epflcdm', 817)],
#  [('falt', 737)],
#  [('apprendr', 118),
#   ('apprendr', 311),
#   ('apprendr', 827),
#   ('apprendr', 827),
#   ('apprendr', 1026)],
#  [('httpstconiyyitetug', 852)],
#  [('attack', 547), ('attack', 880)],
#  [('suchamp', 180)],
#  [('gala', 1017)],
#  [('httpstco5hwwdcahxr', 206)],
#  [('httpstcootrxa96zfu', 100)],
#  [('httpstco2byw3asuc2', 267)],
#  [('httpstcoz2jnfclvgk', 305)],
#  [('—', 260)],
#  [('lavieparisienn', 190)],
#  [('size', 100), ('size', 280), ('size', 1044)],
#  [('rule', 291)],
#  [('lîle', 463)],
#  [('semiarid', 235)],
#  [('désormai', 16)],
#  [('wto', 637)],
#  [('unlik', 260)],
#  [('dsm', 522)],
#  [('fleshandblood', 216), ('fleshandblood', 634)],
#  [('httpstcoqzv4saerzq', 178)],
#  [('pathbas', 469)],
#  [('clo', 363)],
#  [('them', 109),
#   ('them', 259),
#   ('them', 458),
#   ('them', 577),
#   ('them', 641),
#   ('them', 679),
#   ('them', 679),
#   ('them', 691),
#   ('them', 778),
#   ('them', 899),
#   ('them', 938)],
#  [('httpstcobpnpc47k3l', 746)],
#  [('geomicrobiolog', 555)],
#  [('davo', 64), ('davo', 526), ('davo', 830)],
#  [('pari', 467), ('pari', 479), ('pari', 710)],
#  [('glass', 225), ('glass', 234)],
#  [('uzhnew', 50),
#   ('uzhnew', 391),
#   ('uzhnew', 580),
#   ('uzhnew', 759),
#   ('uzhnew', 890)],
#  [('satellit', 666)],
#  [('gt', 66),
#   ('gt', 210),
#   ('gt', 441),
#   ('gt', 492),
#   ('gt', 887),
#   ('gt', 1032)],
#  [('httpstconkj1g5q9ri', 999)],
#  [('coût', 283)],
#  [('httpstcohrx0n07gtj', 469)],
#  [('preventiteu', 588)],
#  [('line', 93), ('line', 589), ('line', 686), ('line', 1061)],
#  [('eu', 18), ('eu', 71), ('eu', 319), ('eu', 556), ('eu', 965)],
#  [('httpstcogxoftztum9', 480)],
#  [('serment', 862), ('serment', 862)],
#  [('nanoobjetsnanoparticul', 978)],
#  [('ashg17', 358)],
#  [('httpstcorm46e0v8gi', 628)],
#  [('avant', 197), ('avant', 207), ('avant', 543)],
#  [('technew', 414)],
#  [('httpstcokm1p7dnpr4', 919)],
#  [('assoc', 119)],
#  [('recrut', 592)],
#  [('cors', 906)],
#  [('🇨🇭', 241), ('🇨🇭', 382)],
#  [('httpstco4ldoldo6uw', 250)],
#  [('martian', 24), ('martian', 67), ('martian', 153), ('martian', 932)],
#  [('httpstcoxxxszgejwt', 934)],
#  [('institut', 28),
#   ('institut', 54),
#   ('institut', 220),
#   ('institut', 449),
#   ('institut', 579),
#   ('institut', 665),
#   ('institut', 675),
#   ('institut', 741),
#   ('institut', 799),
#   ('institut', 933),
#   ('institut', 937),
#   ('institut', 950),
#   ('institut', 984)],
#  [('proposai', 862)],
#  [('globu', 1011)],
#  [('besar', 1020)],
#  [('httpstco7g2w1geiz9', 860)],
#  [('zero', 869)],
#  [('kaust', 622), ('kaust', 741)],
#  [('readtoreef', 814)],
#  [('rtscqfd', 172), ('rtscqfd', 172)],
#  [('rüegg', 209)],
#  [('timeseri', 34), ('timeseri', 34)],
#  [('biomimétism', 599)],
#  [('dessu', 1071)],
#  [('bon', 168), ('bon', 325), ('bon', 682)],
#  [('lemondefr', 109)],
#  [('schleiss', 400), ('schleiss', 823), ('schleiss', 1067)],
#  [('vice', 875)],
#  [('fish', 249), ('fish', 254), ('fish', 414), ('fish', 414)],
#  [('appliedmlday', 34),
#   ('appliedmlday', 127),
#   ('appliedmlday', 276),
#   ('appliedmlday', 501),
#   ('appliedmlday', 503),
#   ('appliedmlday', 572),
#   ('appliedmlday', 605),
#   ('appliedmlday', 612)],
#  [('httpstco6utnj68psc', 5)],
#  [('carv', 256), ('carv', 389)],
#  [('httpstcopqqkry5ny9', 69)],
#  [('singl', 170),
#   ('singl', 436),
#   ('singl', 454),
#   ('singl', 695),
#   ('singl', 734),
#   ('singl', 957)],
#  [('httpstcocwmdckutob', 776)],
#  [('plongé', 456)],
#  [('han', 1015)],
#  [('co', 188)],
#  [('extinct', 112)],
#  [('latsi', 288)],
#  [('intens', 714)],
#  [('httpstcopnam80x8tn', 250)],
#  [('mass', 624), ('mass', 745)],
#  [('valeur', 325), ('valeur', 844)],
#  [('httpstcobanevqtrxf', 157)],
#  [('httpstcodtqvfwl3lj', 433)],
#  [('nsf', 697)],
#  [('gigant', 75)],
#  [('alor', 94)],
#  [('httpstcowt09cxhcaa', 1050)],
#  [('ist', 105), ('ist', 167), ('ist', 319)],
#  [('dnasequenc', 159)],
#  [('math', 903)],
#  [('lütolf', 425)],
#  [('immunotherapi', 349), ('immunotherapi', 529)],
#  [('httpstco9olqaib7vf', 375)],
#  [('femtoprint', 225)],
#  [('explan', 19)],
#  [('molecularscal', 303)],
#  [('clear', 65)],
#  [('httpstcoknqnghd6ma', 383)],
#  [('tout', 63), ('tout', 356), ('tout', 382), ('tout', 740)],
#  [('recour', 183)],
#  [('alumnu', 741)],
#  [('httpstcoudqn1rpspf', 1051)],
#  [('aitcamp', 953)],
#  [('vrtmedialab', 428)],
#  [('45th', 550)],
#  [('laboratoir', 123), ('laboratoir', 129)],
#  [('f', 107)],
#  [('httpstcoigikg8yrxi', 488)],
#  [('cet', 345), ('cet', 815), ('cet', 996)],
#  [('nicholasdemil', 741)],
#  [('helga', 210)],
#  [('hazard', 185), ('hazard', 526)],
#  [('httpstco5coubobbj1', 409)],
#  [('acquisit', 80)],
#  [('httpstcojs4tewsguh', 147)],
#  [('httpstcoxcrufbsg5a', 524)],
#  [('virtualr', 102), ('virtualr', 313), ('virtualr', 969)],
#  [('dubochet', 42),
#   ('dubochet', 238),
#   ('dubochet', 258),
#   ('dubochet', 265),
#   ('dubochet', 285),
#   ('dubochet', 720)],
#  [('physastro', 650)],
#  [('champel28', 1071)],
#  [('leaf', 237)],
#  [('inequ', 401)],
#  [('award', 48),
#   ('award', 77),
#   ('award', 137),
#   ('award', 179),
#   ('award', 230),
#   ('award', 237),
#   ('award', 293),
#   ('award', 380),
#   ('award', 403),
#   ('award', 434),
#   ('award', 489),
#   ('award', 688),
#   ('award', 767)],
#  [('epflev', 191),
#   ('epflev', 238),
#   ('epflev', 258),
#   ('epflev', 265),
#   ('epflev', 309),
#   ('epflev', 506),
#   ('epflev', 528),
#   ('epflev', 635),
#   ('epflev', 707),
#   ('epflev', 846)],
#  [('greenway', 841)],
#  [('québec', 1030)],
#  [('rôle', 488)],
#  [('réaménag', 1063)],
#  [('spheroid', 100)],
#  [('danish', 152),
#   ('danish', 473),
#   ('danish', 517),
#   ('danish', 853),
#   ('danish', 968)],
#  [('directeur', 182), ('directeur', 304), ('directeur', 958)],
#  [('dessou', 1071)],
#  [('electricvehicl', 642)],
#  [('tom', 119)],
#  [('differ', 176), ('differ', 648), ('differ', 734)],
#  [('africangeek', 233)],
#  [('smart', 39),
#   ('smart', 234),
#   ('smart', 510),
#   ('smart', 515),
#   ('smart', 537),
#   ('smart', 690),
#   ('smart', 693),
#   ('smart', 852)],
#  [('surround', 1032)],
#  [('haut', 919)],
#  [('epflpark', 3),
#   ('epflpark', 200),
#   ('epflpark', 432),
#   ('epflpark', 448),
#   ('epflpark', 589),
#   ('epflpark', 613)],
#  [('c', 175),
#   ('c', 294),
#   ('c', 294),
#   ('c', 468),
#   ('c', 468),
#   ('c', 627),
#   ('c', 627)],
#  [('dan', 81),
#   ('dan', 172),
#   ('dan', 345),
#   ('dan', 382),
#   ('dan', 456),
#   ('dan', 548),
#   ('dan', 554),
#   ('dan', 570),
#   ('dan', 610),
#   ('dan', 665),
#   ('dan', 739),
#   ('dan', 789),
#   ('dan', 825),
#   ('dan', 844),
#   ('dan', 860),
#   ('dan', 876),
#   ('dan', 976),
#   ('dan', 977),
#   ('dan', 983),
#   ('dan', 996)],
#  [('fli', 124), ('fli', 711)],
#  [('pollut', 145), ('pollut', 926), ('pollut', 1008)],
#  [('univers', 4),
#   ('univers', 13),
#   ('univers', 64),
#   ('univers', 71),
#   ('univers', 121),
#   ('univers', 139),
#   ('univers', 195),
#   ('univers', 294),
#   ('univers', 468),
#   ('univers', 482),
#   ('univers', 531),
#   ('univers', 632),
#   ('univers', 648),
#   ('univers', 686),
#   ('univers', 759),
#   ('univers', 759),
#   ('univers', 812),
#   ('univers', 817),
#   ('univers', 912),
#   ('univers', 912),
#   ('univers', 934),
#   ('univers', 944),
#   ('univers', 995)],
#  [('httpstcoixjnhrirwi', 97)],
#  [('participez', 571)],
#  [('httpstcoydtazxvv5g', 317)],
#  [('planar', 36)],
#  [('vtol', 124)],
#  [('popular', 407), ('popular', 490), ('popular', 1056)],
#  [('objectif', 996)],
#  [('vont', 1026)],
#  [('mynyonregion', 192)],
#  [('pattern', 6), ('pattern', 387)],
#  [('special', 259)],
#  [('tlemberg', 629)],
#  [('konrad', 785)],
#  [('vacanc', 81)],
#  [('cio', 1037), ('cio', 1042)],
#  [('httpstcowuuplby1uj', 261)],
#  [('resid', 210)],
#  [('stabl', 268), ('stabl', 485), ('stabl', 628)],
#  [('myself', 612)],
#  [('strategi', 60), ('strategi', 166), ('strategi', 291), ('strategi', 704)],
#  [('growth', 143)],
#  [('style', 413), ('style', 682), ('style', 682)],
#  [('solv', 104), ('solv', 114), ('solv', 728)],
#  [('professorship', 850)],
#  [('actuallywork', 224)],
#  [('infra', 520)],
#  [('formul', 740)],
#  [('httpstcolakv7l5brm', 290)],
#  [('prepar', 343)],
#  [('httpstcobymmkjagz1', 1042)],
#  [('uefa', 128), ('uefa', 291), ('uefa', 992)],
#  [('aux', 129),
#   ('aux', 161),
#   ('aux', 161),
#   ('aux', 261),
#   ('aux', 297),
#   ('aux', 405),
#   ('aux', 424),
#   ('aux', 439),
#   ('aux', 710),
#   ('aux', 742),
#   ('aux', 773),
#   ('aux', 1020),
#   ('aux', 1026)],
#  [('transact', 407)],
#  [('ai', 21),
#   ('ai', 27),
#   ('ai', 50),
#   ('ai', 97),
#   ('ai', 165),
#   ('ai', 181),
#   ('ai', 198),
#   ('ai', 236),
#   ('ai', 323),
#   ('ai', 414),
#   ('ai', 448),
#   ('ai', 501),
#   ('ai', 534),
#   ('ai', 580),
#   ('ai', 581),
#   ('ai', 610),
#   ('ai', 692),
#   ('ai', 722),
#   ('ai', 747),
#   ('ai', 765),
#   ('ai', 899),
#   ('ai', 946),
#   ('ai', 999)],
#  [('beibringen', 701)],
#  [('bluebrain', 796)],
#  [('articl', 74),
#   ('articl', 103),
#   ('articl', 243),
#   ('articl', 407),
#   ('articl', 526),
#   ('articl', 705),
#   ('articl', 808),
#   ('articl', 844),
#   ('articl', 856),
#   ('articl', 905),
#   ('articl', 986)],
#  [('increas', 470)],
#  [('rive', 167), ('rive', 252)],
#  [('httpstcoj3gzqu9pqa', 705)],
#  [('httpstcoarbz9t2dzx', 181)],
#  [('httpstcojgq7umgzgi', 378)],
#  [('aleaf', 237)],
#  [('httpstcoun7wlrhkna', 156)],
#  [('httpstcosi9sz9cxpv', 257)],
#  [('ecommerc', 733)],
#  [('label', 557)],
#  [('evalu', 101), ('evalu', 469)],
#  [('httpstcoud2auxd5', 820)],
#  [('51', 272)],
#  [('httpstco23kjig8pxt', 1)],
#  [('mini3d', 544)],
#  [('terrywinn', 419)],
#  [('vou', 144),
#   ('vou', 174),
#   ('vou', 197),
#   ('vou', 265),
#   ('vou', 277),
#   ('vou', 325),
#   ('vou', 342),
#   ('vou', 345),
#   ('vou', 402),
#   ('vou', 467),
#   ('vou', 467),
#   ('vou', 659),
#   ('vou', 665),
#   ('vou', 860),
#   ('vou', 920),
#   ('vou', 988),
#   ('vou', 1030),
#   ('vou', 1039),
#   ('vou', 1066)],
#  [('scientistswhoselfi', 288)],
#  [('tournent', 244)],
#  [('infect', 352), ('infect', 696), ('infect', 922)],
#  [('polic', 122),
#   ('polic', 163),
#   ('polic', 278),
#   ('polic', 979),
#   ('polic', 979)],
#  [('stop', 131), ('stop', 134), ('stop', 142), ('stop', 532), ('stop', 997)],
#  [('httpstcod7slk6ruat', 742)],
#  [('formid', 12)],
#  [('artlab', 174), ('artlab', 363), ('artlab', 895)],
#  [('hubert', 424)],
#  [('room', 419), ('room', 513)],
#  [('httpstcotavirrwpkc', 178)],
#  [('httpstco9fgitpnf', 572)],
#  [('synthesi', 334), ('synthesi', 807)],
#  [('undergrad', 88)],
#  [('crew', 474)],
#  [('epfl', 2),
#   ('epfl', 4),
#   ('epfl', 5),
#   ('epfl', 6),
#   ('epfl', 8),
#   ('epfl', 9),
#   ('epfl', 10),
#   ('epfl', 11),
#   ('epfl', 15),
#   ('epfl', 16),
#   ('epfl', 18),
#   ('epfl', 20),
#   ('epfl', 22),
#   ('epfl', 23),
#   ('epfl', 25),
#   ('epfl', 26),
#   ('epfl', 27),
#   ('epfl', 28),
#   ('epfl', 29),
#   ('epfl', 31),
#   ('epfl', 31),
#   ('epfl', 32),
#   ('epfl', 33),
#   ('epfl', 34),
#   ('epfl', 40),
#   ('epfl', 40),
#   ('epfl', 42),
#   ('epfl', 43),
#   ('epfl', 44),
#   ('epfl', 46),
#   ('epfl', 47),
#   ('epfl', 49),
#   ('epfl', 52),
#   ('epfl', 57),
#   ('epfl', 59),
#   ('epfl', 60),
#   ('epfl', 61),
#   ('epfl', 62),
#   ('epfl', 63),
#   ('epfl', 64),
#   ('epfl', 68),
#   ('epfl', 69),
#   ('epfl', 70),
#   ('epfl', 74),
#   ('epfl', 75),
#   ('epfl', 77),
#   ('epfl', 81),
#   ('epfl', 83),
#   ('epfl', 85),
#   ('epfl', 86),
#   ('epfl', 87),
#   ('epfl', 88),
#   ('epfl', 90),
#   ('epfl', 92),
#   ('epfl', 93),
#   ('epfl', 96),
#   ('epfl', 98),
#   ('epfl', 102),
#   ('epfl', 104),
#   ('epfl', 105),
#   ('epfl', 106),
#   ('epfl', 107),
#   ('epfl', 107),
#   ('epfl', 108),
#   ('epfl', 109),
#   ('epfl', 112),
#   ('epfl', 115),
#   ('epfl', 116),
#   ('epfl', 117),
#   ('epfl', 118),
#   ('epfl', 123),
#   ('epfl', 124),
#   ('epfl', 125),
#   ('epfl', 126),
#   ('epfl', 129),
#   ('epfl', 130),
#   ('epfl', 131),
#   ('epfl', 132),
#   ('epfl', 133),
#   ('epfl', 135),
#   ('epfl', 136),
#   ('epfl', 137),
#   ('epfl', 138),
#   ('epfl', 141),
#   ('epfl', 143),
#   ('epfl', 144),
#   ('epfl', 145),
#   ('epfl', 149),
#   ('epfl', 150),
#   ('epfl', 154),
#   ('epfl', 157),
#   ('epfl', 158),
#   ('epfl', 160),
#   ('epfl', 161),
#   ('epfl', 162),
#   ('epfl', 163),
#   ('epfl', 164),
#   ('epfl', 165),
#   ('epfl', 166),
#   ('epfl', 167),
#   ('epfl', 168),
#   ('epfl', 168),
#   ('epfl', 171),
#   ('epfl', 171),
#   ('epfl', 172),
#   ('epfl', 174),
#   ('epfl', 174),
#   ('epfl', 175),
#   ('epfl', 176),
#   ('epfl', 177),
#   ('epfl', 178),
#   ('epfl', 180),
#   ('epfl', 181),
#   ('epfl', 183),
#   ('epfl', 184),
#   ('epfl', 185),
#   ('epfl', 188),
#   ('epfl', 188),
#   ('epfl', 189),
#   ('epfl', 190),
#   ('epfl', 191),
#   ('epfl', 191),
#   ('epfl', 192),
#   ('epfl', 193),
#   ('epfl', 194),
#   ('epfl', 197),
#   ('epfl', 197),
#   ('epfl', 201),
#   ('epfl', 202),
#   ('epfl', 203),
#   ('epfl', 205),
#   ('epfl', 207),
#   ('epfl', 208),
#   ('epfl', 209),
#   ('epfl', 210),
#   ('epfl', 212),
#   ('epfl', 213),
#   ('epfl', 215),
#   ('epfl', 216),
#   ('epfl', 217),
#   ('epfl', 218),
#   ('epfl', 220),
#   ('epfl', 225),
#   ('epfl', 226),
#   ('epfl', 229),
#   ('epfl', 230),
#   ('epfl', 231),
#   ('epfl', 232),
#   ('epfl', 233),
#   ('epfl', 238),
#   ('epfl', 239),
#   ('epfl', 241),
#   ('epfl', 243),
#   ('epfl', 244),
#   ('epfl', 245),
#   ('epfl', 246),
#   ('epfl', 247),
#   ('epfl', 248),
#   ('epfl', 249),
#   ('epfl', 250),
#   ('epfl', 250),
#   ('epfl', 252),
#   ('epfl', 253),
#   ('epfl', 255),
#   ('epfl', 255),
#   ('epfl', 258),
#   ('epfl', 259),
#   ('epfl', 260),
#   ('epfl', 261),
#   ('epfl', 262),
#   ('epfl', 264),
#   ('epfl', 265),
#   ('epfl', 266),
#   ('epfl', 267),
#   ('epfl', 268),
#   ('epfl', 272),
#   ('epfl', 273),
#   ('epfl', 274),
#   ('epfl', 275),
#   ('epfl', 276),
#   ('epfl', 280),
#   ('epfl', 282),
#   ('epfl', 283),
#   ('epfl', 284),
#   ('epfl', 287),
#   ('epfl', 289),
#   ('epfl', 290),
#   ('epfl', 291),
#   ('epfl', 292),
#   ('epfl', 296),
#   ('epfl', 297),
#   ('epfl', 299),
#   ('epfl', 300),
#   ('epfl', 301),
#   ('epfl', 302),
#   ('epfl', 303),
#   ('epfl', 304),
#   ('epfl', 306),
#   ('epfl', 307),
#   ('epfl', 309),
#   ('epfl', 310),
#   ('epfl', 310),
#   ('epfl', 311),
#   ('epfl', 312),
#   ('epfl', 313),
#   ('epfl', 314),
#   ('epfl', 315),
#   ('epfl', 316),
#   ('epfl', 317),
#   ('epfl', 320),
#   ('epfl', 322),
#   ('epfl', 323),
#   ('epfl', 325),
#   ('epfl', 326),
#   ('epfl', 327),
#   ('epfl', 329),
#   ('epfl', 330),
#   ('epfl', 331),
#   ('epfl', 334),
#   ('epfl', 335),
#   ('epfl', 339),
#   ('epfl', 342),
#   ('epfl', 343),
#   ('epfl', 345),
#   ('epfl', 347),
#   ('epfl', 350),
#   ('epfl', 351),
#   ('epfl', 352),
#   ('epfl', 353),
#   ('epfl', 356),
#   ('epfl', 357),
#   ('epfl', 359),
#   ('epfl', 360),
#   ('epfl', 362),
#   ('epfl', 363),
#   ('epfl', 366),
#   ('epfl', 367),
#   ('epfl', 368),
#   ('epfl', 369),
#   ('epfl', 370),
#   ('epfl', 371),
#   ('epfl', 371),
#   ('epfl', 373),
#   ('epfl', 375),
#   ('epfl', 378),
#   ('epfl', 380),
#   ('epfl', 381),
#   ('epfl', 382),
#   ('epfl', 383),
#   ('epfl', 384),
#   ('epfl', 386),
#   ('epfl', 387),
#   ('epfl', 388),
#   ('epfl', 390),
#   ('epfl', 390),
#   ('epfl', 391),
#   ('epfl', 393),
#   ('epfl', 402),
#   ('epfl', 403),
#   ('epfl', 404),
#   ('epfl', 405),
#   ('epfl', 407),
#   ('epfl', 408),
#   ('epfl', 409),
#   ('epfl', 411),
#   ('epfl', 413),
#   ('epfl', 416),
#   ('epfl', 419),
#   ('epfl', 423),
#   ('epfl', 424),
#   ('epfl', 427),
#   ('epfl', 428),
#   ('epfl', 429),
#   ('epfl', 431),
#   ('epfl', 432),
#   ('epfl', 435),
#   ('epfl', 436),
#   ('epfl', 437),
#   ('epfl', 438),
#   ('epfl', 439),
#   ('epfl', 440),
#   ('epfl', 440),
#   ('epfl', 443),
#   ('epfl', 444),
#   ('epfl', 444),
#   ('epfl', 446),
#   ('epfl', 448),
#   ('epfl', 449),
#   ('epfl', 451),
#   ('epfl', 452),
#   ('epfl', 453),
#   ('epfl', 454),
#   ('epfl', 455),
#   ('epfl', 456),
#   ('epfl', 458),
#   ('epfl', 459),
#   ('epfl', 460),
#   ('epfl', 462),
#   ('epfl', 463),
#   ('epfl', 464),
#   ('epfl', 466),
#   ('epfl', 467),
#   ('epfl', 470),
#   ('epfl', 471),
#   ('epfl', 472),
#   ('epfl', 475),
#   ('epfl', 476),
#   ('epfl', 477),
#   ('epfl', 479),
#   ('epfl', 481),
#   ('epfl', 487),
#   ('epfl', 488),
#   ('epfl', 489),
#   ('epfl', 491),
#   ('epfl', 492),
#   ('epfl', 494),
#   ('epfl', 494),
#   ('epfl', 495),
#   ('epfl', 496),
#   ('epfl', 497),
#   ('epfl', 500),
#   ('epfl', 501),
#   ('epfl', 503),
#   ('epfl', 506),
#   ('epfl', 509),
#   ('epfl', 509),
#   ('epfl', 514),
#   ('epfl', 518),
#   ('epfl', 523),
#   ('epfl', 525),
#   ('epfl', 526),
#   ('epfl', 528),
#   ('epfl', 529),
#   ('epfl', 533),
#   ('epfl', 536),
#   ('epfl', 536),
#   ('epfl', 537),
#   ('epfl', 540),
#   ('epfl', 541),
#   ('epfl', 543),
#   ('epfl', 544),
#   ('epfl', 545),
#   ('epfl', 545),
#   ('epfl', 547),
#   ('epfl', 550),
#   ('epfl', 551),
#   ('epfl', 552),
#   ('epfl', 553),
#   ('epfl', 553),
#   ('epfl', 554),
#   ('epfl', 555),
#   ('epfl', 556),
#   ('epfl', 559),
#   ('epfl', 563),
#   ('epfl', 564),
#   ('epfl', 565),
#   ('epfl', 566),
#   ('epfl', 567),
#   ('epfl', 568),
#   ('epfl', 569),
#   ('epfl', 570),
#   ('epfl', 571),
#   ('epfl', 572),
#   ('epfl', 573),
#   ('epfl', 574),
#   ('epfl', 575),
#   ('epfl', 577),
#   ('epfl', 578),
#   ('epfl', 585),
#   ('epfl', 586),
#   ('epfl', 588),
#   ('epfl', 589),
#   ('epfl', 592),
#   ('epfl', 593),
#   ('epfl', 594),
#   ('epfl', 596),
#   ('epfl', 599),
#   ('epfl', 604),
#   ('epfl', 607),
#   ('epfl', 609),
#   ('epfl', 610),
#   ('epfl', 611),
#   ('epfl', 614),
#   ('epfl', 617),
#   ('epfl', 618),
#   ('epfl', 618),
#   ('epfl', 619),
#   ('epfl', 621),
#   ('epfl', 623),
#   ('epfl', 625),
#   ('epfl', 626),
#   ('epfl', 627),
#   ('epfl', 628),
#   ('epfl', 629),
#   ('epfl', 631),
#   ('epfl', 632),
#   ('epfl', 633),
#   ('epfl', 634),
#   ('epfl', 636),
#   ('epfl', 638),
#   ('epfl', 640),
#   ('epfl', 644),
#   ('epfl', 647),
#   ('epfl', 648),
#   ('epfl', 650),
#   ('epfl', 651),
#   ('epfl', 653),
#   ('epfl', 654),
#   ('epfl', 655),
#   ('epfl', 658),
#   ('epfl', 662),
#   ('epfl', 663),
#   ('epfl', 663),
#   ('epfl', 665),
#   ('epfl', 666),
#   ('epfl', 667),
#   ('epfl', 672),
#   ('epfl', 673),
#   ('epfl', 674),
#   ('epfl', 676),
#   ('epfl', 677),
#   ('epfl', 677),
#   ('epfl', 679),
#   ('epfl', 681),
#   ('epfl', 682),
#   ('epfl', 684),
#   ('epfl', 685),
#   ('epfl', 688),
#   ('epfl', 689),
#   ('epfl', 690),
#   ('epfl', 695),
#   ('epfl', 696),
#   ('epfl', 697),
#   ('epfl', 698),
#   ('epfl', 700),
#   ('epfl', 700),
#   ('epfl', 701),
#   ('epfl', 705),
#   ('epfl', 706),
#   ('epfl', 710),
#   ('epfl', 711),
#   ('epfl', 713),
#   ('epfl', 715),
#   ('epfl', 716),
#   ('epfl', 719),
#   ('epfl', 723),
#   ('epfl', 724),
#   ('epfl', 726),
#   ('epfl', 727),
#   ('epfl', 728),
#   ('epfl', 729),
#   ('epfl', 730),
#   ('epfl', 731),
#   ('epfl', 733),
#   ('epfl', 734),
#   ('epfl', 735),
#   ('epfl', 737),
#   ('epfl', 739),
#   ('epfl', 742),
#   ('epfl', 743),
#   ('epfl', 744),
#   ('epfl', 745),
#   ('epfl', 746),
#   ('epfl', 747),
#   ('epfl', 748),
#   ('epfl', 749),
#   ('epfl', 749),
#   ('epfl', 750),
#   ('epfl', 752),
#   ('epfl', 755),
#   ('epfl', 756),
#   ('epfl', 757),
#   ('epfl', 762),
#   ('epfl', 763),
#   ('epfl', 763),
#   ('epfl', 765),
#   ('epfl', 767),
#   ('epfl', 770),
#   ('epfl', 773),
#   ('epfl', 774),
#   ('epfl', 775),
#   ('epfl', 776),
#   ('epfl', 780),
#   ('epfl', 781),
#   ('epfl', 782),
#   ('epfl', 783),
#   ('epfl', 784),
#   ('epfl', 785),
#   ('epfl', 786),
#   ('epfl', 787),
#   ('epfl', 788),
#   ('epfl', 791),
#   ('epfl', 794),
#   ('epfl', 795),
#   ('epfl', 796),
#   ('epfl', 796),
#   ('epfl', 797),
#   ('epfl', 798),
#   ('epfl', 799),
#   ('epfl', 800),
#   ('epfl', 800),
#   ('epfl', 801),
#   ('epfl', 804),
#   ('epfl', 805),
#   ('epfl', 806),
#   ('epfl', 807),
#   ('epfl', 808),
#   ('epfl', 810),
#   ('epfl', 814),
#   ('epfl', 815),
#   ('epfl', 817),
#   ('epfl', 819),
#   ('epfl', 820),
#   ('epfl', 821),
#   ('epfl', 822),
#   ('epfl', 823),
#   ('epfl', 824),
#   ('epfl', 825),
#   ('epfl', 826),
#   ('epfl', 827),
#   ('epfl', 828),
#   ('epfl', 829),
#   ('epfl', 830),
#   ('epfl', 832),
#   ('epfl', 835),
#   ('epfl', 836),
#   ('epfl', 837),
#   ('epfl', 841),
#   ('epfl', 842),
#   ('epfl', 843),
#   ('epfl', 844),
#   ('epfl', 846),
#   ('epfl', 847),
#   ('epfl', 848),
#   ('epfl', 849),
#   ('epfl', 850),
#   ('epfl', 851),
#   ('epfl', 855),
#   ('epfl', 859),
#   ('epfl', 860),
#   ('epfl', 860),
#   ('epfl', 861),
#   ('epfl', 862),
#   ('epfl', 863),
#   ('epfl', 864),
#   ('epfl', 866),
#   ('epfl', 870),
#   ('epfl', 871),
#   ('epfl', 872),
#   ('epfl', 873),
#   ('epfl', 874),
#   ('epfl', 876),
#   ('epfl', 878),
#   ('epfl', 881),
#   ('epfl', 882),
#   ('epfl', 885),
#   ('epfl', 885),
#   ('epfl', 886),
#   ('epfl', 887),
#   ('epfl', 889),
#   ('epfl', 890),
#   ('epfl', 892),
#   ('epfl', 893),
#   ('epfl', 894),
#   ('epfl', 895),
#   ('epfl', 896),
#   ('epfl', 899),
#   ('epfl', 900),
#   ('epfl', 901),
#   ('epfl', 902),
#   ('epfl', 903),
#   ('epfl', 904),
#   ('epfl', 905),
#   ('epfl', 906),
#   ('epfl', 907),
#   ('epfl', 908),
#   ('epfl', 911),
#   ('epfl', 913),
#   ('epfl', 915),
#   ('epfl', 919),
#   ('epfl', 920),
#   ('epfl', 921),
#   ('epfl', 922),
#   ('epfl', 923),
#   ('epfl', 924),
#   ('epfl', 925),
#   ('epfl', 926),
#   ('epfl', 928),
#   ('epfl', 929),
#   ('epfl', 930),
#   ('epfl', 931),
#   ('epfl', 935),
#   ('epfl', 940),
#   ('epfl', 941),
#   ('epfl', 942),
#   ('epfl', 944),
#   ('epfl', 945),
#   ('epfl', 946),
#   ('epfl', 946),
#   ('epfl', 947),
#   ('epfl', 948),
#   ('epfl', 950),
#   ('epfl', 951),
#   ('epfl', 952),
#   ('epfl', 953),
#   ('epfl', 954),
#   ('epfl', 955),
#   ('epfl', 956),
#   ('epfl', 958),
#   ('epfl', 959),
#   ('epfl', 960),
#   ('epfl', 961),
#   ('epfl', 962),
#   ('epfl', 964),
#   ('epfl', 964),
#   ('epfl', 967),
#   ('epfl', 969),
#   ('epfl', 971),
#   ('epfl', 974),
#   ('epfl', 975),
#   ('epfl', 976),
#   ('epfl', 977),
#   ('epfl', 978),
#   ('epfl', 979),
#   ('epfl', 981),
#   ('epfl', 983),
#   ('epfl', 985),
#   ('epfl', 985),
#   ('epfl', 986),
#   ('epfl', 988),
#   ('epfl', 989),
#   ('epfl', 990),
#   ('epfl', 996),
#   ('epfl', 1001),
#   ('epfl', 1003),
#   ('epfl', 1003),
#   ('epfl', 1004),
#   ('epfl', 1005),
#   ('epfl', 1008),
#   ('epfl', 1009),
#   ('epfl', 1010),
#   ('epfl', 1013),
#   ('epfl', 1015),
#   ('epfl', 1016),
#   ('epfl', 1017),
#   ('epfl', 1018),
#   ('epfl', 1019),
#   ('epfl', 1020),
#   ('epfl', 1021),
#   ('epfl', 1022),
#   ('epfl', 1023),
#   ('epfl', 1024),
#   ('epfl', 1025),
#   ('epfl', 1026),
#   ('epfl', 1030),
#   ('epfl', 1031),
#   ('epfl', 1032),
#   ('epfl', 1033),
#   ('epfl', 1034),
#   ('epfl', 1035),
#   ('epfl', 1036),
#   ('epfl', 1037),
#   ('epfl', 1038),
#   ('epfl', 1039),
#   ('epfl', 1040),
#   ('epfl', 1041),
#   ('epfl', 1042),
#   ('epfl', 1043),
#   ('epfl', 1044),
#   ('epfl', 1045),
#   ('epfl', 1045),
#   ('epfl', 1046),
#   ('epfl', 1047),
#   ('epfl', 1048),
#   ('epfl', 1049),
#   ('epfl', 1050),
#   ('epfl', 1051),
#   ('epfl', 1052),
#   ('epfl', 1053),
#   ('epfl', 1054),
#   ('epfl', 1060),
#   ('epfl', 1061),
#   ('epfl', 1061),
#   ('epfl', 1062),
#   ('epfl', 1063),
#   ('epfl', 1064),
#   ('epfl', 1065),
#   ('epfl', 1066),
#   ('epfl', 1067),
#   ('epfl', 1068),
#   ('epfl', 1069),
#   ('epfl', 1070),
#   ('epfl', 1071),
#   ('epfl', 1071)],
#  [('turn', 333), ('turn', 360), ('turn', 396), ('turn', 722)],
#  [('trump', 556), ('trump', 620), ('trump', 1054)],
#  [('zia', 935)],
#  [('alzheim', 131),
#   ('alzheim', 149),
#   ('alzheim', 264),
#   ('alzheim', 532),
#   ('alzheim', 879),
#   ('alzheim', 997)],
#  [('thermiqu', 322)],
#  [('dphroy', 735)],
#  [('25novemb', 774)],
#  [('httpstco0xczhd4kon', 949)],
#  [('yqi', 293)],
#  [('worldbrailleday', 878)],
#  [('honneur', 843)],
#  [('faessler', 552)],
#  [('feedback', 668), ('feedback', 708), ('feedback', 864)],
#  [('httpstcodgxoj2dafk', 219)],
#  [('love', 125),
#   ('love', 263),
#   ('love', 418),
#   ('love', 466),
#   ('love', 624),
#   ('love', 743)],
#  [('httpstcoly2nor8i6m', 756)],
#  [('120', 175)],
#  [('cafe', 1032)],
#  [('httpstcofnu3wqtnd3', 306)],
#  [('tortur', 122),
#   ('tortur', 122),
#   ('tortur', 163),
#   ('tortur', 240),
#   ('tortur', 979)],
#  [('httpstconpcumuigef', 342)],
#  [('parl', 357), ('parl', 844)],
#  [('nm2', 135)],
#  [('découvert', 266), ('découvert', 895)],
#  [('lacadémi', 1022)],
#  [('théoriqu', 61)],
#  [('bibliothécair', 94)],
#  [('magistral', 257)],
#  [('kellyannepol', 637)],
#  [('glad', 269), ('glad', 428)],
#  [('httpstco7q3ofxp28a', 311)],
#  [('httpstco00omllvto8', 136)],
#  [('neighbor', 66)],
#  [('karen', 748)],
#  [('mélodi', 942)],
#  [('débrouillé', 548)],
#  [('learn', 33),
#   ('learn', 60),
#   ('learn', 176),
#   ('learn', 194),
#   ('learn', 208),
#   ('learn', 229),
#   ('learn', 231),
#   ('learn', 337),
#   ('learn', 347),
#   ('learn', 347),
#   ('learn', 390),
#   ('learn', 390),
#   ('learn', 411),
#   ('learn', 426),
#   ('learn', 464),
#   ('learn', 587),
#   ('learn', 600),
#   ('learn', 613),
#   ('learn', 623),
#   ('learn', 747),
#   ('learn', 859),
#   ('learn', 872),
#   ('learn', 888),
#   ('learn', 899),
#   ('learn', 974),
#   ('learn', 1009),
#   ('learn', 1048)],
#  [('top10', 686), ('top10', 767)],
#  [('reçoit', 752)],
#  [('japanimpact', 144), ('japanimpact', 342)],
#  [('lunil', 925)],
#  [('relev', 262)],
#  [('juli', 222)],
#  [('psf', 80), ('psf', 80), ('psf', 685), ('psf', 685)],
#  [('microbiolog', 378)],
#  [('httpstcoi5lwefylxm', 914)],
#  [('securityprivaci', 640)],
#  [('httpstcovlxoltnhwo', 807)],
#  [('plane', 108), ('plane', 108)],
#  [('27', 13), ('27', 633)],
#  [('coeur', 207)],
#  [('decor', 719)],
#  [('nouveaux', 357), ('nouveaux', 408)],
#  [('🇨🇭merci', 26)],
#  [('httpstco6uwi3r9ku', 587)],
#  [('httpstco3rmmobhido', 436)],
#  [('grante', 717)],
#  [('nomin', 778), ('nomin', 1006)],
#  [('httpstcoaaiitfl6ji', 741)],
#  [('sothebi', 849)],
#  [('programm', 56),
#   ('programm', 167),
#   ('programm', 233),
#   ('programm', 252),
#   ('programm', 342),
#   ('programm', 347),
#   ('programm', 382),
#   ('programm', 495),
#   ('programm', 677),
#   ('programm', 742),
#   ('programm', 742),
#   ('programm', 958)],
#  [('arbeitsplätz', 425)],
#  [('allègrement', 927)],
#  [('abbschweizag', 425)],
#  [('httpstco3jd6ff6a9z', 191)],
#  [('httpstcorkcvwo6k2p', 182)],
#  [('httpstcosmokpqawtf', 510)],
#  [('packag', 624)],
#  [('nevertheless', 66)],
#  [('ferdinand', 927)],
#  [('httpstcot528zfgtmn', 23)],
#  [('mess', 48)],
#  [('cargo', 124), ('cargo', 604)],
#  [('laureat', 434)],
#  [('httpstcou09m0mpdu', 396)],
#  [('materialwissenschaft', 309)],
#  [('cortexia', 383)],
#  [('ehmicrobiomes2017', 119)],
#  [('httpstcomtl9l8rnev', 280)],
#  [('fakenew', 27)],
#  [('httpstco1ktfeyqze6', 904)],
#  [('httpstcozie2dckwsg', 1055)],
#  [('steven', 746)],
#  [('esmtelecom', 559)],
#  [('httpstcopntoznv3jk', 397)],
#  [('egiannoni', 922)],
#  [('aussi', 51), ('aussi', 610), ('aussi', 925)],
#  [('🔪', 655)],
#  [('ces2018', 387)],
#  [('httpstcoxuzpa1rzzt', 591)],
#  [('chronic', 907)],
#  [('httpstcofzvdm86ntf', 1002)],
#  [('anoth', 58), ('anoth', 272), ('anoth', 858)],
#  [('5060', 1068)],
#  [('danss', 1030)],
#  [('point', 108),
#   ('point', 175),
#   ('point', 251),
#   ('point', 272),
#   ('point', 292),
#   ('point', 312),
#   ('point', 1067)],
#  [('réell', 794)],
#  [('feasibl', 101)],
#  [('novemb', 9)],
#  [('youtubechanel', 637)],
#  [('har', 666)],
#  [('0203', 569)],
#  [('badcompani', 85)],
#  [('april', 30), ('april', 479), ('april', 642), ('april', 990)],
#  [('fischerconnect', 492)],
#  [('crossdress', 529)],
#  [('httpstcoptubxymebp', 949)],
#  [('innov', 27),
#   ('innov', 48),
#   ('innov', 71),
#   ('innov', 106),
#   ('innov', 140),
#   ('innov', 156),
#   ('innov', 229),
#   ('innov', 241),
#   ('innov', 243),
#   ('innov', 273),
#   ('innov', 283),
#   ('innov', 304),
#   ('innov', 341),
#   ('innov', 448),
#   ('innov', 464),
#   ('innov', 549),
#   ('innov', 576),
#   ('innov', 589),
#   ('innov', 644),
#   ('innov', 677),
#   ('innov', 688),
#   ('innov', 702),
#   ('innov', 711),
#   ('innov', 714),
#   ('innov', 748),
#   ('innov', 780),
#   ('innov', 848),
#   ('innov', 881),
#   ('innov', 912),
#   ('innov', 915),
#   ('innov', 924),
#   ('innov', 1007),
#   ('innov', 1041),
#   ('innov', 1070)],
#  [('ecol', 98), ('ecol', 596), ('ecol', 841)],
#  [('thank', 108),
#   ('thank', 113),
#   ('thank', 218),
#   ('thank', 232),
#   ('thank', 245),
#   ('thank', 247),
#   ('thank', 259),
#   ('thank', 307),
#   ('thank', 315),
#   ('thank', 337),
#   ('thank', 341),
#   ('thank', 353),
#   ('thank', 399),
#   ('thank', 446),
#   ('thank', 460),
#   ('thank', 496),
#   ('thank', 516),
#   ('thank', 522),
#   ('thank', 552),
#   ('thank', 724),
#   ('thank', 747),
#   ('thank', 764),
#   ('thank', 810),
#   ('thank', 938),
#   ('thank', 938),
#   ('thank', 1002),
#   ('thank', 1005)],
#  [('httpstcognraozl2zh', 521)],
#  [('manif', 988)],
#  [('rock', 621)],
#  [('httpstcosoiiictqnr', 70)],
#  [('httpstcozxoxqotnii', 714)],
#  [('shouldnt', 556)],
#  [('donn', 644)],
#  [('enacresearchday', 931)],
#  [('knecht', 137), ('knecht', 506)],
#  [('ouvron', 282)],
#  [('shed', 597)],
#  [('michaeljfoxorg', 945)],
#  [('enoch', 189)],
#  [('wasser', 451)],
#  [('42born2cod', 561)],
#  [('kickoff', 390), ('kickoff', 464), ('kickoff', 974)],
#  [('joe', 620)],
#  [('détendr', 277)],
#  [('mechdev', 607)],
#  [('cciliv', 80), ('cciliv', 100), ('cciliv', 685)],
#  [('httpstco2vtdqhgppr', 532)],
#  [('foreign', 122)],
#  [('nouvel', 705), ('nouvel', 882), ('nouvel', 893)],
#  [('httpstcobiwgqtdufw', 695)],
#  [('150', 401)],
#  [('constraint', 260)],
#  [('psncnewslightbox', 428)],
#  [('swissrobot', 646), ('swissrobot', 657)],
#  [('httpstcoqgwo4mcpjt', 754)],
#  [('httpstcohou5tl7roj', 616)],
#  [('franz', 633)],
#  [('front', 247), ('front', 615)],
#  [('raconté', 1022)],
#  [('httpstcoxtxseusdj9', 310)],
#  [('ho', 658)],
#  [('httpstcoctx6uusyog', 276)],
#  [('confus', 58), ('confus', 65)],
#  [('recruit', 323), ('recruit', 938)],
#  [('y', 287), ('y', 682), ('y', 1024)],
#  [('écrivezn', 197)],
#  [('❤️epflcultur', 812)],
#  [('blond', 746)],
#  [('adressé', 742)],
#  [('fusion', 115), ('fusion', 164)],
#  [('dean', 741)],
#  [('reef', 814)],
#  [('usd', 499)],
#  [('personalis', 758)],
#  [('ictpnew', 663)],
#  [('httpstcouui9tmgnxt', 916)],
#  [('42', 561)],
#  [('behavior', 324), ('behavior', 507), ('behavior', 832)],
#  [('httpstcocniwy0knqi', 442)],
#  [('transport', 69),
#   ('transport', 69),
#   ('transport', 366),
#   ('transport', 520),
#   ('transport', 851),
#   ('transport', 1061)],
#  [('rank', 4),
#   ('rank', 121),
#   ('rank', 220),
#   ('rank', 675),
#   ('rank', 912),
#   ('rank', 1041)],
#  [('cancertreat', 529)],
#  [('sinspir', 874)],
#  [('youtub', 12),
#   ('youtub', 107),
#   ('youtub', 459),
#   ('youtub', 676),
#   ('youtub', 843),
#   ('youtub', 1062),
#   ('youtub', 1064)],
#  [('explain', 275), ('explain', 481), ('explain', 699)],
#  [('httpstco9lr6sbjlil', 669)],
#  [('seen', 691), ('seen', 751)],
#  [('poulet', 927)],
#  [('those', 312), ('those', 513), ('those', 743)],
#  [('ye', 664)],
#  [('architectureschool', 93)],
#  [('prudenc', 185)],
#  [('lhiver', 877)],
#  [('kind', 414)],
#  [('swisseconom', 1041)],
#  [('septembr', 47), ('septembr', 901), ('septembr', 929)],
#  [('httpstcowmrbimab2g', 664)],
#  [('lovedata18', 125), ('lovedata18', 466)],
#  [('continu', 166), ('continu', 177), ('continu', 703)],
#  [('httpstcoxxmuldcqlg', 464)],
#  [('domain', 657), ('domain', 858), ('domain', 984)],
#  [('le', 12),
#   ('le', 26),
#   ('le', 43),
#   ('le', 62),
#   ('le', 62),
#   ('le', 63),
#   ('le', 63),
#   ('le', 63),
#   ('le', 70),
#   ('le', 70),
#   ('le', 81),
#   ('le', 96),
#   ('le', 129),
#   ('le', 144),
#   ('le', 149),
#   ('le', 157),
#   ('le', 157),
#   ('le', 161),
#   ('le', 168),
#   ('le', 183),
#   ('le', 197),
#   ('le', 197),
#   ('le', 207),
#   ('le', 208),
#   ('le', 244),
#   ('le', 251),
#   ('le', 251),
#   ('le', 252),
#   ('le', 252),
#   ('le', 252),
#   ('le', 277),
#   ('le', 277),
#   ('le', 300),
#   ('le', 311),
#   ('le', 322),
#   ('le', 331),
#   ('le', 342),
#   ('le', 342),
#   ('le', 342),
#   ('le', 345),
#   ('le', 356),
#   ('le', 366),
#   ('le', 369),
#   ('le', 383),
#   ('le', 383),
#   ('le', 388),
#   ('le', 388),
#   ('le', 403),
#   ('le', 403),
#   ('le', 405),
#   ('le', 408),
#   ('le', 424),
#   ('le', 437),
#   ('le', 462),
#   ('le', 463),
#   ('le', 472),
#   ('le', 488),
#   ('le', 523),
#   ('le', 543),
#   ('le', 548),
#   ('le', 552),
#   ('le', 554),
#   ('le', 565),
#   ('le', 566),
#   ('le', 568),
#   ('le', 569),
#   ('le', 571),
#   ('le', 592),
#   ('le', 602),
#   ('le', 603),
#   ('le', 604),
#   ('le', 610),
#   ('le', 636),
#   ('le', 644),
#   ('le', 651),
#   ('le', 653),
#   ('le', 683),
#   ('le', 705),
#   ('le', 705),
#   ('le', 710),
#   ('le', 710),
#   ('le', 729),
#   ('le', 740),
#   ('le', 742),
#   ('le', 744),
#   ('le', 746),
#   ('le', 752),
#   ('le', 789),
#   ('le', 794),
#   ('le', 801),
#   ('le', 801),
#   ('le', 821),
#   ('le', 823),
#   ('le', 824),
#   ('le', 829),
#   ('le', 837),
#   ('le', 842),
#   ('le', 843),
#   ('le', 844),
#   ('le', 857),
#   ('le', 862),
#   ('le', 862),
#   ('le', 876),
#   ('le', 889),
#   ('le', 893),
#   ('le', 900),
#   ('le', 902),
#   ('le', 921),
#   ('le', 922),
#   ('le', 922),
#   ('le', 924),
#   ('le', 925),
#   ('le', 925),
#   ('le', 958),
#   ('le', 961),
#   ('le', 961),
#   ('le', 962),
#   ('le', 976),
#   ('le', 976),
#   ('le', 977),
#   ('le', 977),
#   ('le', 978),
#   ('le', 978),
#   ('le', 983),
#   ('le', 989),
#   ('le', 989),
#   ('le', 993),
#   ('le', 1001),
#   ('le', 1010),
#   ('le', 1019),
#   ('le', 1021),
#   ('le', 1023),
#   ('le', 1024),
#   ('le', 1024),
#   ('le', 1026),
#   ('le', 1031),
#   ('le', 1035),
#   ('le', 1037),
#   ('le', 1037),
#   ('le', 1037),
#   ('le', 1040),
#   ('le', 1042),
#   ('le', 1042),
#   ('le', 1043),
#   ('le', 1048),
#   ('le', 1049),
#   ('le', 1050),
#   ('le', 1053),
#   ('le', 1063),
#   ('le', 1063),
#   ('le', 1066),
#   ('le', 1066),
#   ('le', 1066),
#   ('le', 1067),
#   ('le', 1067)],
#  [('mediaroad', 27)],
#  [('httpstcof8vfogntco', 842)],
#  [('ailleur', 896)],
#  [('immunitair', 978)],
#  [('allergi', 564), ('allergi', 726)],
#  [('httpstcoeoe8vhmgek', 804)],
#  [('nemat', 335)],
#  [('500', 429)],
#  [('noemiematthey', 591)],
#  [('queen', 582)],
#  [('httpstcopz1j7srhmm', 655)],
#  [('focu', 754), ('focu', 911)],
#  [('periscop', 953)],
#  [('httpstconr5ni3chy4', 984)],
#  [('ive', 262)],
#  [('capac', 126)],
#  [('mathemat', 717)],
#  [('allow', 260), ('allow', 438), ('allow', 878)],
#  [('critic', 150), ('critic', 292)],
#  [('possibl', 12),
#   ('possibl', 24),
#   ('possibl', 44),
#   ('possibl', 67),
#   ('possibl', 153),
#   ('possibl', 467),
#   ('possibl', 797),
#   ('possibl', 932)],
#  [('mang', 927)],
#  [('chroniqu', 1031)],
#  [('professionnel', 244), ('professionnel', 261)],
#  [('synapt', 77)],
#  [('tmech', 407)],
#  [('httpstcomsdk9vygcj', 291)],
#  [('génétiqu', 266), ('génétiqu', 783)],
#  [('silkroad', 530)],
#  [('ieee', 407), ('ieee', 917)],
#  [('simonl', 346)],
#  [('supsi', 202)],
#  [('meetup', 427)],
#  [('scolair', 783)],
#  [('organisateur', 1020)],
#  [('httpstcoxfrvqn5ceu', 626)],
#  [('jetzt', 167)],
#  [('crime', 641)],
#  [('valaisw', 829), ('valaisw', 847)],
#  [('cheesecak', 253)],
#  [('museomixch', 781), ('museomixch', 983)],
#  [('were', 84), ('were', 221), ('were', 576), ('were', 776)],
#  [('absorpt', 597)],
#  [('robotiqu', 20), ('robotiqu', 382), ('robotiqu', 929)],
#  [('lose', 692)],
#  [('ujinoticia', 76), ('ujinoticia', 933)],
#  [('revoir', 12)],
#  [('civiqu', 856)],
#  [('control', 534),
#   ('control', 668),
#   ('control', 708),
#   ('control', 838),
#   ('control', 864),
#   ('control', 867),
#   ('control', 970)],
#  [('librari', 125),
#   ('librari', 136),
#   ('librari', 136),
#   ('librari', 326),
#   ('librari', 466),
#   ('librari', 655)],
#  [('superglaz', 231)],
#  [('character', 159)],
#  [('type', 356), ('type', 732), ('type', 840), ('type', 880)],
#  [('httpstcog6qbwtrwga', 402)],
#  [('embopress', 629)],
#  [('sorbonneuniv', 164)],
#  [('1012', 107)],
#  [('begreifbar', 48)],
#  [('httpstcorolwlcnfew', 174)],
#  [('njit', 77)],
#  [('solarenergi', 217)],
#  [('curti', 148)],
#  [('httpstcowy69jze1zc', 393)],
#  [('porto', 306)],
#  [('perditab', 661)],
#  [('httpstco8hh2xacpdn', 139)],
#  [('flexibl', 440)],
#  [('lign', 12), ('lign', 252), ('lign', 958)],
#  [('fsrm', 1005)],
#  [('pavilion', 770)],
#  [('down', 173), ('down', 307), ('down', 719), ('down', 736), ('down', 854)],
#  [('swissborg', 19)],
#  [('realli', 58),
#   ('realli', 260),
#   ('realli', 353),
#   ('realli', 387),
#   ('realli', 691),
#   ('realli', 790),
#   ('realli', 938),
#   ('realli', 999)],
#  [('fourthrevolut', 22)],
#  [('clearer', 73), ('clearer', 839)],
#  [('war', 890)],
#  [('natur', 44),
#   ('natur', 104),
#   ('natur', 169),
#   ('natur', 414),
#   ('natur', 532),
#   ('natur', 562),
#   ('natur', 749),
#   ('natur', 831)],
#  [('biologist', 379)],
#  [('stabilité', 900)],
#  [('experi', 346),
#   ('experi', 387),
#   ('experi', 518),
#   ('experi', 526),
#   ('experi', 640),
#   ('experi', 960),
#   ('experi', 985)],
#  [('well', 260), ('well', 260), ('well', 267), ('well', 761), ('well', 948)],
#  [('temperatur', 769)],
#  [('cement', 133), ('cement', 748)],
#  [('techforgood', 635)],
#  [('chair', 270)],
#  [('live', 17),
#   ('live', 95),
#   ('live', 112),
#   ('live', 180),
#   ('live', 257),
#   ('live', 589),
#   ('live', 992)],
#  [('cerveau', 362)],
#  [('marchand', 1068)],
#  [('bottom', 589)],
#  [('httpstconz9kigfbn2', 124)],
#  [('iranian', 359), ('iranian', 556)],
#  [('letter', 409)],
#  [('session', 223),
#   ('session', 294),
#   ('session', 393),
#   ('session', 468),
#   ('session', 991)],
#  [('httpstcogjfgwn1gcq', 197)],
#  [('erc', 717)],
#  [('httpstcoco2lbnhmvd', 737)],
#  [('httpstcons9d2v1vba', 144)],
#  [('httpstcouocn4jhqwb', 531)],
#  [('mechan', 44),
#   ('mechan', 512),
#   ('mechan', 607),
#   ('mechan', 607),
#   ('mechan', 753),
#   ('mechan', 809)],
#  [('httpstcos6uszeucpm', 907)],
#  [('soon', 963), ('soon', 972), ('soon', 998)],
#  [('metastasi', 32)],
#  [('httpstcoiawwhc0abh', 550)],
#  [('témoignag', 955)],
#  [('httpstcolb223yt804', 92)],
#  [('coucou', 670), ('coucou', 1039)],
#  [('pierr', 741), ('pierr', 837)],
#  [('httpstcoqr5bho3ejh', 794)],
#  [('ubisim', 386)],
#  [('précieux', 279)],
#  [('imperialcolleg', 76), ('imperialcolleg', 933)],
#  [('below', 125)],
#  [('métier', 357)],
#  [('intelligenceartificiel', 251)],
#  [('forestsandwood', 630)],
#  [('httpstcoob8ruct0pk', 698)],
#  [('manufactur', 375)],
#  [('relevé', 167), ('relevé', 252)],
#  [('httpstco4rh442x4q1', 72)],
#  [('ethspinoff', 963)],
#  [('httpstco06jmxdae2h', 59)],
#  [('drug', 211), ('drug', 284), ('drug', 577)],
#  [('erf2018', 102)],
#  [('insect', 74), ('insect', 379), ('insect', 835)],
#  [('geotherm', 79), ('geotherm', 79)],
#  [('facil', 98)],
#  [('leprosi', 284), ('leprosi', 777)],
#  [('technic', 640)],
#  [('bitcoincash', 561)],
#  [('graphic', 878)],
#  [('18th', 225)],
#  [('produc', 64),
#   ('produc', 80),
#   ('produc', 301),
#   ('produc', 497),
#   ('produc', 533),
#   ('produc', 680)],
#  [('matrixbind', 349)],
#  [('lacustr', 167), ('lacustr', 252)],
#  [('sundanc', 313)],
#  [('blown', 323)],
#  [('soldout', 655)],
#  [('wisest', 675)],
#  [('httpstcoluzvtvhqzm', 926)],
#  [('lnco', 247)],
#  [('gerolimini', 805)],
#  [('montr', 892)],
#  [('profit', 129)],
#  [('nm2conf', 135), ('nm2conf', 179), ('nm2conf', 223)],
#  [('lectur', 32),
#   ('lectur', 107),
#   ('lectur', 164),
#   ('lectur', 223),
#   ('lectur', 293),
#   ('lectur', 371),
#   ('lectur', 413),
#   ('lectur', 600),
#   ('lectur', 816),
#   ('lectur', 859)],
#  [('grt', 375)],
#  [('balelec', 1052)],
#  [('avc', 43)],
#  [('httpstcoy7gteavf58', 813)],
#  [('lextensoetudian', 61), ('lextensoetudian', 682)],
#  [('5g', 212), ('5g', 636)],
#  [('imboden', 916)],
#  [('aihealth', 21),
#   ('aihealth', 50),
#   ('aihealth', 198),
#   ('aihealth', 580),
#   ('aihealth', 581),
#   ('aihealth', 722)],
#  [('httpstcowqjw1nfwcb', 691)],
#  [('ehlnew', 244), ('ehlnew', 302)],
#  [('expliqu', 205)],
#  [('httpstcoewpqrcc817', 733)],
#  [('quel', 543), ('quel', 789)],
#  [('calibr', 438)],
#  [('rate', 834)],
#  [('celui', 862)],
#  [('cooper', 71)],
#  [('fiber', 544), ('fiber', 544), ('fiber', 959)],
#  [('ditmai', 659)],
#  [('hormon', 714)],
#  [('bluefactori', 705)],
#  [('fan', 12), ('fan', 472)],
#  [('es', 638), ('es', 701), ('es', 890)],
#  [('httpstcoiklrksjqn5', 213)],
#  [('elluba', 418)],
#  [('httpstcoayzqdgq6r4', 449)],
#  [('hp1a', 66), ('hp1a', 959)],
#  [('kingconrad', 240), ('kingconrad', 637)],
#  [('wild', 557)],
#  [('détecter', 892)],
#  [('predict', 127), ('predict', 557)],
#  [('»', 167),
#   ('»', 188),
#   ('»', 202),
#   ('»', 208),
#   ('»', 252),
#   ('»', 282),
#   ('»', 294),
#   ('»', 366),
#   ('»', 384),
#   ('»', 468),
#   ('»', 610),
#   ('»', 618),
#   ('»', 627),
#   ('»', 636),
#   ('»', 644),
#   ('»', 710),
#   ('»', 742),
#   ('»', 752),
#   ('»', 842),
#   ('»', 851),
#   ('»', 862),
#   ('»', 862),
#   ('»', 1071)],
#  [('sa', 202), ('sa', 627)],
#  [('swissnexsf', 215),
#   ('swissnexsf', 241),
#   ('swissnexsf', 247),
#   ('swissnexsf', 313),
#   ('swissnexsf', 963)],
#  [('2nd', 391), ('2nd', 393), ('2nd', 899)],
#  [('httpstcowo4wo77xm2', 639)],
#  [('hillaryclinton', 582)],
#  [('cett', 12), ('cett', 1047)],
#  [('poesi', 311)],
#  [('robotera', 828)],
#  [('😏😊', 866)],
#  [('golfweek', 1018)],
#  [('httpstcoysim9d7hdi', 384)],
#  [('dotastro', 869)],
#  [('ski', 786)],
#  [('httpstcokbmt3ojtnm', 360)],
#  [('triest', 545), ('triest', 663)],
#  [('caution', 185), ('caution', 185)],
#  [('lordsofmap', 772)],
#  [('aud', 118)],
#  [('medal', 413)],
#  [('enough', 965)],
#  [('stabil', 66),
#   ('stabil', 289),
#   ('stabil', 377),
#   ('stabil', 551),
#   ('stabil', 628)],
#  [('dont', 134),
#   ('dont', 215),
#   ('dont', 224),
#   ('dont', 281),
#   ('dont', 325),
#   ('dont', 979)],
#  [('thrive', 375)],
#  [('wed', 301)],
#  [('dépend', 783)],
#  [('françou', 535)],
#  [('httpstco7e2mgk4jiu', 338)],
#  [('side', 620)],
#  [('imdeanano', 76), ('imdeanano', 933)],
#  [('protein', 159), ('protein', 228), ('protein', 795), ('protein', 838)],
#  [('queenuk', 582)],
#  [('runtim', 917)],
#  [('sixleg', 379)],
#  [('dublin', 427)],
#  [('level', 166),
#   ('level', 611),
#   ('level', 790),
#   ('level', 804),
#   ('level', 836)],
#  [('csschweiz', 1018)],
#  [('httpstcox2y212dkup', 7)],
#  [('mond', 356), ('mond', 568), ('mond', 913), ('mond', 923), ('mond', 1037)],
#  [('httpstcoztwr6xeqot', 1025)],
#  [('soutien', 996)],
#  [('ateli', 11), ('ateli', 265), ('ateli', 265)],
#  [('domest', 228)],
#  [('httpstcotakzfgo7zx', 975)],
#  [('venez', 243), ('venez', 983), ('venez', 1037)],
#  [('httpstcoqkysnjcskw', 182)],
#  [('timeshigh', 121),
#   ('timeshigh', 139),
#   ('timeshigh', 319),
#   ('timeshigh', 934)],
#  [('blindpad', 435), ('blindpad', 878)],
#  [('proud', 33),
#   ('proud', 42),
#   ('proud', 64),
#   ('proud', 264),
#   ('proud', 501),
#   ('proud', 576),
#   ('proud', 605),
#   ('proud', 703),
#   ('proud', 720),
#   ('proud', 776),
#   ('proud', 846),
#   ('proud', 934),
#   ('proud', 963)],
#  [('ran', 88)],
#  [('choic', 669), ('choic', 791)],
#  [('theyll', 269)],
#  [('currenc', 294), ('currenc', 468)],
#  [('httpstcod76buifpkw', 952)],
#  [('gtgtventuregtgt', 390),
#   ('gtgtventuregtgt', 464),
#   ('gtgtventuregtgt', 465)],
#  [('sandec', 975)],
#  [('ctmcecam', 335)],
#  [('rejouit', 437)],
#  [('httpstcou6ve2en6q8', 613)],
#  [('même', 548), ('même', 610), ('même', 893), ('même', 1054)],
#  [('befcorreiahantschelmblokesch', 593)],
#  [('hr', 301)],
#  [('philbati', 934)],
#  [('httpstco58hoxs4wco', 894)],
#  [('gruenebw', 1057), ('gruenebw', 1058), ('gruenebw', 1059)],
#  [('uneth', 198)],
#  [('besoin', 118), ('besoin', 283), ('besoin', 1030)],
#  [('httpstcookq8sxesiv', 642)],
#  [('lʹesprit', 1069)],
#  [('lenvironn', 783), ('lenvironn', 876)],
#  [('œuvr', 456)],
#  [('httpstcoqfnrpqe4t2', 825)],
#  [('swisssporttv', 52)],
#  [('eksobion', 871)],
#  [('marathon', 363)],
#  [('students🏅🏆', 471)],
#  [('wpcapit', 399)],
#  [('counterpart', 216), ('counterpart', 634)],
#  [('memotv', 418)],
#  [('messestand', 48)],
#  [('httpstcoipc3bfdrsl', 824)],
#  [('map', 206)],
#  [('solutionssolar', 980)],
#  [('lumièr', 788)],
#  [('regierungbw', 1057), ('regierungbw', 1058), ('regierungbw', 1059)],
#  [('httpstcoxddm5pf3d', 263)],
#  [('httpstcovekuwvpahh', 839)],
#  [('number', 519)],
#  [('logitech', 177)],
#  [('fritz', 785)],
#  [('chromatin', 378), ('chromatin', 378), ('chromatin', 959)],
#  [('janv', 250)],
#  [('httpstcovppidzey2b', 489)],
#  [('touchscreen', 878)],
#  [('httpstcoiv291y1aiu', 268)],
#  [('httpstcoqjzmsogwyo', 397)],
#  [('percept', 292), ('percept', 322)],
#  [('nettoy', 383)],
#  [('classifi', 734)],
#  [('portivechju', 207), ('portivechju', 989)],
#  [('httpstcoxwnsg7vcei', 149)],
#  [('httpstcoeek6g1vnm5', 970)],
#  [('httpstcoslv8b53ggj', 578)],
#  [('realiti', 376),
#   ('realiti', 444),
#   ('realiti', 718),
#   ('realiti', 907),
#   ('realiti', 1014)],
#  [('httpstco5t7egh0quw', 29)],
#  [('extend', 393)],
#  [('pdf', 327)],
#  [('bourgd', 729)],
#  [('président', 989), ('président', 1022)],
#  [('fpga', 666), ('fpga', 909), ('fpga', 917)],
#  [('httpstcosikakpfu0o', 684)],
#  [('httpstcovve1osjejv', 363)],
#  [('carlo', 218), ('carlo', 460), ('carlo', 496)],
#  [('httpstcoctes8y5qxj', 729)],
#  [('vu', 130)],
#  [('httpstcotku6hpx2', 573)],
#  [('httpstcoy2s3hz1817', 796)],
#  [('newyear', 719)],
#  [('includ', 13), ('includ', 471)],
#  [('wave', 44), ('wave', 328), ('wave', 527), ('wave', 534), ('wave', 908)],
#  [('ict4dev', 46)],
#  [('félicit', 954)],
#  [('olymp', 1042)],
#  [('httpstcoty35u7vfah', 712)],
#  [('tournament', 535)],
#  [('decathlon', 364)],
#  [('bien', 12),
#   ('bien', 26),
#   ('bien', 81),
#   ('bien', 610),
#   ('bien', 627),
#   ('bien', 927),
#   ('bien', 939)],
#  [('httpstcohtryoqhyq7', 370)],
#  [('siliconbas', 398)],
#  [('morn', 335), ('morn', 964)],
#  [('uniofoxford', 22)],
#  [('void', 410)],
#  [('pioneer', 317)],
#  [('froid', 1052)],
#  [('rtsi', 144)],
#  [('mécaniqu', 627), ('mécaniqu', 710)],
#  [('inventé', 1043)],
#  [('codeweekch', 333)],
#  [('httpstcoznjk3bz6mo', 838)],
#  [('consid', 340), ('consid', 350)],
#  [('deserv', 413)],
#  [('développeur', 862)],
#  [('demonstr', 104), ('demonstr', 909)],
#  [('bibliograph', 739)],
#  [('dispositif', 383)],
#  [('stack', 66), ('stack', 66)],
#  [('doehlergroup', 522)],
#  [('trevp', 68)],
#  [('lereseau', 251), ('lereseau', 321), ('lereseau', 645)],
#  [('moham', 861)],
#  [('chip', 865), ('chip', 916)],
#  [('5', 333),
#   ('5', 350),
#   ('5', 393),
#   ('5', 489),
#   ('5', 560),
#   ('5', 586),
#   ('5', 1014)],
#  [('pont', 463)],
#  [('mine', 957)],
#  [('httpstcoxaapgicva3', 139)],
#  [('physic', 440), ('physic', 728), ('physic', 1029)],
#  [('publish', 415), ('publish', 532), ('publish', 745), ('publish', 917)],
#  [('nexu', 524), ('nexu', 616), ('nexu', 713), ('nexu', 904)],
#  [('bootcamp', 269)],
#  [('intéressé', 197)],
#  [('fems2017', 55), ('fems2017', 498), ('fems2017', 809), ('fems2017', 991)],
#  [('cant', 359)],
#  [('httpstcof6us6yutfq', 448)],
#  [('chbotschaftd', 319)],
#  [('factor', 170), ('factor', 494)],
#  [('they', 224),
#   ('they', 507),
#   ('they', 679),
#   ('they', 699),
#   ('they', 699),
#   ('they', 704),
#   ('they', 875),
#   ('they', 899),
#   ('they', 938)],
#  [('poverti', 229)],
#  [('suitabl', 159), ('suitabl', 685)],
#  [('mise', 844)],
#  [('datastorag', 558), ('datastorag', 728)],
#  [('vo', 801)],
#  [('categori', 469)],
#  [('boy', 281), ('boy', 979)],
#  [('kurs', 167)],
#  [('httpstcoxaxuscw6kp', 648)],
#  [('molsystbiol', 629)],
#  [('ground', 872)],
#  [('ct', 109), ('ct', 109)],
#  [('informatiqu', 742), ('informatiqu', 742)],
#  [('he', 126)],
#  [('httpstcoruvegs5egz', 204)],
#  [('origamiinspir', 124)],
#  [('silentparti', 168), ('silentparti', 197)],
#  [('trè', 183), ('trè', 417), ('trè', 794), ('trè', 996)],
#  [('positionné', 26)],
#  [('httpstcoesz9scdzao', 416)],
#  [('bonjour', 467)],
#  [('thinkservic', 862)],
#  [('futuri', 419)],
#  [('httpstcos1t6jccyoj', 398)],
#  [('lexposit', 895)],
#  [('illustr', 382), ('illustr', 652), ('illustr', 841)],
#  [('biofuel', 965), ('biofuel', 965)],
#  [('auroregranvalepflch', 197)],
#  [('estel', 851)],
#  [('plasmon', 113)],
#  [('httpstcofeglco5gun', 431)],
#  [('hard', 14)],
#  [('naturecomm', 74), ('naturecomm', 211), ('naturecomm', 959)],
#  [('michel', 782)],
#  [('httpstcoa0fsbkkmwn', 148)],
#  [('verfolgen', 638)],
#  [('within', 639), ('within', 1060)],
#  [('🙌', 77), ('🙌', 522)],
#  [('httpstcojokzxoverh', 929)],
#  [('prototyp', 983)],
#  [('our', 65),
#   ('our', 78),
#   ('our', 102),
#   ('our', 108),
#   ('our', 108),
#   ('our', 142),
#   ('our', 154),
#   ('our', 178),
#   ('our', 200),
#   ('our', 203),
#   ('our', 228),
#   ('our', 264),
#   ('our', 264),
#   ('our', 312),
#   ('our', 320),
#   ('our', 341),
#   ('our', 381),
#   ('our', 387),
#   ('our', 407),
#   ('our', 415),
#   ('our', 420),
#   ('our', 436),
#   ('our', 446),
#   ('our', 481),
#   ('our', 493),
#   ('our', 510),
#   ('our', 522),
#   ('our', 526),
#   ('our', 559),
#   ('our', 587),
#   ('our', 613),
#   ('our', 654),
#   ('our', 658),
#   ('our', 662),
#   ('our', 703),
#   ('our', 719),
#   ('our', 756),
#   ('our', 760),
#   ('our', 762),
#   ('our', 776),
#   ('our', 792),
#   ('our', 799),
#   ('our', 863),
#   ('our', 864),
#   ('our', 941),
#   ('our', 959),
#   ('our', 963),
#   ('our', 1046),
#   ('our', 1065)],
#  [('medicin', 156), ('medicin', 164), ('medicin', 625)],
#  [('dure', 89),
#   ('dure', 107),
#   ('dure', 173),
#   ('dure', 245),
#   ('dure', 333),
#   ('dure', 341),
#   ('dure', 854),
#   ('dure', 931),
#   ('dure', 999),
#   ('dure', 1013)],
#  [('tomograph', 446)],
#  [('vmwaremitgründ', 25)],
#  [('httpstcoggjxqokinp', 231)],
#  [('pfeifer', 264), ('pfeifer', 879)],
#  [('beim', 309), ('beim', 890)],
#  [('waltz', 865)],
#  [('ident', 957)],
#  [('normal', 104), ('normal', 234)],
#  [('fascinant', 456)],
#  [('httpstcowflk2bilxi', 485)],
#  [('rang', 499)],
#  [('psc', 628)],
#  [('manquez', 604)],
#  [('seminar', 336), ('seminar', 946)],
#  [('httpstcos6vtp56sbr', 1046)],
#  [('deephot', 79)],
#  [('child', 979)],
#  [('amyloid', 661)],
#  [('diabet', 880)],
#  [('httpstcogyclie4vhl', 1054)],
#  [('ond', 277)],
#  [('problem', 260), ('problem', 260)],
#  [('propos', 200), ('propos', 341), ('propos', 346), ('propos', 391)],
#  [('resolv', 589)],
#  [('keynot', 898)],
#  [('srg', 144)],
#  [('durabilité', 961)],
#  [('httpstcofs7tdpbfsp', 636)],
#  [('mainten', 307), ('mainten', 567), ('mainten', 1019)],
#  [('beltandroad1', 598), ('beltandroad1', 639)],
#  [('documentalist', 439)],
#  [('mystèr', 300), ('mystèr', 523)],
#  [('isabel', 801)],
#  [('notr', 63),
#   ('notr', 243),
#   ('notr', 362),
#   ('notr', 565),
#   ('notr', 710),
#   ('notr', 821),
#   ('notr', 927)],
#  [('vulnérabilité', 1031)],
#  [('httpstcobexn0kdflf', 906)],
#  [('webot', 74)],
#  [('ladysmith', 272)],
#  [('aprè', 277),
#   ('aprè', 665),
#   ('aprè', 705),
#   ('aprè', 752),
#   ('aprè', 900),
#   ('aprè', 1037)],
#  [('nemin', 549)],
#  [('ecorobotix', 31)],
#  [('collaboratif', 304), ('collaboratif', 385)],
#  [('distanc', 627), ('distanc', 838)],
#  [('camp', 619), ('camp', 906), ('camp', 963)],
#  [('5pm', 743)],
#  [('valoris', 844), ('valoris', 976), ('valoris', 977)],
#  [('facteur', 1031)],
#  [('cmi', 225)],
#  [('chôro', 806)],
#  [('httpstcoj2equhxb66', 309)],
#  [('done', 591), ('done', 691), ('done', 761), ('done', 948), ('done', 1006)],
#  [('soin', 386)],
#  [('httpstcopqipgcl9wc', 295)],
#  [('some', 100),
#   ('some', 100),
#   ('some', 185),
#   ('some', 189),
#   ('some', 262),
#   ('some', 323),
#   ('some', 457),
#   ('some', 458),
#   ('some', 466),
#   ('some', 474),
#   ('some', 640),
#   ('some', 722),
#   ('some', 836),
#   ('some', 937),
#   ('some', 1056)],
#  [('order', 87)],
#  [('multipl', 180)],
#  [('legales', 236)],
#  [('httpstcod7efdxo4mp', 575)],
#  [('httpstcotqwfwbeq8c', 39)],
#  [('j2bryson', 198),
#   ('j2bryson', 501),
#   ('j2bryson', 580),
#   ('j2bryson', 581),
#   ('j2bryson', 581)],
#  [('passionnant', 895)],
#  [('solar', 29),
#   ('solar', 40),
#   ('solar', 83),
#   ('solar', 152),
#   ('solar', 296),
#   ('solar', 299),
#   ('solar', 317),
#   ('solar', 364),
#   ('solar', 396),
#   ('solar', 398),
#   ('solar', 406),
#   ('solar', 419),
#   ('solar', 473),
#   ('solar', 517),
#   ('solar', 595),
#   ('solar', 681),
#   ('solar', 684),
#   ('solar', 705),
#   ('solar', 771),
#   ('solar', 853),
#   ('solar', 913),
#   ('solar', 968),
#   ('solar', 1002),
#   ('solar', 1004)],
#  [('reconcil', 299)],
#  [('micronarc', 63)],
#  [('futur', 11),
#   ('futur', 126),
#   ('futur', 127),
#   ('futur', 135),
#   ('futur', 140),
#   ('futur', 205),
#   ('futur', 296),
#   ('futur', 310),
#   ('futur', 388),
#   ('futur', 534),
#   ('futur', 585),
#   ('futur', 647),
#   ('futur', 711),
#   ('futur', 762),
#   ('futur', 772),
#   ('futur', 870),
#   ('futur', 924)],
#  [('tf1lejt', 244), ('tf1lejt', 302)],
#  [('16', 266), ('16', 492), ('16', 958), ('16', 983)],
#  [('nettra', 635)],
#  [('httpstcocey6grxdgf', 315)],
#  [('mobil', 37),
#   ('mobil', 104),
#   ('mobil', 250),
#   ('mobil', 275),
#   ('mobil', 292),
#   ('mobil', 294),
#   ('mobil', 468),
#   ('mobil', 842)],
#  [('often', 134)],
#  [('httpstcopoi6gl8iyv', 230)],
#  [('liver', 298)],
#  [('httpstco3ekteqvhor', 638)],
#  [('cecam', 335)],
#  [('allen', 449)],
#  [('s3', 126), ('s3', 126), ('s3', 704)],
#  [('slow', 941)],
#  [('kevinschawinski', 187), ('kevinschawinski', 501)],
#  [('thesi', 401),
#   ('thesi', 469),
#   ('thesi', 502),
#   ('thesi', 743),
#   ('thesi', 808),
#   ('thesi', 867)],
#  [('httpstcotodcuwv0e7', 911)],
#  [('httpstcokwdnn0uxmn', 764)],
#  [('bad', 104), ('bad', 335), ('bad', 575)],
#  [('doe', 260), ('doe', 613), ('doe', 736)],
#  [('httpstcormxjlczif6', 64)],
#  [('issu', 434), ('issu', 519), ('issu', 669), ('issu', 830)],
#  [('winstonmeiii', 979)],
#  [('turd', 556)],
#  [('🐦', 341)],
#  [('httpstco6eo2nbfqg0', 327)],
#  [('sefaward', 721)],
#  [('montreuxjazz', 1032)],
#  [('httpstcohrow4kecko', 858)],
#  [('deadpooly96', 637)],
#  [('clarifi', 133)],
#  [('epflphd', 246)],
#  [('mettrait', 356)],
#  [('microsoft', 10), ('microsoft', 830)],
#  [('recherch', 16),
#   ('recherch', 168),
#   ('recherch', 197),
#   ('recherch', 569),
#   ('recherch', 892),
#   ('recherch', 1023)],
#  [('httpstcobh4l44zsmn', 166)],
#  [('consult', 566)],
#  [('place', 0),
#   ('place', 0),
#   ('place', 137),
#   ('place', 283),
#   ('place', 429),
#   ('place', 560),
#   ('place', 764),
#   ('place', 873),
#   ('place', 886),
#   ('place', 976),
#   ('place', 977),
#   ('place', 1048)],
#  [('pie', 383)],
#  [('euronew', 419)],
#  [('leila', 935)],
#  [('thx', 561)],
#  [('httpstcocjwc2eueii', 762)],
#  [('agent', 414)],
#  [('cytometri', 98),
#   ('cytometri', 203),
#   ('cytometri', 365),
#   ('cytometri', 509),
#   ('cytometri', 578)],
#  [('landwirtschaft', 721)],
#  [('photograph', 44),
#   ('photograph', 328),
#   ('photograph', 527),
#   ('photograph', 908)],
#  [('httpstcog0hzwjpurg', 465)],
#  [('andor', 80)],
#  [('quitt', 919), ('quitt', 1039)],
#  [('matièr', 26), ('matièr', 392)],
#  [('communelausann', 52)],
#  [('linda', 294), ('linda', 468)],
#  [('road', 598)],
#  [('jeanpierr', 182)],
#  [('code', 233),
#   ('code', 347),
#   ('code', 525),
#   ('code', 528),
#   ('code', 636),
#   ('code', 707),
#   ('code', 742),
#   ('code', 752)],
#  [('uzh', 905)],
#  [('httpstco6yp1ywa7ww', 206)],
#  [('farm', 2)],
#  [('schoolchildren', 450)],
#  [('roboreptil', 216), ('roboreptil', 634)],
#  [('worldli', 675)],
#  [('httpstcomxk2y5brhf', 339)],
#  [('caban', 388)],
#  [('ta', 790)],
#  [('environment', 101), ('environment', 617)],
#  [('symboliqu', 782)],
#  [('unser', 638)],
#  [('jeanclaudebadoux', 1022)],
#  [('ukni', 215)],
#  [('httpstcohvhfodh1ai', 1000)],
#  [('colab', 176)],
#  [('24', 265), ('24', 990)],
#  [('son', 16),
#   ('son', 205),
#   ('son', 651),
#   ('son', 665),
#   ('son', 705),
#   ('son', 752),
#   ('son', 860),
#   ('son', 874),
#   ('son', 893),
#   ('son', 996)],
#  [('httpstco4gegfxu8co', 577)],
#  [('unicorn', 563)],
#  [('fxpetit', 561)],
#  [('thinksportsuccessstori', 1060)],
#  [('further', 525), ('further', 697)],
#  [('trust', 21),
#   ('trust', 50),
#   ('trust', 198),
#   ('trust', 580),
#   ('trust', 580),
#   ('trust', 581),
#   ('trust', 581),
#   ('trust', 640),
#   ('trust', 1044)],
#  [('cloud', 521), ('cloud', 533), ('cloud', 917)],
#  [('scène', 1019)],
#  [('yesterday', 381), ('yesterday', 525)],
#  [('histoir', 243), ('histoir', 782)],
#  [('prendrai', 61)],
#  [('httpstcos8zkriahbq', 69)],
#  [('httpstcoaxxf5tgqj3', 692)],
#  [('envirobot', 145), ('envirobot', 828), ('envirobot', 1008)],
#  [('pain', 718), ('pain', 907), ('pain', 907)],
#  [('ladhul', 219)],
#  [('2018hpeworkshop', 611)],
#  [('httpstco7qzba4qjxg', 588)],
#  [('httpstco6uzlxnhwvr', 434)],
#  [('parametr', 101)],
#  [('anyth', 585)],
#  [('heterogen', 734), ('heterogen', 766)],
#  [('openfood', 2), ('openfood', 158), ('openfood', 500), ('openfood', 656)],
#  [('httpstcox4p8uwpivg', 347)],
#  [('creation', 363)],
#  [('sneedit', 199), ('sneedit', 840), ('sneedit', 939), ('sneedit', 993)],
#  [('encrypt', 930)],
#  [('httpstcob1rcngnblz', 213), ('httpstcob1rcngnblz', 479)],
#  [('claudio', 226)],
#  [('problèm', 823)],
#  [('film', 44),
#   ('film', 301),
#   ('film', 313),
#   ('film', 339),
#   ('film', 396),
#   ('film', 419),
#   ('film', 420),
#   ('film', 730)],
#  [('sundancefest', 247), ('sundancefest', 615)],
#  [('custom', 492)],
#  [('bateau', 815)],
#  [('quelqu', 325), ('quelqu', 402), ('quelqu', 939)],
#  [('httpstcoomasebul3l', 443)],
#  [('httpstcosnelwpuby7', 895)],
#  [('bepa', 1070)],
#  [('announc', 78),
#   ('announc', 137),
#   ('announc', 479),
#   ('announc', 703),
#   ('announc', 950),
#   ('announc', 963),
#   ('announc', 1060)],
#  [('salgado', 231)],
#  [('sportscrunchind', 291)],
#  [('httpstcodftdrcetrl', 163)],
#  [('httpstcozyenraseir', 5)],
#  [('httpstco403ikcep1k', 718)],
#  [('advertis', 555)],
#  [('httpstcoxunovzzdtm', 517)],
#  [('httpstcocixq0xhiu9', 657)],
#  [('melodi', 750)],
#  [('nafld', 298)],
#  [('seront', 554)],
#  [('slingshot', 746)],
#  [('zotero', 61),
#   ('zotero', 439),
#   ('zotero', 682),
#   ('zotero', 840),
#   ('zotero', 939)],
#  [('heiafr', 11)],
#  ...]

# %%
test_values = {('xx',2),('yy',4),('tt',3)}

set(map(lambda x:x[0], test_values))
# Out:
# {'tt', 'xx', 'yy'}

# %%
# We simulate the mapreduce framework by this function
def run_mapreduce(docs_n_doc_ids):
    # Map phase
    key_values = []
    for doc_id, doc_content in docs_n_doc_ids:
        key_values.extend(map_function(doc_id, doc_content))
    # Shuffle phase
    values = set(map(lambda x:x[0], key_values))
    grouped_key_values = [[y for y in key_values if y[0]==x] for x in values]
    # Reduce phase
    inverted_files = []
    for grouped_key_value in grouped_key_values:
        word, total, doc_ids = reduce_function(grouped_key_value)
        inverted_files.append((word, total, doc_ids))
    return inverted_files

# %%
run_mapreduce(docs_n_doc_ids)
# Out:
# [('verbeek', 1, [915]),
#  ('aziz', 1, [55]),
#  ('httpstco9d256rj7ct', 1, [769]),
#  ('trevp', 1, [68]),
#  ('smile', 1, [894]),
#  ('explan', 1, [19]),
#  ('httpstcoscnzxhptgu', 1, [303]),
#  ('mystèr', 2, [300, 523]),
#  ('avez', 1, [1030]),
#  ('httpstco89ziiby5f', 1, [990]),
#  ('swissnexindia', 1, [143]),
#  ('httpstcopfocmykcvb', 1, [407]),
#  ('cdu', 3, [1057, 1058, 1059]),
#  ('save', 5, [339, 441, 698, 887, 1060]),
#  ('although', 1, [685]),
#  ('public', 10, [13, 107, 163, 301, 339, 366, 635, 745, 975, 1017]),
#  ('around', 4, [290, 614, 689, 764]),
#  ('embol', 1, [446]),
#  ('clean', 7, [152, 419, 473, 517, 853, 866, 968]),
#  ('ihr', 2, [309, 319]),
#  ('upcom', 1, [27]),
#  ('janetgh', 1, [785]),
#  ('pourriez', 1, [1039]),
#  ('blond', 1, [746]),
#  ('left', 1, [941]),
#  ('prochain', 1, [252]),
#  ('led', 1, [938]),
#  ('presenc', 2, [238, 866]),
#  ('aurelberra', 1, [925]),
#  ('ecolog', 2, [41, 41]),
#  ('murderparti', 1, [655]),
#  ('❤️epflcultur', 1, [812]),
#  ('httpstcowpkspxtdc9', 1, [460]),
#  ('dann', 1, [890]),
#  ('darchiv', 1, [202]),
#  ('recherch', 6, [16, 168, 197, 569, 892, 1023]),
#  ('shadaislam', 1, [270]),
#  ('cityclub', 1, [339]),
#  ('nestl', 1, [522]),
#  ('httpstcoo84k23wblm', 1, [600]),
#  ('50000', 1, [688]),
#  ('becaus', 1, [655]),
#  ('solarimpuls', 1, [620]),
#  ('httpstcodkgmxia7tq', 1, [985]),
#  ('swissedtechcollid', 3, [91, 143, 273]),
#  ('entrepreneurship', 4, [539, 613, 623, 791]),
#  ('intéress', 1, [744]),
#  ('back', 5, [267, 335, 649, 814, 938]),
#  ('httpstcoss6ygoof2f', 1, [888]),
#  ('ar', 3, [241, 518, 521]),
#  ('brillant', 1, [246]),
#  ('degrad', 1, [986]),
#  ('compress', 1, [855]),
#  ('tri', 4, [260, 418, 461, 938]),
#  ('scellé', 1, [70]),
#  ('foresti', 1, [653]),
#  ('fail', 1, [813]),
#  ('montreuxjazz', 1, [1032]),
#  ('uber', 1, [930]),
#  ('httpstcohrx0n07gtj', 1, [469]),
#  ('cell',
#   16,
#   [29,
#    173,
#    242,
#    296,
#    317,
#    398,
#    406,
#    529,
#    595,
#    607,
#    681,
#    734,
#    734,
#    771,
#    833,
#    854]),
#  ('minuten', 1, [1015]),
#  ('gehen', 1, [701]),
#  ('sublim', 1, [843]),
#  ('httpstcosj1zr4xd52', 1, [243]),
#  ('augmentedr', 1, [624]),
#  ('sticker', 1, [409]),
#  ('httpstcoxunovzzdtm', 1, [517]),
#  ('httpstcojosupjdg7k', 1, [14]),
#  ('ouvertur', 1, [385]),
#  ('farm', 1, [2]),
#  ('chip', 2, [865, 916]),
#  ('scientistswhoselfi', 1, [288]),
#  ('httpstcomll94mdiwz', 1, [332]),
#  ('eurosys2018', 3, [274, 306, 306]),
#  ('colleagu', 6, [193, 352, 526, 724, 818, 875]),
#  ('httpstcotcovytrn9i', 1, [983]),
#  ('suitabl', 2, [159, 685]),
#  ('vitro', 1, [354]),
#  ('techsmithd', 1, [747]),
#  ('mylausann', 1, [749]),
#  ('andor', 1, [80]),
#  ('httpstcogqk1h9bplr', 1, [825]),
#  ('dario', 1, [318]),
#  ('privat', 2, [499, 957]),
#  ('httpstcodnot4oimmv', 1, [969]),
#  ('httpstcohjbhwul4pv', 1, [979]),
#  ('dédié', 2, [261, 297]),
#  ('footersi', 1, [980]),
#  ('proposé', 3, [261, 844, 862]),
#  ('maje', 1, [504]),
#  ('read',
#   13,
#   [109, 109, 150, 236, 262, 278, 546, 550, 577, 820, 935, 981, 986]),
#  ('camion', 1, [604]),
#  ('divisar', 1, [232]),
#  ('choos', 1, [791]),
#  ('32', 1, [492]),
#  ('isabel', 1, [801]),
#  ('httpstco856yhgi74j', 1, [58]),
#  ('traversé', 1, [11]),
#  ('httpstcozmvfhhyhli', 1, [141]),
#  ('uncertainti', 1, [613]),
#  ('world',
#   16,
#   [4,
#    13,
#    40,
#    139,
#    152,
#    158,
#    401,
#    473,
#    517,
#    560,
#    589,
#    759,
#    817,
#    853,
#    968,
#    995]),
#  ('compbio', 1, [30]),
#  ('sensefli', 1, [318]),
#  ('fair', 9, [51, 168, 197, 291, 530, 610, 1039, 1039, 1051]),
#  ('28082017', 1, [756]),
#  ('httpstcody437yk4su', 1, [364]),
#  ('sourc', 3, [145, 264, 1008]),
#  ('csnew', 1, [772]),
#  ('act', 2, [82, 581]),
#  ('httpstcoj3gzqu9pqa', 1, [705]),
#  ('bedsid', 1, [694]),
#  ('socrat', 1, [1038]),
#  ('supercrit', 1, [769]),
#  ('softrobots………', 1, [1065]),
#  ('aud', 1, [118]),
#  ('past', 1, [296]),
#  ('antichrist', 1, [281]),
#  ('nicolli', 3, [138, 570, 829]),
#  ('naturel', 1, [788]),
#  ('ijspeert', 1, [95]),
#  ('httpstcoivvkwm8ymi', 1, [656]),
#  ('suffir', 1, [892]),
#  ('oscienc', 9, [24, 67, 111, 153, 328, 355, 527, 811, 932]),
#  ('httpstcoyrndlr6zh0', 1, [187]),
#  ('suincol', 1, [154]),
#  ('set', 4, [398, 469, 595, 772]),
#  ('slashandburn', 1, [808]),
#  ('httpstcoipwddkwnuf', 1, [546]),
#  ('opportunité', 2, [129, 801]),
#  ('httpstcolijub1fwym', 1, [654]),
#  ('physic', 3, [440, 728, 1029]),
#  ('befcorreiahantschelmblokesch', 1, [593]),
#  ('httpstcohrow4kecko', 1, [858]),
#  ('révolut', 1, [627]),
#  ('envscitech', 1, [248]),
#  ('séduisent', 1, [388]),
#  ('currenc', 2, [294, 468]),
#  ('mustread', 1, [573]),
#  ('zizi', 1, [988]),
#  ('httpstcooe6jhuulm9', 1, [169]),
#  ('nois', 1, [221]),
#  ('euronew', 1, [419]),
#  ('mani', 8, [122, 122, 190, 262, 346, 697, 724, 1044]),
#  ('journé', 2, [467, 1042]),
#  ('métro', 1, [93]),
#  ('ceux', 2, [168, 282]),
#  ('haptic', 2, [102, 102]),
#  ('cardiolog', 1, [758]),
#  ('mer', 1, [919]),
#  ('context', 2, [601, 975]),
#  ('us',
#   17,
#   [46,
#    195,
#    245,
#    263,
#    264,
#    359,
#    391,
#    487,
#    504,
#    623,
#    697,
#    726,
#    733,
#    741,
#    790,
#    946,
#    990]),
#  ('flyerlft', 1, [375]),
#  ('httpstco04a2xijk2f', 1, [107]),
#  ('tini', 1, [1000]),
#  ('musi', 2, [688, 801]),
#  ('httpstcoae68flyvs5', 1, [113]),
#  ('vidéo', 1, [893]),
#  ('projet',
#   13,
#   [12, 205, 304, 386, 403, 567, 569, 740, 780, 857, 955, 1024, 1037]),
#  ('httpstcowuuplby1uj', 1, [261]),
#  ('réussi', 2, [851, 955]),
#  ('httpstco2ibzrspr4b', 1, [166]),
#  ('fiberopt', 1, [544]),
#  ('worldli', 1, [675]),
#  ('embojourn', 1, [694]),
#  ('tweet', 1, [160]),
#  ('cybersécurité', 2, [182, 251]),
#  ('war', 1, [890]),
#  ('waterborn', 1, [248]),
#  ('httpstcozwtxnyi6r1', 1, [512]),
#  ('smileseq', 1, [170]),
#  ('provid', 2, [65, 703]),
#  ('oneshot', 2, [332, 680]),
#  ('httpstcovdczjrh87j', 1, [772]),
#  ('nucleosom', 2, [66, 66]),
#  ('calibr', 1, [438]),
#  ('httpstcobh4l44zsmn', 1, [166]),
#  ('httpstcoiv291y1aiu', 1, [268]),
#  ('httpstco6onrmewcnb', 1, [959]),
#  ('insiscnr', 1, [304]),
#  ('caméra', 1, [892]),
#  ('punta', 1, [919]),
#  ('stroke', 2, [972, 1029]),
#  ('bringt', 1, [105]),
#  ('httpstcor3t1sszogo', 1, [564]),
#  ('scrnaseq', 1, [734]),
#  ('curdi', 1, [824]),
#  ('possibl', 8, [12, 24, 44, 67, 153, 467, 797, 932]),
#  ('dkineu', 1, [684]),
#  ('french', 7, [150, 185, 286, 492, 682, 702, 905]),
#  ('ur', 1, [62]),
#  ('humain', 4, [183, 610, 978, 1038]),
#  ('httpstcovtwpvixgkz', 1, [883]),
#  ('entdeckt', 1, [451]),
#  ('httpstcofzvdm86ntf', 1, [1002]),
#  ('hydropow', 1, [271]),
#  ('coursera', 1, [315]),
#  ('wwim15igerslausann', 2, [475, 476]),
#  ('httpstcozdvowdckrx', 1, [93]),
#  ('solid', 1, [166]),
#  ('legales', 1, [236]),
#  ('titl', 2, [103, 845]),
#  ('clé', 1, [565]),
#  ('africangeek', 1, [233]),
#  ('duré', 1, [266]),
#  ('fête', 1, [277]),
#  ('ethdomain', 1, [187]),
#  ('mindblow', 1, [1014]),
#  ('regain', 1, [970]),
#  ('dirti', 1, [941]),
#  ('httpstcojr2dh5kofq', 1, [22]),
#  ('focusonlin', 3, [1057, 1058, 1059]),
#  ('unread', 1, [109]),
#  ('didnt', 2, [409, 938]),
#  ('finir', 1, [488]),
#  ('ericsson', 1, [212]),
#  ('invas', 1, [32]),
#  ('hormon', 1, [714]),
#  ('httpstcoassaroj5bc', 1, [739]),
#  ('a…', 1, [426]),
#  ('httpstcofiymwvlnar', 1, [512]),
#  ('vuill', 1, [107]),
#  ('smyle', 1, [304]),
#  ('altitud', 1, [611]),
#  ('itw', 2, [526, 1068]),
#  ('httpstcoubz0qtqpqz', 1, [1009]),
#  ('“', 12, [18, 69, 103, 166, 212, 260, 292, 393, 497, 504, 863, 985]),
#  ('polic', 5, [122, 163, 278, 979, 979]),
#  ('contribu', 1, [26]),
#  ('mattia', 1, [154]),
#  ('parametr', 1, [101]),
#  ('remo', 1, [425]),
#  ('effect', 1, [217]),
#  ('5gppp', 1, [549]),
#  ('bertrandpiccard', 1, [582]),
#  ('speak', 6, [296, 622, 722, 792, 886, 974]),
#  ('varient', 1, [925]),
#  ('bind', 1, [170]),
#  ('⚠️', 1, [185]),
#  ('into',
#   14,
#   [9, 50, 73, 88, 303, 396, 669, 692, 722, 726, 746, 754, 774, 839]),
#  ('oper', 7, [98, 115, 138, 438, 798, 903, 986]),
#  ('solarpanel', 1, [155]),
#  ('httpstcogyh0xlimff', 1, [704]),
#  ('httpstco089f9utg0f', 1, [462]),
#  ('er', 1, [105]),
#  ('epflsb', 2, [406, 757]),
#  ('👉httpstco0vhv4zhq4u', 1, [637]),
#  ('henri', 1, [818]),
#  ('respons', 4, [13, 65, 314, 862]),
#  ('lebenswissenschaftenundtechnologi', 1, [309]),
#  ('httpstcoe2ogm9ze7v', 1, [992]),
#  ('thanksforthefollow', 2, [330, 819]),
#  ('import', 4, [10, 323, 628, 830]),
#  ('now',
#   27,
#   [17,
#    23,
#    41,
#    88,
#    89,
#    108,
#    135,
#    246,
#    248,
#    264,
#    306,
#    335,
#    337,
#    353,
#    393,
#    415,
#    430,
#    537,
#    542,
#    556,
#    608,
#    704,
#    756,
#    805,
#    813,
#    982,
#    1027]),
#  ('evidencebas', 1, [126]),
#  ('itfaconfer', 3, [294, 468, 468]),
#  ('httpstcow5bxpzmtuo', 1, [325]),
#  ('virtualr', 3, [102, 313, 969]),
#  ('httpstcoqm2ctalgea', 1, [699]),
#  ('httpstcoyqz0yffegc', 1, [551]),
#  ('wyplosz', 1, [921]),
#  ('tell', 3, [163, 790, 846]),
#  ('unil',
#   21,
#   [15,
#    42,
#    52,
#    192,
#    219,
#    238,
#    258,
#    265,
#    301,
#    339,
#    489,
#    586,
#    674,
#    720,
#    727,
#    730,
#    780,
#    925,
#    961,
#    1025,
#    1063]),
#  ('httpstcoq0oikdrfgg', 1, [77]),
#  ('cdf', 1, [282]),
#  ('jfellay', 1, [922]),
#  ('fujilove30', 1, [455]),
#  ('carbon', 2, [575, 918]),
#  ('opportun', 11, [3, 100, 126, 296, 339, 341, 393, 505, 512, 697, 973]),
#  ('fintech', 3, [19, 127, 538]),
#  ('laupm', 1, [709]),
#  ('timko', 1, [210]),
#  ('butweet', 1, [916]),
#  ('focus', 2, [303, 507]),
#  ('sestrin1', 1, [35]),
#  ('httpstcoboxkkgrla', 1, [553]),
#  ('newest', 1, [591]),
#  ('httpstcowlhy8wmfhl', 1, [793]),
#  ('signatur', 1, [365]),
#  ('time',
#   20,
#   [2,
#    12,
#    44,
#    68,
#    125,
#    164,
#    323,
#    326,
#    361,
#    397,
#    448,
#    497,
#    586,
#    719,
#    720,
#    830,
#    858,
#    888,
#    958,
#    1056]),
#  ('rather', 1, [580]),
#  ('recrut', 1, [592]),
#  ('httpstcoglfsbvjxso', 1, [391]),
#  ('point', 7, [108, 175, 251, 272, 292, 312, 1067]),
#  ('cold', 1, [661]),
#  ('🔧', 1, [307]),
#  ('land', 1, [451]),
#  ('spacewatchm', 1, [798]),
#  ('🚆ferroviair', 1, [567]),
#  ('valu', 3, [613, 858, 914]),
#  ('httpstcoxxxszgejwt', 1, [934]),
#  ('highlight', 2, [55, 849]),
#  ('veulent', 1, [644]),
#  ('sa', 2, [202, 627]),
#  ('modernité', 1, [26]),
#  ('futuri', 1, [419]),
#  ('julio', 1, [231]),
#  ('1112', 1, [642]),
#  ('690', 4, [61, 199, 682, 840]),
#  ('httpstco45apcebiwl', 1, [853]),
#  ('📍hannov', 1, [48]),
#  ('dutilis', 1, [889]),
#  ('httpstconkj1g5q9ri', 1, [999]),
#  ('bid', 1, [594]),
#  ('porto', 1, [306]),
#  ('i2cat', 1, [428]),
#  ('gratzel', 1, [296]),
#  ('httpstco1ktfeyqze6', 1, [904]),
#  ('girault', 1, [424]),
#  ('lapp', 1, [366]),
#  ('fpga', 3, [666, 909, 917]),
#  ('joint', 1, [935]),
#  ('technologi', 1, [172]),
#  ('httpstcoquwkbsmdmf', 1, [673]),
#  ('httpstcootfyqinqgv', 1, [389]),
#  ('httpstcovekuwvpahh', 1, [839]),
#  ('httpstcotl9v2shaai', 1, [547]),
#  ('teamwork', 1, [955]),
#  ('httpstcoockxeddtcn', 1, [935]),
#  ('hit', 2, [411, 808]),
#  ('httpstco9fgitpnf', 1, [572]),
#  ('httpstcocfigqtyncp', 1, [157]),
#  ('httpstcouwvuz7i9v9', 1, [501]),
#  ('sundancefest', 2, [247, 615]),
#  ('toss2017', 1, [471]),
#  ('httpstcofotu0dxvup', 1, [1025]),
#  ('oset2017', 1, [329]),
#  ('httpstcoj8pzbx8p6v', 1, [726]),
#  ('swisseconom', 1, [1041]),
#  ('droit', 1, [939]),
#  ('seguinb', 1, [316]),
#  ('well', 5, [260, 260, 267, 761, 948]),
#  ('comité', 1, [304]),
#  ('ast', 1, [741]),
#  ('y', 3, [287, 682, 1024]),
#  ('httpstco5kzmbdfpr', 1, [350]),
#  ('httpstconok4aklk3a', 1, [557]),
#  ('umrcarrtel', 1, [766]),
#  ('httpstcoavujdhhuvu', 1, [834]),
#  ('ocsdnet', 1, [393]),
#  ('metastast', 1, [32]),
#  ('roberv', 1, [710]),
#  ('qualité', 1, [788]),
#  ('archiv', 5, [12, 351, 844, 914, 1012]),
#  ('don', 1, [278]),
#  ('far', 1, [834]),
#  ('queenuk', 1, [582]),
#  ('archizoom', 1, [453]),
#  ('slim', 1, [170]),
#  ('suck', 1, [353]),
#  ('irem\u200b', 1, [77]),
#  ('american', 1, [812]),
#  ('httpstcoh45eoihqmh', 1, [819]),
#  ('httpstcot2okbgyqsz', 1, [749]),
#  ('mutat', 1, [35]),
#  ('larchiv', 1, [844]),
#  ('berichten', 1, [309]),
#  ('26th', 1, [447]),
#  ('saphana', 1, [955]),
#  ('chemjob', 1, [617]),
#  ('hunt', 2, [173, 854]),
#  ('baks3assoc', 1, [704]),
#  ('claudiopagliara', 1, [530]),
#  ('si', 4, [12, 61, 877, 877]),
#  ('décret', 1, [1054]),
#  ('sest', 1, [548]),
#  ('httpstcoknbo1qjpfq', 1, [976]),
#  ('rtscqfd', 2, [172, 172]),
#  ('passport', 1, [1073]),
#  ('httpstcoktstr2m5yi', 1, [984]),
#  ('httpstcolnjbg0cmn', 1, [914]),
#  ('integr', 3, [83, 606, 734]),
#  ('day',
#   45,
#   [33,
#    60,
#    85,
#    100,
#    107,
#    180,
#    219,
#    245,
#    257,
#    258,
#    270,
#    301,
#    316,
#    337,
#    339,
#    341,
#    347,
#    370,
#    409,
#    411,
#    412,
#    492,
#    576,
#    587,
#    605,
#    607,
#    622,
#    657,
#    671,
#    697,
#    714,
#    869,
#    887,
#    889,
#    899,
#    931,
#    991,
#    999,
#    1009,
#    1027,
#    1045,
#    1046,
#    1062,
#    1064,
#    1065]),
#  ('httpstcomrtgu1nzsl', 1, [1053]),
#  ('httpstcorhuhh0jm97', 1, [885]),
#  ('soumithchintala', 1, [501]),
#  ('disast', 1, [519]),
#  ('periscop', 1, [953]),
#  ('httpstcojdnhozn0oa', 1, [1015]),
#  ('professorship', 1, [850]),
#  ('derrièr', 1, [1024]),
#  ('limb', 1, [970]),
#  ('clapton', 1, [1012]),
#  ('conundrum', 1, [394]),
#  ('bourgd', 1, [729]),
#  ('fondamental', 1, [827]),
#  ('daylight', 1, [376]),
#  ('a',
#   195,
#   [1,
#    13,
#    13,
#    16,
#    21,
#    24,
#    35,
#    44,
#    44,
#    45,
#    58,
#    65,
#    67,
#    88,
#    88,
#    101,
#    103,
#    107,
#    118,
#    125,
#    130,
#    134,
#    136,
#    138,
#    143,
#    147,
#    153,
#    155,
#    159,
#    163,
#    179,
#    195,
#    210,
#    211,
#    213,
#    229,
#    236,
#    237,
#    242,
#    245,
#    246,
#    247,
#    249,
#    254,
#    257,
#    260,
#    260,
#    262,
#    263,
#    264,
#    270,
#    281,
#    281,
#    287,
#    289,
#    294,
#    303,
#    307,
#    314,
#    317,
#    320,
#    323,
#    326,
#    328,
#    334,
#    336,
#    336,
#    337,
#    337,
#    358,
#    361,
#    371,
#    375,
#    375,
#    394,
#    407,
#    409,
#    409,
#    409,
#    409,
#    413,
#    414,
#    415,
#    418,
#    432,
#    435,
#    436,
#    450,
#    454,
#    468,
#    469,
#    469,
#    469,
#    480,
#    485,
#    486,
#    493,
#    494,
#    494,
#    504,
#    512,
#    512,
#    516,
#    518,
#    526,
#    527,
#    530,
#    531,
#    534,
#    539,
#    546,
#    546,
#    547,
#    573,
#    581,
#    589,
#    589,
#    595,
#    596,
#    600,
#    624,
#    625,
#    628,
#    628,
#    639,
#    641,
#    643,
#    646,
#    648,
#    668,
#    673,
#    674,
#    677,
#    678,
#    682,
#    685,
#    688,
#    690,
#    692,
#    708,
#    710,
#    710,
#    717,
#    722,
#    725,
#    732,
#    736,
#    736,
#    736,
#    753,
#    768,
#    772,
#    795,
#    801,
#    816,
#    820,
#    821,
#    835,
#    838,
#    842,
#    845,
#    864,
#    866,
#    875,
#    878,
#    881,
#    883,
#    884,
#    899,
#    902,
#    908,
#    911,
#    916,
#    932,
#    933,
#    938,
#    938,
#    946,
#    948,
#    956,
#    957,
#    957,
#    960,
#    979,
#    979,
#    982,
#    1009,
#    1024,
#    1029,
#    1034,
#    1036,
#    1044,
#    1055,
#    1072,
#    1073]),
#  ('httpstco9lr6sbjlil', 1, [669]),
#  ('patrimoin', 3, [243, 844, 844]),
#  ('scari', 1, [1044]),
#  ('mondial', 1, [1024]),
#  ('ug', 1, [1011]),
#  ('haïku', 1, [311]),
#  ('bionic', 1, [725]),
#  ('profit', 1, [129]),
#  ('her', 2, [359, 808]),
#  ('uzhscienc', 1, [489]),
#  ('httpstcoerqa06qoiy', 1, [62]),
#  ('scan', 2, [849, 949]),
#  ('rajiv', 1, [915]),
#  ('zusammen', 1, [105]),
#  ('big', 4, [315, 442, 625, 731]),
#  ('httpstcoptv8wrfg9u', 1, [484]),
#  ('elsevierchemist', 1, [745]),
#  ('propriété', 1, [923]),
#  ('rewalkrobot', 1, [871]),
#  ('win', 5, [77, 175, 267, 272, 688]),
#  ('httpstcozfq3kf9r6r', 1, [617]),
#  ('each', 2, [858, 858]),
#  ('lor', 3, [543, 569, 874]),
#  ('pfurrer', 1, [346]),
#  ('fab', 1, [916]),
#  ('neighbor', 1, [66]),
#  ('kind', 1, [414]),
#  ('vu', 1, [130]),
#  ('rappel', 1, [168]),
#  ('httpstcolmdqyovvl9', 1, [53]),
#  ('lithographi', 1, [949]),
#  ('sccerfeebd', 1, [608]),
#  ('scientificqu', 1, [280]),
#  ('httpstco15wpb7m1bb', 1, [935]),
#  ('27', 2, [13, 633]),
#  ('httpstco7zgbr0eotc', 1, [187]),
#  ('comfort', 2, [613, 867]),
#  ('😍', 1, [764]),
#  ('gesundheit', 1, [638]),
#  ('hill', 1, [736]),
#  ('feder', 5, [54, 596, 641, 675, 950]),
#  ('marion', 1, [824]),
#  ('agre', 1, [615]),
#  ('hour', 1, [919]),
#  ('what',
#   22,
#   [139,
#    204,
#    278,
#    278,
#    359,
#    397,
#    409,
#    448,
#    474,
#    481,
#    516,
#    521,
#    580,
#    613,
#    671,
#    699,
#    717,
#    799,
#    938,
#    956,
#    995,
#    1060]),
#  ('pattern', 2, [6, 387]),
#  ('be',
#   40,
#   [65,
#    78,
#    80,
#    102,
#    108,
#    213,
#    236,
#    263,
#    267,
#    314,
#    325,
#    374,
#    411,
#    447,
#    457,
#    479,
#    501,
#    513,
#    519,
#    547,
#    594,
#    613,
#    613,
#    655,
#    660,
#    666,
#    715,
#    715,
#    760,
#    791,
#    845,
#    846,
#    863,
#    903,
#    909,
#    915,
#    999,
#    1002,
#    1028,
#    1072]),
#  ('21st', 2, [89, 971]),
#  ('yve', 1, [898]),
#  ('resolv', 1, [589]),
#  ('nzz', 1, [477]),
#  ('20242028', 1, [1042]),
#  ('lts5', 1, [855]),
#  ('dernièr', 1, [12]),
#  ('driverless', 1, [1044]),
#  ('press', 2, [232, 589]),
#  ('rate', 1, [834]),
#  ('lc3technolog', 1, [748]),
#  ('httpstcoluq7bwf0mh', 1, [386]),
#  ('largescal', 1, [469]),
#  ('grave', 1, [922]),
#  ('httpstcoum0imlludj', 1, [361]),
#  ('refract', 1, [770]),
#  ('httpstcobeq7t6h43v', 1, [667]),
#  ('policevalai', 1, [979]),
#  ('ehr', 1, [25]),
#  ('httpstcohnsuosekx3', 1, [344]),
#  ('siliconbas', 1, [398]),
#  ('golang', 1, [347]),
#  ('technionl', 1, [522]),
#  ('sunris', 1, [749]),
#  ('superpouvoir', 1, [94]),
#  ('konrad', 1, [785]),
#  ('lire', 2, [70, 351]),
#  ('moschaer', 1, [474]),
#  ('serendip', 1, [258]),
#  ('belt', 1, [598]),
#  ('httpstcop8px0sqn4q', 1, [803]),
#  ('grapheneco', 1, [334]),
#  ('entretien', 1, [463]),
#  ('matièr', 2, [26, 392]),
#  ('françai', 3, [244, 744, 939]),
#  ('ideal', 3, [640, 883, 884]),
#  ('artmyn', 1, [849]),
#  ('ia', 5, [165, 181, 452, 452, 610]),
#  ('risqu', 2, [185, 1048]),
#  ('uchicago', 1, [349]),
#  ('nouveaux', 2, [357, 408]),
#  ('httpstcosjyt8nxfat', 1, [407]),
#  ('seen', 2, [691, 751]),
#  ('confianc', 1, [723]),
#  ('cargobik', 1, [944]),
#  ('hk–chic', 1, [90]),
#  ('httpstcot9zid3kv0c', 1, [237]),
#  ('ces2017', 1, [460]),
#  ('ceremoni', 5, [137, 238, 255, 288, 767]),
#  ('luciano', 1, [22]),
#  ('bellon', 1, [419]),
#  ('plan', 3, [618, 910, 922]),
#  ('exzellenz', 1, [954]),
#  ('extens', 1, [899]),
#  ('shametortur', 1, [278]),
#  ('psich', 1, [504]),
#  ('début', 3, [47, 901, 1018]),
#  ('cors', 1, [906]),
#  ('objetsconnecté', 1, [251]),
#  ('br', 1, [238]),
#  ('miniatur', 1, [690]),
#  ('httpstco70efmmqrxt', 1, [889]),
#  ('httpstcod2oi9inptx', 1, [177]),
#  ('2nd', 3, [391, 393, 899]),
#  ('httpstcoaf6shy2cvv', 1, [373]),
#  ('httpstco9olqaib7vf', 1, [375]),
#  ('onlineschul', 1, [188]),
#  ('stimmungsbild', 1, [209]),
#  ('store', 1, [217]),
#  ('httpstcob4qwcq4hda', 1, [143]),
#  ('theme', 1, [669]),
#  ('devop', 1, [521]),
#  ('trump', 3, [556, 620, 1054]),
#  ('vaud', 4, [42, 457, 889, 1039]),
#  ('fractur', 1, [1030]),
#  ('artmynch', 1, [1073]),
#  ('aebisch', 3, [702, 821, 1071]),
#  ('sequencedirect', 1, [378]),
#  ('battin', 1, [119]),
#  ('photograph', 4, [44, 328, 527, 908]),
#  ('httpstcoigikg8yrxi', 1, [488]),
#  ('httpstco40du7yawd9', 1, [506]),
#  ('traditionalcathol', 1, [936]),
#  ('intellig', 6, [62, 69, 292, 610, 797, 1070]),
#  ('httpstcokft1w7g4lu', 1, [264]),
#  ('jvican', 1, [427]),
#  ('gehendragurung', 1, [350]),
#  ('3001', 1, [243]),
#  ('thesi', 6, [401, 469, 502, 743, 808, 867]),
#  ('diplomtypu', 1, [188]),
#  ('httpstcokmp1urxpuo', 1, [156]),
#  ('revolutionari', 1, [577]),
#  ('2020', 3, [521, 981, 996]),
#  ('httpstcoceuog4myqi', 1, [971]),
#  ('grand', 4, [602, 752, 823, 913]),
#  ('httpstcohmtp66wt6w', 1, [916]),
#  ('magistrale2017', 3, [191, 593, 1019]),
#  ('interministériel', 1, [687]),
#  ('buccipergenova', 1, [639]),
#  ('httpstco16jwmxzzn8', 1, [634]),
#  ('httpstcobkliewfcro', 1, [100]),
#  ('tel', 1, [658]),
#  ('httpstcohczufdnrbc', 1, [818]),
#  ('may', 4, [263, 728, 732, 972]),
#  ('👹', 1, [240]),
#  ('incubateur', 1, [297]),
#  ('falt', 1, [737]),
#  ('captur', 3, [575, 585, 770]),
#  ('smit', 1, [575]),
#  ('take',
#   17,
#   [27,
#    125,
#    137,
#    341,
#    422,
#    613,
#    628,
#    719,
#    765,
#    772,
#    873,
#    886,
#    937,
#    963,
#    979,
#    1004,
#    1009]),
#  ('scholarli', 1, [422]),
#  ('httpstcooueqdvczdd', 1, [878]),
#  ('httpstcojw8swvtltq', 1, [494]),
#  ('suivi', 1, [265]),
#  ('barran', 1, [661]),
#  ('highlights1112', 1, [438]),
#  ('savmap', 1, [235]),
#  ('skill', 3, [640, 762, 775]),
#  ('entier', 1, [644]),
#  ('microbiota', 1, [498]),
#  ('lavoir', 1, [392]),
#  ('écrivezn', 1, [197]),
#  ('neuen', 2, [188, 822]),
#  ('smartgrid', 1, [510]),
#  ('httpstcoz9peeqtzc', 1, [788]),
#  ('been', 9, [104, 264, 269, 387, 407, 507, 540, 812, 963]),
#  ('next',
#   19,
#   [78,
#    108,
#    108,
#    117,
#    180,
#    267,
#    461,
#    464,
#    479,
#    623,
#    626,
#    658,
#    672,
#    760,
#    762,
#    865,
#    919,
#    973,
#    975]),
#  ('leila', 1, [935]),
#  ('exploit', 1, [1026]),
#  ('forumepfl', 5, [58, 65, 312, 733, 760]),
#  ('transit', 2, [320, 381]),
#  ('sciencevalai', 1, [743]),
#  ('httpstcofmf9ged4km', 1, [901]),
#  ('lab',
#   16,
#   [95,
#    95,
#    100,
#    245,
#    258,
#    387,
#    419,
#    419,
#    503,
#    532,
#    591,
#    699,
#    731,
#    864,
#    958,
#    980]),
#  ('lespac', 1, [570]),
#  ('httpstco9qmkshraqj', 1, [802]),
#  ('these', 8, [85, 116, 269, 323, 414, 511, 641, 859]),
#  ('httpstco9j5gplmcoi', 1, [481]),
#  ('scolair', 1, [783]),
#  ('scienc',
#   34,
#   [4,
#    30,
#    49,
#    109,
#    131,
#    183,
#    201,
#    210,
#    250,
#    300,
#    301,
#    358,
#    393,
#    420,
#    420,
#    426,
#    443,
#    524,
#    544,
#    593,
#    600,
#    616,
#    688,
#    710,
#    713,
#    730,
#    743,
#    764,
#    778,
#    810,
#    904,
#    969,
#    1054,
#    1056]),
#  ('🇨🇭innov', 1, [888]),
#  ('docomomo', 1, [633]),
#  ('ehl', 1, [744]),
#  ('app', 5, [323, 528, 571, 856, 876]),
#  ('identifi', 4, [35, 170, 734, 880]),
#  ('inaugur', 3, [106, 273, 826]),
#  ('prison', 1, [122]),
#  ('lereseau', 3, [251, 321, 645]),
#  ('nation', 3, [54, 64, 480]),
#  ('unineuchatel', 1, [402]),
#  ('socibiz', 1, [791]),
#  ('donnez', 1, [144]),
#  ('uefa', 3, [128, 291, 992]),
#  ('dimprovis', 1, [894]),
#  ('httpstcofsy9srernq', 1, [495]),
#  ('pedagog', 1, [219]),
#  ('mpagran', 2, [659, 740]),
#  ('selfsuffici', 2, [83, 155]),
#  ('music', 4, [221, 221, 394, 750]),
#  ('mélodi', 1, [942]),
#  ('httpstcoxgb8ynuklt', 1, [585]),
#  ('microchip', 1, [636]),
#  ('search', 3, [134, 316, 640]),
#  ('aprè', 6, [277, 665, 705, 752, 900, 1037]),
#  ('continu', 3, [166, 177, 703]),
#  ('sfgeneva', 1, [672]),
#  ('hanahan', 1, [32]),
#  ('statt', 1, [167]),
#  ('sonor', 1, [876]),
#  ('idsia', 1, [905]),
#  ('hat', 3, [188, 241, 413]),
#  ('yunuscentr', 2, [635, 672]),
#  ('fribourg', 1, [705]),
#  ('yunu', 3, [107, 107, 791]),
#  ('pfsc', 1, [291]),
#  ('httpstcoqqh8dbzpub', 1, [665]),
#  ('klok', 1, [336]),
#  ('prevent', 1, [486]),
#  ('ultrasound', 1, [855]),
#  ('immers', 1, [444]),
#  ('even', 10, [110, 111, 134, 278, 355, 556, 620, 811, 957, 979]),
#  ('✌🏽🌱', 1, [253]),
#  ('rapist', 1, [278]),
#  ('unicorn', 1, [563]),
#  ('fibril', 1, [661]),
#  ('achiev', 4, [397, 448, 519, 681]),
#  ('irak', 1, [1067]),
#  ('gamayanew', 3, [721, 891, 910]),
#  ('httpstcovkmbzf7wc0', 1, [307]),
#  ('symposium', 3, [28, 481, 807]),
#  ('httpstcoptubxymebp', 1, [949]),
#  ('deco', 1, [1020]),
#  ('condit', 1, [986]),
#  ('financi', 2, [127, 291]),
#  ('jaqu', 1, [42]),
#  ('httpstcoumkzw0yvo0', 1, [820]),
#  ('dougla', 1, [32]),
#  ('their',
#   19,
#   [17,
#    58,
#    66,
#    216,
#    301,
#    323,
#    371,
#    450,
#    522,
#    525,
#    528,
#    634,
#    649,
#    679,
#    707,
#    716,
#    765,
#    791,
#    931]),
#  ('besoin', 3, [118, 283, 1030]),
#  ('michel', 1, [782]),
#  ('swissquotenew', 1, [825]),
#  ('can',
#   33,
#   [21,
#    80,
#    124,
#    128,
#    169,
#    236,
#    353,
#    359,
#    397,
#    406,
#    414,
#    448,
#    510,
#    547,
#    547,
#    562,
#    577,
#    585,
#    589,
#    635,
#    660,
#    666,
#    679,
#    690,
#    791,
#    791,
#    831,
#    856,
#    869,
#    909,
#    937,
#    1008,
#    1055]),
#  ('ebugnion', 2, [10, 25]),
#  ('esrofficiel', 1, [130]),
#  ('httpstcog6qbwtrwga', 1, [402]),
#  ('beim', 2, [309, 890]),
#  ('modélis', 2, [568, 766]),
#  ('été', 2, [710, 710]),
#  ('brevet', 1, [923]),
#  ('httpstcou4fnmegdup', 1, [990]),
#  ('wslresearch', 4, [526, 653, 785, 984]),
#  ('httpstcofp0yajwe9n', 1, [385]),
#  ('11am', 1, [31]),
#  ('loch', 1, [189]),
#  ('featur', 4, [458, 612, 856, 905]),
#  ('httpstcofclluldktk', 1, [571]),
#  ('epflcdm', 1, [817]),
#  ('iranian', 2, [359, 556]),
#  ('perspect', 2, [562, 831]),
#  ('savonario', 1, [70]),
#  ('httpstcopo2quiakbh', 1, [986]),
#  ('jordi', 1, [227]),
#  ('bra', 1, [584]),
#  ('httpstcobvuygd07tv', 1, [988]),
#  ('glisser', 1, [548]),
#  ('eröffnungsred', 1, [1015]),
#  ('httpstcodoj2hmekbc', 1, [828]),
#  ('surfac', 2, [87, 967]),
#  ('badcompani', 1, [85]),
#  ('campusday', 1, [721]),
#  ('personifi', 1, [50]),
#  ('martin', 3, [568, 643, 863]),
#  ('httpstcodhsmrolyj7', 1, [429]),
#  ('génie', 1, [842]),
#  ('continuum', 1, [55]),
#  ('httpstcotw2m5h2tnt', 1, [960]),
#  ('httpstcomyvdqpm7r4', 1, [394]),
#  ('chinagoabroad', 1, [530]),
#  ('adressé', 1, [742]),
#  ('savoglidi', 1, [1027]),
#  ('fad', 1, [1056]),
#  ('jqinew', 1, [431]),
#  ('australia', 1, [278]),
#  ('nécessit', 1, [567]),
#  ('httpstcofhtmlunack', 1, [52]),
#  ('yeux', 1, [924]),
#  ('httpstcowzdrbf6q3m', 1, [876]),
#  ('httpstcogyvwr4hg0h', 1, [385]),
#  ('gobolo', 1, [698]),
#  ('intelligenz', 1, [737]),
#  ('mend', 1, [419]),
#  ('digitalhealth', 4, [84, 181, 514, 588]),
#  ('illustr', 3, [382, 652, 841]),
#  ('réduisent', 1, [149]),
#  ('preventiteu', 1, [588]),
#  ('advantag', 1, [341]),
#  ('🙏🏻', 1, [418]),
#  ('than', 12, [21, 64, 64, 111, 214, 355, 379, 531, 580, 778, 811, 858]),
#  ('knowledg', 1, [524]),
#  ('httpstcokm1p7dnpr4', 1, [919]),
#  ('subject', 1, [4]),
#  ('rosicrucioprotest', 1, [936]),
#  ('httpstcoxesvznpwj2', 1, [503]),
#  ('rue', 1, [383]),
#  ('unildur', 2, [586, 961]),
#  ('justinegdc', 1, [808]),
#  ('janvier', 1, [958]),
#  ('httpstcoslv8b53ggj', 1, [578]),
#  ('stellar', 1, [269]),
#  ('vice', 1, [875]),
#  ('httpstco1fgggsnrkl', 1, [95]),
#  ('jet', 2, [90, 115]),
#  ('met', 2, [108, 269]),
#  ('zebrafish', 1, [249]),
#  ('fabriqu', 1, [877]),
#  ('clipair', 2, [711, 711]),
#  ('limpress', 1, [287]),
#  ('httpstcorpg0ytemsu', 1, [176]),
#  ('httpstcomamryi4lj1', 1, [751]),
#  ('société', 1, [565]),
#  ('dont', 6, [134, 215, 224, 281, 325, 979]),
#  ('built', 3, [442, 1014, 1055]),
#  ('surprisingli', 1, [87]),
#  ('authentiqu', 1, [942]),
#  ('sécurité', 3, [81, 892, 978]),
#  ('dsmeu', 3, [140, 263, 549]),
#  ('🙌', 2, [77, 522]),
#  ('mass', 2, [624, 745]),
#  ('httpstcoxorkl6jcgv', 1, [1071]),
#  ('territoirela', 1, [851]),
#  ('jeandaniel', 1, [552]),
#  ('class', 3, [383, 429, 882]),
#  ('forbesunder30', 1, [143]),
#  ('prix', 4, [710, 801, 842, 961]),
#  ('ecologi', 1, [644]),
#  ('forêt', 3, [543, 653, 784]),
#  ('lunil', 1, [925]),
#  ('httpstcokjpogu24it', 1, [266]),
#  ('httpstcol4mhqa7upb', 1, [8]),
#  ('gordon', 1, [88]),
#  ('cyclometal', 2, [29, 743]),
#  ('900', 1, [337]),
#  ('capac', 1, [126]),
#  ('httpstcontjzmgmydp', 1, [317]),
#  ('offgrid', 1, [642]),
#  ('httpstcoqfzdfohgpp', 1, [129]),
#  ('unser', 1, [638]),
#  ('develop',
#   21,
#   [31,
#    132,
#    159,
#    166,
#    169,
#    229,
#    419,
#    440,
#    551,
#    577,
#    577,
#    607,
#    624,
#    647,
#    677,
#    678,
#    684,
#    712,
#    732,
#    966,
#    980]),
#  ('srg', 1, [144]),
#  ('gold', 1, [577]),
#  ('au',
#   36,
#   [20,
#    26,
#    96,
#    194,
#    202,
#    243,
#    304,
#    325,
#    345,
#    382,
#    462,
#    467,
#    566,
#    583,
#    644,
#    665,
#    705,
#    752,
#    844,
#    857,
#    861,
#    894,
#    913,
#    925,
#    954,
#    954,
#    962,
#    969,
#    976,
#    977,
#    996,
#    1017,
#    1017,
#    1031,
#    1035,
#    1043]),
#  ('httpstcoq0iipbcctw', 1, [351]),
#  ('désormai', 1, [16]),
#  ('httpstcovnvszikvoc', 1, [415]),
#  ('while', 2, [938, 960]),
#  ('httpstcooeey3veeb4', 1, [123]),
#  ('opendatach', 3, [587, 621, 656]),
#  ('universel', 1, [602]),
#  ('contrib', 1, [740]),
#  ('voici', 1, [325]),
#  ('fast', 3, [233, 495, 941]),
#  ('linnov', 2, [902, 1054]),
#  ('highlights1212', 1, [178]),
#  ('guess', 1, [1060]),
#  ('traver', 3, [70, 351, 893]),
#  ('sociologi', 1, [463]),
#  ('blockfest', 1, [561]),
#  ('garfieldabh', 1, [1019]),
#  ('devic', 1, [878]),
#  ('bilanmagazin', 1, [243]),
#  ('httpstcoeoe8vhmgek', 1, [804]),
#  ('httpstcowflk2bilxi', 1, [485]),
#  ('allergytest', 1, [564]),
#  ('dtutweet', 2, [71, 1006]),
#  ('enough', 1, [965]),
#  ('6th', 1, [301]),
#  ('httpstcofeglco5gun', 1, [431]),
#  ('emprunt', 1, [157]),
#  ('follicularlymphoma', 1, [943]),
#  ('cumul', 1, [337]),
#  ('itfa', 2, [294, 468]),
#  ('shevchenko', 1, [745]),
#  ('httpstcolliavntc9r', 1, [831]),
#  ('pie', 1, [383]),
#  ('kellyannepol', 1, [637]),
#  ('givaudan', 1, [522]),
#  ('pavilion', 1, [770]),
#  ('enjoy', 1, [575]),
#  ('examen', 2, [161, 495]),
#  ('waltz', 1, [865]),
#  ('tissu', 4, [712, 734, 966, 1000]),
#  ('httpstcoruxbhhsidi', 1, [803]),
#  ('3e', 1, [780]),
#  ('wasserverschmutzung', 1, [828]),
#  ('pdf', 1, [327]),
#  ('httpstco5mf6xxcaih', 1, [103]),
#  ('httpstcoinstarq4w', 1, [806]),
#  ('gise', 2, [441, 772]),
#  ('httpstcohbayeuqajd', 1, [314]),
#  ('royes', 1, [290]),
#  ('parti', 2, [592, 875]),
#  ('0206', 1, [453]),
#  ('rayonsx', 1, [351]),
#  ('ressourc', 2, [539, 939]),
#  ('proposai', 1, [862]),
#  ('resolut', 1, [446]),
#  ('rape', 2, [122, 979]),
#  ('cont', 1, [375]),
#  ('sctr', 1, [375]),
#  ('ovat', 1, [1]),
#  ('présenc', 1, [829]),
#  ('didn', 1, [692]),
#  ('nips2016', 1, [97]),
#  ('fb', 1, [192]),
#  ('wearabl', 2, [521, 642]),
#  ('httpstcohpfqgy1yuf', 1, [304]),
#  ('vie', 2, [266, 705]),
#  ('normal', 2, [104, 234]),
#  ('3d', 7, [109, 193, 206, 332, 544, 544, 680]),
#  ('note', 2, [682, 840]),
#  ('googl', 2, [276, 287]),
#  ('herzlich', 1, [25]),
#  ('limit', 1, [909]),
#  ('english', 1, [469]),
#  ('hopitauxunig', 3, [116, 357, 437]),
#  ('httpstconhsvjdpa0w', 1, [142]),
#  ('httpstcojlgbaxvtkj', 1, [924]),
#  ('httpstcoe3pdcg6nvb', 1, [30]),
#  ('♻🔆', 1, [757]),
#  ('open',
#   26,
#   [2,
#    49,
#    54,
#    109,
#    188,
#    245,
#    260,
#    348,
#    393,
#    393,
#    420,
#    442,
#    453,
#    480,
#    504,
#    515,
#    587,
#    590,
#    688,
#    688,
#    703,
#    730,
#    850,
#    898,
#    911,
#    960]),
#  ('befor', 5, [90, 275, 504, 727, 751]),
#  ('intel', 4, [234, 241, 533, 624]),
#  ('inscrut', 1, [236]),
#  ('tempêt', 1, [543]),
#  ('arm', 1, [585]),
#  ('httpstcot7ui6snzek', 1, [1067]),
#  ('wissenschaftw', 1, [743]),
#  ('interessant', 1, [969]),
#  ('campusbiotech', 2, [181, 708]),
#  ('unicopenhagen', 1, [817]),
#  ('httpstconr6udhtjm', 1, [211]),
#  ('ignobel', 2, [230, 380]),
#  ('law', 1, [163]),
#  ('•', 1, [613]),
#  ('➡️httpstcofek8vok2dn', 1, [878]),
#  ('epigenet', 1, [622]),
#  ('fabiansuter1', 1, [975]),
#  ('45', 1, [150]),
#  ('quantum', 8, [44, 113, 328, 377, 395, 527, 551, 865]),
#  ('anywher', 1, [957]),
#  ('texa', 2, [215, 969]),
#  ('httpstcoym6u32ngfp', 1, [566]),
#  ('vp', 1, [688]),
#  ('sen', 2, [279, 1071]),
#  ('custom', 1, [492]),
#  ('reflex', 1, [993]),
#  ('naturenpj', 1, [119]),
#  ('httpstcobiqcjzrjl8', 1, [917]),
#  ('disconcert', 1, [951]),
#  ('unternehmertum', 1, [105]),
#  ('hi',
#   16,
#   [142,
#    142,
#    195,
#    296,
#    310,
#    458,
#    485,
#    503,
#    550,
#    550,
#    674,
#    816,
#    855,
#    867,
#    869,
#    960]),
#  ('imit', 2, [599, 610]),
#  ('innovaud', 5, [143, 148, 399, 421, 605]),
#  ('florislondon', 1, [582]),
#  ('kurs', 1, [167]),
#  ('httpstcot9bil1adqz', 1, [688]),
#  ('danss', 1, [1030]),
#  ('httpstcor7o2hxomyv', 1, [1040]),
#  ('décerné', 1, [710]),
#  ('februari', 4, [200, 391, 464, 465]),
#  ('httpstcoixgzzoaatx', 1, [658]),
#  ('martelinnov', 2, [263, 391]),
#  ('pytorch', 2, [859, 859]),
#  ('hesso', 5, [11, 63, 200, 525, 829]),
#  ('plaît', 1, [467]),
#  ('swissmadehardwar', 1, [624]),
#  ('length', 2, [103, 845]),
#  ('httpstcos8zkriahbq', 1, [69]),
#  ('regul', 1, [833]),
#  ('httpstcotu6j8j44kl', 1, [42]),
#  ('architectureschool', 1, [93]),
#  ('other', 3, [214, 260, 413]),
#  ('with',
#   103,
#   [7,
#    14,
#    27,
#    34,
#    39,
#    60,
#    66,
#    68,
#    75,
#    76,
#    79,
#    83,
#    86,
#    100,
#    107,
#    120,
#    124,
#    135,
#    142,
#    148,
#    155,
#    210,
#    211,
#    219,
#    226,
#    237,
#    240,
#    259,
#    260,
#    264,
#    288,
#    294,
#    313,
#    315,
#    324,
#    347,
#    352,
#    380,
#    387,
#    398,
#    399,
#    409,
#    419,
#    446,
#    466,
#    468,
#    504,
#    506,
#    507,
#    507,
#    514,
#    526,
#    529,
#    534,
#    544,
#    572,
#    572,
#    594,
#    605,
#    611,
#    613,
#    626,
#    628,
#    640,
#    654,
#    669,
#    676,
#    685,
#    686,
#    725,
#    726,
#    733,
#    735,
#    741,
#    741,
#    770,
#    775,
#    785,
#    786,
#    790,
#    795,
#    795,
#    809,
#    813,
#    813,
#    830,
#    832,
#    855,
#    905,
#    907,
#    909,
#    911,
#    915,
#    917,
#    934,
#    935,
#    949,
#    979,
#    980,
#    984,
#    985,
#    1036,
#    1055]),
#  ('vitrag', 1, [1070]),
#  ('httpstcop6oxc1fnh6', 1, [683]),
#  ('httpstcoitu0ssebug', 1, [892]),
#  ('center',
#   17,
#   [54,
#    194,
#    390,
#    443,
#    464,
#    476,
#    480,
#    546,
#    606,
#    640,
#    829,
#    872,
#    973,
#    974,
#    992,
#    1009,
#    1048]),
#  ('duboul', 1, [783]),
#  ('rdv', 1, [325]),
#  ('method', 6, [166, 332, 377, 551, 638, 786]),
#  ('she', 1, [270]),
#  ('helga', 1, [210]),
#  ('12', 4, [264, 499, 525, 546]),
#  ('connai', 1, [199]),
#  ('déchet', 1, [383]),
#  ('v', 2, [297, 913]),
#  ('httpstcote2xm3np15', 1, [502]),
#  ('1000', 2, [279, 734]),
#  ('100kg', 1, [430]),
#  ('month', 5, [247, 407, 438, 471, 615]),
#  ('httpstcocjnak2wc0p', 1, [225]),
#  ('durabilité', 1, [961]),
#  ('heritag', 1, [299]),
#  ('httpstco5a390onksj', 1, [1048]),
#  ('leuga', 1, [1018]),
#  ('httpstcowsosmmrtbl', 1, [974]),
#  ('dphroy', 1, [735]),
#  ('done', 5, [591, 691, 761, 948, 1006]),
#  ('stefanotempesta', 1, [127]),
#  ('microcityn', 1, [402]),
#  ('mindfulvr', 1, [518]),
#  ('massiv', 1, [515]),
#  ('httpstco4opdwrqfn8', 1, [200]),
#  ('daylightsymposium', 1, [376]),
#  ('and',
#   215,
#   [0,
#    10,
#    10,
#    13,
#    27,
#    27,
#    28,
#    34,
#    42,
#    44,
#    59,
#    64,
#    65,
#    65,
#    66,
#    68,
#    68,
#    68,
#    68,
#    78,
#    80,
#    86,
#    101,
#    103,
#    103,
#    108,
#    108,
#    108,
#    109,
#    112,
#    116,
#    121,
#    121,
#    124,
#    125,
#    126,
#    126,
#    138,
#    139,
#    142,
#    150,
#    164,
#    166,
#    166,
#    170,
#    171,
#    175,
#    176,
#    185,
#    190,
#    191,
#    193,
#    195,
#    210,
#    210,
#    217,
#    220,
#    229,
#    250,
#    250,
#    258,
#    259,
#    262,
#    263,
#    263,
#    264,
#    269,
#    272,
#    284,
#    290,
#    290,
#    291,
#    292,
#    292,
#    294,
#    296,
#    299,
#    301,
#    307,
#    308,
#    313,
#    315,
#    321,
#    328,
#    334,
#    336,
#    337,
#    339,
#    339,
#    341,
#    341,
#    348,
#    352,
#    352,
#    376,
#    376,
#    390,
#    390,
#    401,
#    409,
#    416,
#    419,
#    419,
#    427,
#    440,
#    442,
#    449,
#    458,
#    458,
#    464,
#    468,
#    469,
#    485,
#    498,
#    501,
#    507,
#    513,
#    515,
#    518,
#    518,
#    525,
#    526,
#    526,
#    527,
#    531,
#    545,
#    547,
#    557,
#    561,
#    561,
#    575,
#    575,
#    577,
#    585,
#    589,
#    598,
#    606,
#    613,
#    623,
#    625,
#    626,
#    628,
#    639,
#    639,
#    641,
#    641,
#    642,
#    650,
#    658,
#    660,
#    662,
#    663,
#    666,
#    671,
#    671,
#    671,
#    675,
#    678,
#    679,
#    686,
#    688,
#    689,
#    690,
#    694,
#    699,
#    699,
#    703,
#    719,
#    724,
#    733,
#    734,
#    741,
#    743,
#    743,
#    745,
#    745,
#    756,
#    777,
#    785,
#    798,
#    807,
#    813,
#    820,
#    820,
#    830,
#    830,
#    845,
#    847,
#    850,
#    858,
#    859,
#    866,
#    869,
#    873,
#    898,
#    905,
#    908,
#    928,
#    933,
#    938,
#    941,
#    959,
#    960,
#    973,
#    981,
#    982,
#    995,
#    1014,
#    1036,
#    1036,
#    1036,
#    1046,
#    1060,
#    1065,
#    1072]),
#  ('build', 9, [198, 320, 381, 510, 596, 669, 669, 684, 750]),
#  ('gqdaley', 2, [359, 556]),
#  ('solut', 5, [109, 217, 318, 687, 842]),
#  ('httpstcopr7gbu3f04', 1, [584]),
#  ('chemic', 1, [743]),
#  ('scarletyohansson', 1, [281]),
#  ('httpstcomrcygxna6g', 1, [229]),
#  ('cnp', 1, [247]),
#  ('détect', 1, [383]),
#  ('help', 12, [60, 109, 236, 359, 450, 511, 530, 547, 818, 948, 979, 1029]),
#  ('quel', 2, [543, 789]),
#  ('labor', 2, [294, 468]),
#  ('larg', 2, [13, 104]),
#  ('squat', 1, [1069]),
#  ('race', 1, [178]),
#  ('politonew', 2, [196, 639]),
#  ('sdscdatasci', 7, [235, 295, 443, 480, 610, 982, 984]),
#  ('puzzl', 1, [938]),
#  ('monitor', 3, [41, 514, 514]),
#  ('einem', 1, [241]),
#  ('henrik', 1, [108]),
#  ('startinggood', 1, [793]),
#  ('gopro', 1, [1036]),
#  ('soutien', 1, [996]),
#  ('httpstco9f2iuduopr', 1, [1008]),
#  ('mediaroad', 1, [27]),
#  ('epflpark', 6, [3, 200, 432, 448, 589, 613]),
#  ('manquer', 1, [902]),
#  ('printedelectron', 1, [642]),
#  ('womensmarch', 2, [281, 582]),
#  ('globe🌍', 1, [614]),
#  ('taxonomi', 2, [469, 469]),
#  ('celui', 1, [862]),
#  ('magistretti', 1, [741]),
#  ('httpstcok6xzd2bs7m', 1, [332]),
#  ('tax', 1, [584]),
#  ('until', 2, [590, 671]),
#  ('cad', 1, [603]),
#  ('fleshandblood', 2, [216, 634]),
#  ('directli', 2, [30, 44]),
#  ('microbi', 1, [555]),
#  ('touch', 3, [352, 725, 878]),
#  ('campu',
#   16,
#   [37,
#    40,
#    82,
#    130,
#    202,
#    342,
#    430,
#    455,
#    643,
#    812,
#    925,
#    996,
#    996,
#    1032,
#    1063,
#    1066]),
#  ('françou', 1, [535]),
#  ('httpstcogts6lu5tnr', 1, [989]),
#  ('gtgt', 1, [1063]),
#  ('httpstcop96wkiy9zc', 1, [790]),
#  ('httpstco6ztzov8ylh', 1, [837]),
#  ('breast', 1, [8]),
#  ('jour', 4, [402, 894, 989, 1066]),
#  ('limplant', 1, [1030]),
#  ('hecpari', 1, [482]),
#  ('sciencefor2020', 2, [359, 556]),
#  ('neuroprothès', 1, [947]),
#  ('vallebenasqu', 1, [431]),
#  ('studenten', 1, [309]),
#  ('bruyant', 1, [567]),
#  ('imdbschool', 1, [563]),
#  ('😷😝', 1, [919]),
#  ('elfirepfl', 1, [30]),
#  ('iciq', 1, [237]),
#  ('httpstco4xduwhjtu', 1, [782]),
#  ('in',
#   198,
#   [7,
#    27,
#    28,
#    33,
#    34,
#    35,
#    45,
#    46,
#    46,
#    52,
#    66,
#    72,
#    74,
#    76,
#    79,
#    89,
#    95,
#    98,
#    100,
#    102,
#    104,
#    112,
#    115,
#    126,
#    139,
#    139,
#    146,
#    148,
#    150,
#    150,
#    158,
#    175,
#    177,
#    185,
#    185,
#    187,
#    187,
#    188,
#    192,
#    203,
#    211,
#    215,
#    223,
#    225,
#    226,
#    238,
#    247,
#    264,
#    264,
#    270,
#    272,
#    276,
#    278,
#    286,
#    290,
#    292,
#    294,
#    301,
#    314,
#    316,
#    318,
#    326,
#    340,
#    340,
#    346,
#    352,
#    354,
#    358,
#    359,
#    370,
#    371,
#    374,
#    376,
#    381,
#    391,
#    394,
#    397,
#    401,
#    407,
#    413,
#    419,
#    419,
#    422,
#    432,
#    441,
#    446,
#    448,
#    468,
#    470,
#    477,
#    479,
#    480,
#    482,
#    483,
#    492,
#    494,
#    497,
#    498,
#    503,
#    513,
#    525,
#    531,
#    532,
#    545,
#    546,
#    549,
#    550,
#    557,
#    560,
#    560,
#    573,
#    576,
#    578,
#    580,
#    586,
#    589,
#    591,
#    601,
#    601,
#    615,
#    618,
#    624,
#    629,
#    630,
#    635,
#    639,
#    640,
#    641,
#    642,
#    645,
#    646,
#    655,
#    657,
#    663,
#    671,
#    672,
#    679,
#    686,
#    696,
#    697,
#    702,
#    707,
#    712,
#    714,
#    718,
#    720,
#    725,
#    734,
#    745,
#    755,
#    757,
#    759,
#    762,
#    768,
#    775,
#    784,
#    786,
#    807,
#    834,
#    834,
#    845,
#    850,
#    858,
#    858,
#    859,
#    863,
#    864,
#    869,
#    880,
#    885,
#    903,
#    903,
#    905,
#    907,
#    917,
#    919,
#    935,
#    944,
#    949,
#    959,
#    960,
#    960,
#    963,
#    963,
#    966,
#    971,
#    975,
#    984,
#    985,
#    992,
#    995,
#    1008,
#    1034,
#    1044,
#    1053,
#    1055,
#    1073,
#    1074]),
#  ('artificialintellig', 3, [292, 414, 452]),
#  ('exhibitiondesign', 1, [841]),
#  ('uzhnew', 5, [50, 391, 580, 759, 890]),
#  ('wast', 3, [166, 323, 555]),
#  ('praxisorientiert', 1, [167]),
#  ('peter', 1, [957]),
#  ('3dprintabl', 1, [544]),
#  ('energyharvest', 1, [642]),
#  ('synechronit', 1, [760]),
#  ('httpstco50enztwuhi', 1, [562]),
#  ('httpstcoskukeuexpm', 1, [75]),
#  ('httpstcormj8q7zfkl', 1, [161]),
#  ('httpstco6lmgbkcsdb', 1, [76]),
#  ('email', 1, [773]),
#  ('httpstcoxzqq8zekqj', 1, [729]),
#  ('timeshigh', 4, [121, 139, 319, 934]),
#  ('httpstcozdnwhb0ezl', 1, [1045]),
#  ('bartek', 1, [931]),
#  ('forecast', 1, [526]),
#  ('reprendr', 1, [207]),
#  ('bühler', 1, [323]),
#  ('vertrauen', 1, [384]),
#  ('repair', 3, [712, 966, 1000]),
#  ('natur', 8, [44, 104, 169, 414, 532, 562, 749, 831]),
#  ('httpstcox8uurri5oy', 1, [27]),
#  ('chroniqu', 1, [1031]),
#  ('amélior', 1, [149]),
#  ...]
